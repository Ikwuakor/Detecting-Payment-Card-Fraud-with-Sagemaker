# %% [markdown]
# # Detecting Payment Card Fraud
#
# In this section, we'll look at a credit card fraud detection dataset, and build a binary classification model that can identify transactions as either fraudulent or valid, based on provided, *historical* data. In a [2016 study](https://nilsonreport.com/upload/content_promo/The_Nilson_Report_10-17-2016.pdf), it was estimated that credit card fraud was responsible for over 20 billion dollars in loss, worldwide. Accurately detecting cases of fraud is an ongoing area of research.
#
# <img src=notebook_ims/fraud_detection.png width=50% />
#
# ### Labeled Data
#
# The payment fraud data set (Dal Pozzolo et al. 2015) was downloaded from [Kaggle](https://www.kaggle.com/mlg-ulb/creditcardfraud/data). This has features and labels for thousands of credit card transactions, each of which is labeled as fraudulent or valid. In this notebook, we'd like to train a model based on the features of these transactions so that we can predict risky or fraudulent transactions in the future.
#
# ### Binary Classification
#
# Since we have true labels to aim for, we'll take a **supervised learning** approach and train a binary classifier to sort data into one of our two transaction classes: fraudulent or valid.  We'll train a model on training data and see how well it generalizes on some test data.
#
# The notebook will be broken down into a few steps:
# * Loading and exploring the data
# * Splitting the data into train/test sets
# * Defining and training a LinearLearner, binary classifier
# * Making improvements on the model
# * Evaluating and comparing model test performance
#
# ### Making Improvements
#
# A lot of this notebook will focus on making improvements, as discussed in [this SageMaker blog post](https://aws.amazon.com/blogs/machine-learning/train-faster-more-flexible-models-with-amazon-sagemaker-linear-learner/). Specifically, we'll address techniques for:
#
# 1. **Tuning a model's hyperparameters** and aiming for a specific metric, such as high recall or precision.
# 2. **Managing class imbalance**, which is when we have many more training examples in one class than another (in this case, many more valid transactions than fraudulent).
#
# ---

# %% [markdown]
# First, import the usual resources.

# %%
import io
import os
import matplotlib.pyplot as plt
import numpy as np 
import pandas as pd
from sklearn.model_selection import train_test_split

import boto3
import sagemaker
from sagemaker import get_execution_role

# %matplotlib inline

# %% [markdown]
# I'm storing my **SageMaker variables** in the next cell:
# * sagemaker_session: The SageMaker session we'll use for training models.
# * bucket: The name of the default S3 bucket that we'll use for data storage.
# * role: The IAM role that defines our data and model permissions.

# %%
# sagemaker session, role
sagemaker_session = sagemaker.Session()
role = sagemaker.get_execution_role()

# S3 bucket name
bucket = sagemaker_session.default_bucket()

# %% [markdown]
# ## Loading and Exploring the Data
#
# Next, I am loading the data and unzipping the data in the file `creditcardfraud.zip`. This directory will hold one csv file of all the transaction data, `creditcard.csv`.
#
# As in previous notebooks, it's important to look at the distribution of data since this will inform how we develop a fraud detection model. We'll want to know: How many data points we have to work with, the number and type of features, and finally, the distribution of data over the classes (valid or fraudulent).

# %%
# only have to run once
#!wget https://s3.amazonaws.com/video.udacity-data.com/topher/2019/January/5c534768_creditcardfraud/creditcardfraud.zip
#!unzip creditcardfraud

# %%
# read in the csv file
local_data = 'creditcard.csv'

# print out some data
transaction_df = pd.read_csv(local_data)
print('Data shape (rows, cols): ', transaction_df.shape)
print()
transaction_df.head()
# Out:
# Data shape (rows, cols):  (284807, 31)
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %% [markdown]
# ### EXERCISE: Calculate the percentage of fraudulent data
#
# Take a look at the distribution of this transaction data over the classes, valid and fraudulent.
#
# Complete the function `fraudulent_percentage`, below. Count up the number of data points in each class and calculate the *percentage* of the data points that are fraudulent.

# %%
# Calculate the fraction of data points that are fraudulent
def fraudulent_percentage(transaction_df):
    '''Calculate the fraction of all data points that have a 'Class' label of 1; fraudulent.
       :param transaction_df: Dataframe of all transaction data points; has a column 'Class'
       :return: A fractional percentage of fraudulent data points/all points
    '''
    
    # your code here
    
    return transaction_df[transaction_df['Class']==1].shape[0]/transaction_df.shape[0]

# %% [markdown]
# Test out your code by calling your function and printing the result.

# %%
# call the function to calculate the fraud percentage
fraud_percentage = fraudulent_percentage(transaction_df)

print('Fraudulent percentage = ', fraud_percentage)
print('Total # of fraudulent pts: ', fraud_percentage*transaction_df.shape[0])
print('Out of (total) pts: ', transaction_df.shape[0])
# Out:
# Fraudulent percentage =  0.001727485630620034
# Total # of fraudulent pts:  492.0
# Out of (total) pts:  284807

# %% [markdown]
# ### EXERCISE: Split into train/test datasets
#
# In this example, we'll want to evaluate the performance of a fraud classifier; training it on some training data and testing it on *test data* that it did not see during the training process. So, we'll need to split the data into separate training and test sets.
#
# Complete the `train_test_split` function, below. This function should:
# * Shuffle the transaction data, randomly
# * Split it into two sets according to the parameter `train_frac`
# * Get train/test features and labels
# * Return the tuples: (train_features, train_labels), (test_features, test_labels)

# %%
# split into train/test
def split_data(transaction_df, test_size= 0.3, random_state=1):
    '''Shuffle the data and randomly split into train and test sets;
       separate the class labels (the column in transaction_df) from the features.
       :param df: Dataframe of all credit card transaction data
       :param train_frac: The decimal fraction of data that should be training data
       :param seed: Random seed for shuffling and reproducibility, default = 1
       :return: train_features, train_labels test_features, test_labels
       '''
    X = transaction_df.drop('Class', axis=1)
    y = transaction_df['Class']
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=random_state)
    
    # shuffle and split the data
    train_features = X_train
    train_labels = y_train
    test_features = X_test
    test_labels = y_test
    
    return train_features, test_features, train_labels, test_labels

# %% [markdown]
# ### Test Cell
#
# In the cells below, I'm creating the train/test data and checking to see that result makes sense. The tests below test that the above function splits the data into the expected number of points and that the labels are indeed, class labels (0, 1).

# %%
# get train/test data
train_features, test_features, train_labels, test_labels = split_data(transaction_df, test_size=0.3, random_state=1)

# %%
# manual test

# for a split of 0.7:0.3 there should be ~2.33x as many training as test pts
print('Training data pts: ', len(train_features))
print('Test data pts: ', len(test_features))
print()

# take a look at first item and see that it aligns with first row of data
print('First item: \n', train_features.iloc[0,:].values)
print('Label: ', train_labels[0])
print()

# test split
assert len(train_features) > 2.333*len(test_features), \
        'Unexpected number of train/test points for a train_frac=0.7'
# test labels
assert np.all(train_labels)== 0 or np.all(train_labels)== 1, \
        'Train labels should be 0s or 1s.'
assert np.all(test_labels)== 0 or np.all(test_labels)== 1, \
        'Test labels should be 0s or 1s.'
print('Tests passed!')
# Out:
# Training data pts:  199364
# Test data pts:  85443
#
# First item:
#  [ 1.29124000e+05 -1.90075436e-01  2.03322731e-01 -9.96232474e-01
#  -1.59698524e+00  3.19257862e+00  3.35693491e+00  2.88299308e-01
#   8.95002799e-01 -3.30023995e-01 -6.46900440e-01 -2.82784848e-01
#   2.32409086e-02 -4.21091590e-01  3.68246970e-01 -1.58464836e-01
#  -3.34755915e-01 -3.37179916e-01 -8.42032397e-01 -3.30126357e-02
#  -7.49605900e-03 -1.70598909e-01 -6.19723542e-01  3.96512932e-02
#   7.06805166e-01 -1.60869712e-01  2.74824647e-01 -1.05414134e-02
#   2.21991577e-02  1.43700000e+01]
# Label:  0
#
# Tests passed!

# %% [markdown]
# ---
# # Modeling
#
# Now that you've uploaded your training data, it's time to define and train a model!
#
# In this notebook, you'll define and train the SageMaker, built-in algorithm, [LinearLearner](https://sagemaker.readthedocs.io/en/stable/linear_learner.html).
#
# A LinearLearner has two main applications:
# 1. For regression tasks in which a linear line is fit to some data points, and you want to produce a predicted output value given some data point (example: predicting house prices given square area).
# 2. For binary classification, in which a line is separating two classes of data and effectively outputs labels; either 1 for data that falls above the line or 0 for points that fall on or below the line.
#
# <img src='notebook_ims/linear_separator.png' width=50% />
#
# In this case, we'll be using it for case 2, and we'll train it to separate data into our two classes: valid or fraudulent.

# %% [markdown]
# ### EXERCISE: Create a LinearLearner Estimator
#
# You've had some practice instantiating built-in models in SageMaker. All estimators require some constructor arguments to be passed in. See if you can complete this task, instantiating a LinearLearner estimator, using only the [LinearLearner documentation](https://sagemaker.readthedocs.io/en/stable/linear_learner.html) as a resource. This takes in a lot of arguments, but not all are required. My suggestion is to start with a simple model, utilizing default values where applicable. Later, we will discuss some specific hyperparameters and their use cases.
#
# #### Instance Types
#
# It is suggested that you use instances that are available in the free tier of usage: `'ml.c4.xlarge'` for training and `'ml.t2.medium'` for deployment.

# %%
# import LinearLearner
from sagemaker import LinearLearner

prefix = 'creditcard'
output_path = f's3://{bucket}/{prefix}'

# instantiate LinearLearner
lin_SM = LinearLearner(role=role,
                       instance_count=1,
                       instance_type='ml.c4.xlarge',
                       predictor_type='binary_classifier',
                       output_path=output_path,
                       sagemaker_session=sagemaker_session,
                       epochs=15)

# %% [markdown]
# ### EXERCISE: Convert data into a RecordSet format
#
# Next, prepare the data for a built-in model by converting the train features and labels into numpy array's of float values. Then you can use the [record_set function](https://sagemaker.readthedocs.io/en/stable/linear_learner.html#sagemaker.LinearLearner.record_set) to format the data as a RecordSet and prepare it for training!

# %%
# create RecordSet of training data
train_features_np = train_features.values.astype('float32')
train_labels_np = train_labels.values.astype('float32')

formatted_train_data = lin_SM.record_set(train_features_np, train_labels_np)

# %% [markdown]
# ### EXERCISE: Train the Estimator
#
# After instantiating your estimator, train it with a call to `.fit()`, passing in the formatted training data.

# %%
# %%time 
# train the estimator on formatted training data
lin_SM.fit(formatted_train_data)
# Out:
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# 2022-02-05 03:29:31 Starting - Starting the training job...
# 2022-02-05 03:29:33 Starting - Launching requested ML instancesProfilerReport-1644031771: InProgress
# ...
# 2022-02-05 03:30:31 Starting - Preparing the instances for training............
# 2022-02-05 03:32:28 Downloading - Downloading input data...
# 2022-02-05 03:32:53 Training - Training image download completed. Training in progress.Docker entrypoint called with argument(s): train
# Running default environment configuration script
# [02/05/2022 03:32:59 INFO 140328909731648] Reading default configuration from /opt/amazon/lib/python3.7/site-packages/algorithm/resources/default-input.json: {'mini_batch_size': '1000', 'epochs': '15', 'feature_dim': 'auto', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'accuracy', 'f_beta': '1.0', 'target_recall': '0.8', 'target_precision': '0.8', 'num_models': 'auto', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'auto', 'loss': 'auto', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '1', 'accuracy_top_k': '3', 'wd': 'auto', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': 'auto', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': 'auto', 'lr_scheduler_factor': 'auto', 'lr_scheduler_minimum_lr': 'auto', 'positive_example_weight_mult': '1.0', 'balance_multiclass_weights': 'false', 'normalize_data': 'true', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false'}
# [02/05/2022 03:32:59 INFO 140328909731648] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {'feature_dim': '30', 'predictor_type': 'binary_classifier', 'epochs': '15', 'mini_batch_size': '1000'}
# [02/05/2022 03:32:59 INFO 140328909731648] Final configuration: {'mini_batch_size': '1000', 'epochs': '15', 'feature_dim': '30', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'accuracy', 'f_beta': '1.0', 'target_recall': '0.8', 'target_precision': '0.8', 'num_models': 'auto', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'auto', 'loss': 'auto', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '1', 'accuracy_top_k': '3', 'wd': 'auto', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': 'auto', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': 'auto', 'lr_scheduler_factor': 'auto', 'lr_scheduler_minimum_lr': 'auto', 'positive_example_weight_mult': '1.0', 'balance_multiclass_weights': 'false', 'normalize_data': 'true', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false', 'predictor_type': 'binary_classifier'}
# [02/05/2022 03:32:59 WARNING 140328909731648] Loggers have already been setup.
# Process 1 is a worker.
# [02/05/2022 03:32:59 INFO 140328909731648] Using default worker.
# [02/05/2022 03:32:59 INFO 140328909731648] Checkpoint loading and saving are disabled.
# [2022-02-05 03:32:59.560] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration": 26, "num_examples": 1, "num_bytes": 168000}
# [02/05/2022 03:32:59 INFO 140328909731648] Create Store: local
# [2022-02-05 03:32:59.639] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 1, "duration": 79, "num_examples": 11, "num_bytes": 1848000}
# [02/05/2022 03:32:59 INFO 140328909731648] Scaler algorithm parameters
#  <algorithm.scaler.ScalerAlgorithmStable object at 0x7fa07e189550>
# [02/05/2022 03:32:59 INFO 140328909731648] Scaling model computed with parameters:
#  {'stdev_label': None, 'stdev_weight':
# [4.7823008e+04 1.8987731e+00 1.5821997e+00 1.5291911e+00 1.4364978e+00
#  1.3388461e+00 1.2955806e+00 1.1771069e+00 1.2127448e+00 1.0843055e+00
#  1.0475702e+00 1.0230465e+00 1.0090139e+00 1.0057642e+00 9.5122164e-01
#  9.2613727e-01 8.7072927e-01 8.6057234e-01 8.3151484e-01 8.2762748e-01
#  7.1313608e-01 7.3347980e-01 7.2524083e-01 5.6213826e-01 6.0201687e-01
#  5.1174247e-01 4.8000538e-01 3.7595215e-01 2.7081874e-01 2.3656270e+02]
# <NDArray 30 @cpu(0)>, 'mean_label': None, 'mean_weight':
# [ 9.4275984e+04 -1.7378727e-02  1.5538026e-02  2.5005125e-02
#   3.3166975e-02  1.8197566e-02  1.7799012e-03  6.9396999e-03
#   9.8540336e-03 -3.0757964e-02 -1.2736557e-02  4.0434714e-04
#  -1.4243029e-02  1.6704608e-02  2.2619881e-02 -9.6982103e-03
#  -4.7834702e-03 -1.6767335e-04 -9.0120723e-03 -3.0407687e-03
#   4.6031545e-03 -4.0078526e-03 -1.2586080e-04  1.2784966e-03
#   3.7617318e-03 -3.1254767e-03 -8.2200055e-04  3.4045519e-03
#  -1.0332187e-03  8.7559837e+01]
# <NDArray 30 @cpu(0)>}
# [02/05/2022 03:32:59 INFO 140328909731648] nvidia-smi: took 0.055 seconds to run.
# [02/05/2022 03:32:59 INFO 140328909731648] nvidia-smi identified 0 GPUs.
# [02/05/2022 03:32:59 INFO 140328909731648] Number of GPUs being used: 0
# #metrics {"StartTime": 1644031979.7749026, "EndTime": 1644031979.7749352, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "Meta": "init_train_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 12000.0, "count": 1, "min": 12000, "max": 12000}, "Total Batches Seen": {"sum": 12.0, "count": 1, "min": 12, "max": 12}, "Max Records Seen Between Resets": {"sum": 11000.0, "count": 1, "min": 11000, "max": 11000}, "Max Batches Seen Between Resets": {"sum": 11.0, "count": 1, "min": 11, "max": 11}, "Reset Count": {"sum": 2.0, "count": 1, "min": 2, "max": 2}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [2022-02-05 03:33:06.455] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 3, "duration": 6679, "num_examples": 200, "num_bytes": 33493152}
# #metrics {"StartTime": 1644031986.4552803, "EndTime": 1644031986.4553754, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 0}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.12023840661743777, "count": 1, "min": 0.12023840661743777, "max": 0.12023840661743777}}}
# #metrics {"StartTime": 1644031986.4554644, "EndTime": 1644031986.4554791, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 1}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.1175625283514435, "count": 1, "min": 0.1175625283514435, "max": 0.1175625283514435}}}
# #metrics {"StartTime": 1644031986.4555225, "EndTime": 1644031986.4555337, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 2}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.12012009677216036, "count": 1, "min": 0.12012009677216036, "max": 0.12012009677216036}}}
# #metrics {"StartTime": 1644031986.45557, "EndTime": 1644031986.4555802, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 3}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.11766779350395777, "count": 1, "min": 0.11766779350395777, "max": 0.11766779350395777}}}
# #metrics {"StartTime": 1644031986.4556136, "EndTime": 1644031986.4556231, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 4}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.012220082102483841, "count": 1, "min": 0.012220082102483841, "max": 0.012220082102483841}}}
# #metrics {"StartTime": 1644031986.4556568, "EndTime": 1644031986.455666, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 5}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.012175582823441855, "count": 1, "min": 0.012175582823441855, "max": 0.012175582823441855}}}
# #metrics {"StartTime": 1644031986.4556992, "EndTime": 1644031986.455709, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 6}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.012201707582415348, "count": 1, "min": 0.012201707582415348, "max": 0.012201707582415348}}}
# #metrics {"StartTime": 1644031986.4557421, "EndTime": 1644031986.4557514, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 7}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.012345536659747811, "count": 1, "min": 0.012345536659747811, "max": 0.012345536659747811}}}
# #metrics {"StartTime": 1644031986.4557846, "EndTime": 1644031986.4557936, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 8}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.12014251477035445, "count": 1, "min": 0.12014251477035445, "max": 0.12014251477035445}}}
# #metrics {"StartTime": 1644031986.4558265, "EndTime": 1644031986.4558358, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 9}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.11776210052643589, "count": 1, "min": 0.11776210052643589, "max": 0.11776210052643589}}}
# #metrics {"StartTime": 1644031986.4558685, "EndTime": 1644031986.4558775, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 10}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.12038165889912514, "count": 1, "min": 0.12038165889912514, "max": 0.12038165889912514}}}
# #metrics {"StartTime": 1644031986.4559102, "EndTime": 1644031986.4559193, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 11}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.11770791634602762, "count": 1, "min": 0.11770791634602762, "max": 0.11770791634602762}}}
# #metrics {"StartTime": 1644031986.455961, "EndTime": 1644031986.4559703, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 12}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.01261257816119185, "count": 1, "min": 0.01261257816119185, "max": 0.01261257816119185}}}
# #metrics {"StartTime": 1644031986.4560072, "EndTime": 1644031986.45602, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 13}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.012488340938866289, "count": 1, "min": 0.012488340938866289, "max": 0.012488340938866289}}}
# #metrics {"StartTime": 1644031986.4560635, "EndTime": 1644031986.4560754, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 14}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.012396600667237486, "count": 1, "min": 0.012396600667237486, "max": 0.012396600667237486}}}
# #metrics {"StartTime": 1644031986.4561102, "EndTime": 1644031986.4561195, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 15}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.012499406192096035, "count": 1, "min": 0.012499406192096035, "max": 0.012499406192096035}}}
# #metrics {"StartTime": 1644031986.4561543, "EndTime": 1644031986.456167, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 16}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.1228250465488913, "count": 1, "min": 0.1228250465488913, "max": 0.1228250465488913}}}
# #metrics {"StartTime": 1644031986.4562101, "EndTime": 1644031986.4562216, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 17}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.12008383270723735, "count": 1, "min": 0.12008383270723735, "max": 0.12008383270723735}}}
# #metrics {"StartTime": 1644031986.4562562, "EndTime": 1644031986.4562657, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 18}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.12283358952507901, "count": 1, "min": 0.12283358952507901, "max": 0.12283358952507901}}}
# #metrics {"StartTime": 1644031986.456302, "EndTime": 1644031986.4563115, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 19}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.12025850340109974, "count": 1, "min": 0.12025850340109974, "max": 0.12025850340109974}}}
# #metrics {"StartTime": 1644031986.4563475, "EndTime": 1644031986.4563575, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 20}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.019943902858238126, "count": 1, "min": 0.019943902858238126, "max": 0.019943902858238126}}}
# #metrics {"StartTime": 1644031986.4563909, "EndTime": 1644031986.4564002, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 21}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.01993385848758658, "count": 1, "min": 0.01993385848758658, "max": 0.01993385848758658}}}
# #metrics {"StartTime": 1644031986.456432, "EndTime": 1644031986.4564414, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 22}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.019987651391170133, "count": 1, "min": 0.019987651391170133, "max": 0.019987651391170133}}}
# #metrics {"StartTime": 1644031986.4564736, "EndTime": 1644031986.456483, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 23}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.01984426697302404, "count": 1, "min": 0.01984426697302404, "max": 0.01984426697302404}}}
# #metrics {"StartTime": 1644031986.4565146, "EndTime": 1644031986.4565237, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 24}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.12367208990739219, "count": 1, "min": 0.12367208990739219, "max": 0.12367208990739219}}}
# #metrics {"StartTime": 1644031986.4565556, "EndTime": 1644031986.4565644, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 25}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.12108522349985401, "count": 1, "min": 0.12108522349985401, "max": 0.12108522349985401}}}
# #metrics {"StartTime": 1644031986.4565964, "EndTime": 1644031986.4566057, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 26}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.12374423226399638, "count": 1, "min": 0.12374423226399638, "max": 0.12374423226399638}}}
# #metrics {"StartTime": 1644031986.4566371, "EndTime": 1644031986.4566464, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 27}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.12116944918800239, "count": 1, "min": 0.12116944918800239, "max": 0.12116944918800239}}}
# #metrics {"StartTime": 1644031986.4566784, "EndTime": 1644031986.4566875, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 28}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.02103997616806821, "count": 1, "min": 0.02103997616806821, "max": 0.02103997616806821}}}
# #metrics {"StartTime": 1644031986.456722, "EndTime": 1644031986.4567344, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 29}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.020920196363487135, "count": 1, "min": 0.020920196363487135, "max": 0.020920196363487135}}}
# #metrics {"StartTime": 1644031986.4567692, "EndTime": 1644031986.4567778, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 30}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.021012824348543756, "count": 1, "min": 0.021012824348543756, "max": 0.021012824348543756}}}
# #metrics {"StartTime": 1644031986.4568012, "EndTime": 1644031986.456808, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 31}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.021031404245476327, "count": 1, "min": 0.021031404245476327, "max": 0.021031404245476327}}}
# [02/05/2022 03:33:06 INFO 140328909731648] #quality_metric: host=algo-1, epoch=0, train binary_classification_cross_entropy_objective <loss>=0.12023840661743777
# [02/05/2022 03:33:06 INFO 140328909731648] #early_stopping_criteria_metric: host=algo-1, epoch=0, criteria=binary_classification_cross_entropy_objective, value=0.012175582823441855
# [02/05/2022 03:33:06 INFO 140328909731648] Epoch 0: Loss improved. Updating best model
# [02/05/2022 03:33:06 INFO 140328909731648] Saving model for epoch: 0
# [02/05/2022 03:33:06 INFO 140328909731648] Saved checkpoint to "/tmp/tmpv0lmrx3c/mx-mod-0000.params"
# [02/05/2022 03:33:06 INFO 140328909731648] #progress_metric: host=algo-1, completed 6.666666666666667 % of epochs
# #metrics {"StartTime": 1644031979.7751975, "EndTime": 1644031986.4724758, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 211364.0, "count": 1, "min": 211364, "max": 211364}, "Total Batches Seen": {"sum": 212.0, "count": 1, "min": 212, "max": 212}, "Max Records Seen Between Resets": {"sum": 199364.0, "count": 1, "min": 199364, "max": 199364}, "Max Batches Seen Between Resets": {"sum": 200.0, "count": 1, "min": 200, "max": 200}, "Reset Count": {"sum": 3.0, "count": 1, "min": 3, "max": 3}, "Number of Records Since Last Reset": {"sum": 199364.0, "count": 1, "min": 199364, "max": 199364}, "Number of Batches Since Last Reset": {"sum": 200.0, "count": 1, "min": 200, "max": 200}}}
# [02/05/2022 03:33:06 INFO 140328909731648] #throughput_metric: host=algo-1, train throughput=29767.319015618606 records/second
# [2022-02-05 03:33:13.470] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 5, "duration": 6996, "num_examples": 200, "num_bytes": 33493152}
# #metrics {"StartTime": 1644031993.4700723, "EndTime": 1644031993.470158, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 0}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.016883339575187645, "count": 1, "min": 0.016883339575187645, "max": 0.016883339575187645}}}
# #metrics {"StartTime": 1644031993.4702477, "EndTime": 1644031993.470268, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 1}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.014893327607581363, "count": 1, "min": 0.014893327607581363, "max": 0.014893327607581363}}}
# #metrics {"StartTime": 1644031993.4703238, "EndTime": 1644031993.470342, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 2}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.01687481061178236, "count": 1, "min": 0.01687481061178236, "max": 0.01687481061178236}}}
# #metrics {"StartTime": 1644031993.4703965, "EndTime": 1644031993.4704137, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 3}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.014889016120278056, "count": 1, "min": 0.014889016120278056, "max": 0.014889016120278056}}}
# #metrics {"StartTime": 1644031993.4704673, "EndTime": 1644031993.4704847, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 4}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.0054091289906046496, "count": 1, "min": 0.0054091289906046496, "max": 0.0054091289906046496}}}
# #metrics {"StartTime": 1644031993.4705374, "EndTime": 1644031993.4705534, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 5}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.0055940955086569094, "count": 1, "min": 0.0055940955086569094, "max": 0.0055940955086569094}}}
# #metrics {"StartTime": 1644031993.4706042, "EndTime": 1644031993.4706209, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 6}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.00551705657522283, "count": 1, "min": 0.00551705657522283, "max": 0.00551705657522283}}}
# #metrics {"StartTime": 1644031993.4706733, "EndTime": 1644031993.470689, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 7}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.005566651671825342, "count": 1, "min": 0.005566651671825342, "max": 0.005566651671825342}}}
# #metrics {"StartTime": 1644031993.470751, "EndTime": 1644031993.4707682, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 8}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.0170403941312627, "count": 1, "min": 0.0170403941312627, "max": 0.0170403941312627}}}
# #metrics {"StartTime": 1644031993.470818, "EndTime": 1644031993.4708345, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 9}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.015086053342675444, "count": 1, "min": 0.015086053342675444, "max": 0.015086053342675444}}}
# #metrics {"StartTime": 1644031993.4708843, "EndTime": 1644031993.4709008, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 10}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.017052275235928484, "count": 1, "min": 0.017052275235928484, "max": 0.017052275235928484}}}
# #metrics {"StartTime": 1644031993.4709527, "EndTime": 1644031993.4709697, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 11}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.015078012080647837, "count": 1, "min": 0.015078012080647837, "max": 0.015078012080647837}}}
# #metrics {"StartTime": 1644031993.471029, "EndTime": 1644031993.4710464, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 12}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.005623061710715893, "count": 1, "min": 0.005623061710715893, "max": 0.005623061710715893}}}
# #metrics {"StartTime": 1644031993.4711006, "EndTime": 1644031993.4711177, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 13}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.005685889098512468, "count": 1, "min": 0.005685889098512468, "max": 0.005685889098512468}}}
# #metrics {"StartTime": 1644031993.4711692, "EndTime": 1644031993.4711857, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 14}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.005619973746376421, "count": 1, "min": 0.005619973746376421, "max": 0.005619973746376421}}}
# #metrics {"StartTime": 1644031993.4712343, "EndTime": 1644031993.4712505, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 15}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.005672148302122576, "count": 1, "min": 0.005672148302122576, "max": 0.005672148302122576}}}
# #metrics {"StartTime": 1644031993.4713013, "EndTime": 1644031993.4713163, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 16}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.02126987413665158, "count": 1, "min": 0.02126987413665158, "max": 0.02126987413665158}}}
# #metrics {"StartTime": 1644031993.4713638, "EndTime": 1644031993.4713798, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 17}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.019476390440859387, "count": 1, "min": 0.019476390440859387, "max": 0.019476390440859387}}}
# #metrics {"StartTime": 1644031993.4714298, "EndTime": 1644031993.4714448, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 18}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.02127108111932649, "count": 1, "min": 0.02127108111932649, "max": 0.02127108111932649}}}
# #metrics {"StartTime": 1644031993.4714956, "EndTime": 1644031993.4715111, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 19}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.01948852028679009, "count": 1, "min": 0.01948852028679009, "max": 0.01948852028679009}}}
# #metrics {"StartTime": 1644031993.4715588, "EndTime": 1644031993.4715743, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 20}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.012074755899271174, "count": 1, "min": 0.012074755899271174, "max": 0.012074755899271174}}}
# #metrics {"StartTime": 1644031993.4716322, "EndTime": 1644031993.4716492, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 21}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.012111119604589951, "count": 1, "min": 0.012111119604589951, "max": 0.012111119604589951}}}
# #metrics {"StartTime": 1644031993.471693, "EndTime": 1644031993.4717083, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 22}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.01207915733866955, "count": 1, "min": 0.01207915733866955, "max": 0.01207915733866955}}}
# #metrics {"StartTime": 1644031993.4717636, "EndTime": 1644031993.4717805, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 23}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.01210820182843424, "count": 1, "min": 0.01210820182843424, "max": 0.01210820182843424}}}
# #metrics {"StartTime": 1644031993.4718354, "EndTime": 1644031993.471851, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 24}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.022298133768627992, "count": 1, "min": 0.022298133768627992, "max": 0.022298133768627992}}}
# #metrics {"StartTime": 1644031993.4719067, "EndTime": 1644031993.4719229, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 25}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.020528922866936306, "count": 1, "min": 0.020528922866936306, "max": 0.020528922866936306}}}
# #metrics {"StartTime": 1644031993.4719641, "EndTime": 1644031993.4719794, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 26}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.022301760285343957, "count": 1, "min": 0.022301760285343957, "max": 0.022301760285343957}}}
# #metrics {"StartTime": 1644031993.4720197, "EndTime": 1644031993.472035, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 27}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.020534939981585173, "count": 1, "min": 0.020534939981585173, "max": 0.020534939981585173}}}
# #metrics {"StartTime": 1644031993.472078, "EndTime": 1644031993.4720929, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 28}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.01314413232719479, "count": 1, "min": 0.01314413232719479, "max": 0.01314413232719479}}}
# #metrics {"StartTime": 1644031993.4721339, "EndTime": 1644031993.4721477, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 29}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.013147845992490874, "count": 1, "min": 0.013147845992490874, "max": 0.013147845992490874}}}
# #metrics {"StartTime": 1644031993.4722023, "EndTime": 1644031993.4722183, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 30}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.013144269559251603, "count": 1, "min": 0.013144269559251603, "max": 0.013144269559251603}}}
# #metrics {"StartTime": 1644031993.472269, "EndTime": 1644031993.4722853, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 31}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.013148174486567627, "count": 1, "min": 0.013148174486567627, "max": 0.013148174486567627}}}
# [02/05/2022 03:33:13 INFO 140328909731648] #quality_metric: host=algo-1, epoch=1, train binary_classification_cross_entropy_objective <loss>=0.016883339575187645
# [02/05/2022 03:33:13 INFO 140328909731648] #early_stopping_criteria_metric: host=algo-1, epoch=1, criteria=binary_classification_cross_entropy_objective, value=0.0054091289906046496
# [02/05/2022 03:33:13 INFO 140328909731648] Epoch 1: Loss improved. Updating best model
# [02/05/2022 03:33:13 INFO 140328909731648] Saving model for epoch: 1
# [02/05/2022 03:33:13 INFO 140328909731648] Saved checkpoint to "/tmp/tmp6m3m5cpc/mx-mod-0000.params"
# [02/05/2022 03:33:13 INFO 140328909731648] #progress_metric: host=algo-1, completed 13.333333333333334 % of epochs
# #metrics {"StartTime": 1644031986.473756, "EndTime": 1644031993.47961, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 410728.0, "count": 1, "min": 410728, "max": 410728}, "Total Batches Seen": {"sum": 412.0, "count": 1, "min": 412, "max": 412}, "Max Records Seen Between Resets": {"sum": 199364.0, "count": 1, "min": 199364, "max": 199364}, "Max Batches Seen Between Resets": {"sum": 200.0, "count": 1, "min": 200, "max": 200}, "Reset Count": {"sum": 4.0, "count": 1, "min": 4, "max": 4}, "Number of Records Since Last Reset": {"sum": 199364.0, "count": 1, "min": 199364, "max": 199364}, "Number of Batches Since Last Reset": {"sum": 200.0, "count": 1, "min": 200, "max": 200}}}
# [02/05/2022 03:33:13 INFO 140328909731648] #throughput_metric: host=algo-1, train throughput=28456.303231354785 records/second
# [2022-02-05 03:33:19.703] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 7, "duration": 6222, "num_examples": 200, "num_bytes": 33493152}
# #metrics {"StartTime": 1644031999.7039418, "EndTime": 1644031999.7040284, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 0}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.010249469512671083, "count": 1, "min": 0.010249469512671083, "max": 0.010249469512671083}}}
# #metrics {"StartTime": 1644031999.7041006, "EndTime": 1644031999.7041156, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 1}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.008671593309047832, "count": 1, "min": 0.008671593309047832, "max": 0.008671593309047832}}}
# #metrics {"StartTime": 1644031999.7041903, "EndTime": 1644031999.7042081, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 2}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.010244108916527063, "count": 1, "min": 0.010244108916527063, "max": 0.010244108916527063}}}
# #metrics {"StartTime": 1644031999.7042596, "EndTime": 1644031999.7042768, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 3}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.00867205645930228, "count": 1, "min": 0.00867205645930228, "max": 0.00867205645930228}}}
# #metrics {"StartTime": 1644031999.7043283, "EndTime": 1644031999.704344, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 4}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.004918119081076066, "count": 1, "min": 0.004918119081076066, "max": 0.004918119081076066}}}
# #metrics {"StartTime": 1644031999.7043965, "EndTime": 1644031999.7044132, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 5}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.005651303291320801, "count": 1, "min": 0.005651303291320801, "max": 0.005651303291320801}}}
# #metrics {"StartTime": 1644031999.704463, "EndTime": 1644031999.7044795, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 6}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.0049273479259643125, "count": 1, "min": 0.0049273479259643125, "max": 0.0049273479259643125}}}
# #metrics {"StartTime": 1644031999.7045305, "EndTime": 1644031999.704546, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 7}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.005490868361226878, "count": 1, "min": 0.005490868361226878, "max": 0.005490868361226878}}}
# #metrics {"StartTime": 1644031999.7045994, "EndTime": 1644031999.7046142, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 8}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.010515944255656334, "count": 1, "min": 0.010515944255656334, "max": 0.010515944255656334}}}
# #metrics {"StartTime": 1644031999.7046654, "EndTime": 1644031999.7046826, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 9}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.009003221483086821, "count": 1, "min": 0.009003221483086821, "max": 0.009003221483086821}}}
# #metrics {"StartTime": 1644031999.704743, "EndTime": 1644031999.7047594, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 10}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.010521823832737141, "count": 1, "min": 0.010521823832737141, "max": 0.010521823832737141}}}
# #metrics {"StartTime": 1644031999.7048101, "EndTime": 1644031999.7048252, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 11}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.008999888767549142, "count": 1, "min": 0.008999888767549142, "max": 0.008999888767549142}}}
# #metrics {"StartTime": 1644031999.704875, "EndTime": 1644031999.7048914, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 12}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.005593623910117988, "count": 1, "min": 0.005593623910117988, "max": 0.005593623910117988}}}
# #metrics {"StartTime": 1644031999.7049415, "EndTime": 1644031999.704957, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 13}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.005721277174338624, "count": 1, "min": 0.005721277174338624, "max": 0.005721277174338624}}}
# #metrics {"StartTime": 1644031999.7050064, "EndTime": 1644031999.7050216, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 14}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.005546630558656089, "count": 1, "min": 0.005546630558656089, "max": 0.005546630558656089}}}
# #metrics {"StartTime": 1644031999.7050712, "EndTime": 1644031999.7050867, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 15}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.005712993024581641, "count": 1, "min": 0.005712993024581641, "max": 0.005712993024581641}}}
# #metrics {"StartTime": 1644031999.7051344, "EndTime": 1644031999.7051506, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 16}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.015533093172102119, "count": 1, "min": 0.015533093172102119, "max": 0.015533093172102119}}}
# #metrics {"StartTime": 1644031999.7052004, "EndTime": 1644031999.7052152, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 17}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.0142904183541111, "count": 1, "min": 0.0142904183541111, "max": 0.0142904183541111}}}
# #metrics {"StartTime": 1644031999.7052677, "EndTime": 1644031999.7052848, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 18}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.01553408638556399, "count": 1, "min": 0.01553408638556399, "max": 0.01553408638556399}}}
# #metrics {"StartTime": 1644031999.7053351, "EndTime": 1644031999.705351, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 19}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.014295967495022108, "count": 1, "min": 0.014295967495022108, "max": 0.014295967495022108}}}
# #metrics {"StartTime": 1644031999.7054021, "EndTime": 1644031999.7054183, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 20}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.012072144002171617, "count": 1, "min": 0.012072144002171617, "max": 0.012072144002171617}}}
# #metrics {"StartTime": 1644031999.7054677, "EndTime": 1644031999.7054834, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 21}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.0121305170963757, "count": 1, "min": 0.0121305170963757, "max": 0.0121305170963757}}}
# #metrics {"StartTime": 1644031999.7055337, "EndTime": 1644031999.7055492, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 22}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.012072037987373583, "count": 1, "min": 0.012072037987373583, "max": 0.012072037987373583}}}
# #metrics {"StartTime": 1644031999.7056015, "EndTime": 1644031999.7056162, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 23}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.012126008991021007, "count": 1, "min": 0.012126008991021007, "max": 0.012126008991021007}}}
# #metrics {"StartTime": 1644031999.7056627, "EndTime": 1644031999.7056792, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 24}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.016575735899671238, "count": 1, "min": 0.016575735899671238, "max": 0.016575735899671238}}}
# #metrics {"StartTime": 1644031999.7057285, "EndTime": 1644031999.7057447, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 25}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.01536184029123891, "count": 1, "min": 0.01536184029123891, "max": 0.01536184029123891}}}
# #metrics {"StartTime": 1644031999.7057927, "EndTime": 1644031999.705809, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 26}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.01657752835451059, "count": 1, "min": 0.01657752835451059, "max": 0.01657752835451059}}}
# #metrics {"StartTime": 1644031999.705858, "EndTime": 1644031999.7058733, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 27}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.01536392712712887, "count": 1, "min": 0.01536392712712887, "max": 0.01536392712712887}}}
# #metrics {"StartTime": 1644031999.7059245, "EndTime": 1644031999.705939, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 28}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.013144806580327862, "count": 1, "min": 0.013144806580327862, "max": 0.013144806580327862}}}
# #metrics {"StartTime": 1644031999.7059865, "EndTime": 1644031999.706003, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 29}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.013156182020153832, "count": 1, "min": 0.013156182020153832, "max": 0.013156182020153832}}}
# #metrics {"StartTime": 1644031999.7060533, "EndTime": 1644031999.7060955, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 30}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.013145586877012972, "count": 1, "min": 0.013145586877012972, "max": 0.013145586877012972}}}
# #metrics {"StartTime": 1644031999.7061503, "EndTime": 1644031999.706166, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 31}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.01315547815998595, "count": 1, "min": 0.01315547815998595, "max": 0.01315547815998595}}}
# [02/05/2022 03:33:19 INFO 140328909731648] #quality_metric: host=algo-1, epoch=2, train binary_classification_cross_entropy_objective <loss>=0.010249469512671083
# [02/05/2022 03:33:19 INFO 140328909731648] #early_stopping_criteria_metric: host=algo-1, epoch=2, criteria=binary_classification_cross_entropy_objective, value=0.004918119081076066
# [02/05/2022 03:33:19 INFO 140328909731648] Epoch 2: Loss improved. Updating best model
# [02/05/2022 03:33:19 INFO 140328909731648] Saving model for epoch: 2
# [02/05/2022 03:33:19 INFO 140328909731648] Saved checkpoint to "/tmp/tmp97gs7ack/mx-mod-0000.params"
# [02/05/2022 03:33:19 INFO 140328909731648] #progress_metric: host=algo-1, completed 20.0 % of epochs
# #metrics {"StartTime": 1644031993.4809477, "EndTime": 1644031999.7142675, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 610092.0, "count": 1, "min": 610092, "max": 610092}, "Total Batches Seen": {"sum": 612.0, "count": 1, "min": 612, "max": 612}, "Max Records Seen Between Resets": {"sum": 199364.0, "count": 1, "min": 199364, "max": 199364}, "Max Batches Seen Between Resets": {"sum": 200.0, "count": 1, "min": 200, "max": 200}, "Reset Count": {"sum": 5.0, "count": 1, "min": 5, "max": 5}, "Number of Records Since Last Reset": {"sum": 199364.0, "count": 1, "min": 199364, "max": 199364}, "Number of Batches Since Last Reset": {"sum": 200.0, "count": 1, "min": 200, "max": 200}}}
# [02/05/2022 03:33:19 INFO 140328909731648] #throughput_metric: host=algo-1, train throughput=31983.01309030738 records/second
# [2022-02-05 03:33:26.019] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 9, "duration": 6304, "num_examples": 200, "num_bytes": 33493152}
# #metrics {"StartTime": 1644032006.0191004, "EndTime": 1644032006.0191553, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 0}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.00796071047279703, "count": 1, "min": 0.00796071047279703, "max": 0.00796071047279703}}}
# #metrics {"StartTime": 1644032006.0192287, "EndTime": 1644032006.019251, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 1}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.0066089136300973555, "count": 1, "min": 0.0066089136300973555, "max": 0.0066089136300973555}}}
# #metrics {"StartTime": 1644032006.019305, "EndTime": 1644032006.0193214, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 2}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.007957086086273194, "count": 1, "min": 0.007957086086273194, "max": 0.007957086086273194}}}
# #metrics {"StartTime": 1644032006.0193753, "EndTime": 1644032006.0193875, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 3}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.006610484449108642, "count": 1, "min": 0.006610484449108642, "max": 0.006610484449108642}}}
# ...
# #metrics {"StartTime": 1644032077.3175876, "EndTime": 1644032077.3176057, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 4}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.0040303359740044, "count": 1, "min": 0.0040303359740044, "max": 0.0040303359740044}}}
# #metrics {"StartTime": 1644032077.3176637, "EndTime": 1644032077.3176813, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 5}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.005875211362862707, "count": 1, "min": 0.005875211362862707, "max": 0.005875211362862707}}}
# #metrics {"StartTime": 1644032077.3177245, "EndTime": 1644032077.3177404, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 6}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.00404278004139512, "count": 1, "min": 0.00404278004139512, "max": 0.00404278004139512}}}
# #metrics {"StartTime": 1644032077.3177917, "EndTime": 1644032077.3178089, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 7}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.005471848284853763, "count": 1, "min": 0.005471848284853763, "max": 0.005471848284853763}}}
# #metrics {"StartTime": 1644032077.3178618, "EndTime": 1644032077.3178787, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 8}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.0055071240819279275, "count": 1, "min": 0.0055071240819279275, "max": 0.0055071240819279275}}}
# #metrics {"StartTime": 1644032077.31793, "EndTime": 1644032077.3179467, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 9}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.005093599353004341, "count": 1, "min": 0.005093599353004341, "max": 0.005093599353004341}}}
# #metrics {"StartTime": 1644032077.3180099, "EndTime": 1644032077.3180258, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 10}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.005507833725243956, "count": 1, "min": 0.005507833725243956, "max": 0.005507833725243956}}}
# #metrics {"StartTime": 1644032077.3181076, "EndTime": 1644032077.3181248, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 11}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.005093542199638022, "count": 1, "min": 0.005093542199638022, "max": 0.005093542199638022}}}
# #metrics {"StartTime": 1644032077.3181758, "EndTime": 1644032077.3181932, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 12}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.0050990720678813495, "count": 1, "min": 0.0050990720678813495, "max": 0.0050990720678813495}}}
# #metrics {"StartTime": 1644032077.3182435, "EndTime": 1644032077.3182597, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 13}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.005519994659040441, "count": 1, "min": 0.005519994659040441, "max": 0.005519994659040441}}}
# #metrics {"StartTime": 1644032077.318312, "EndTime": 1644032077.3183284, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 14}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.005098994569862308, "count": 1, "min": 0.005098994569862308, "max": 0.005098994569862308}}}
# #metrics {"StartTime": 1644032077.3183784, "EndTime": 1644032077.3183947, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 15}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.005520632858851448, "count": 1, "min": 0.005520632858851448, "max": 0.005520632858851448}}}
# #metrics {"StartTime": 1644032077.318452, "EndTime": 1644032077.3184693, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 16}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.012167769629751617, "count": 1, "min": 0.012167769629751617, "max": 0.012167769629751617}}}
# #metrics {"StartTime": 1644032077.318519, "EndTime": 1644032077.3185349, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 17}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.012054018840118868, "count": 1, "min": 0.012054018840118868, "max": 0.012054018840118868}}}
# #metrics {"StartTime": 1644032077.3185787, "EndTime": 1644032077.3185937, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 18}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.012167777455631811, "count": 1, "min": 0.012167777455631811, "max": 0.012167777455631811}}}
# #metrics {"StartTime": 1644032077.3186476, "EndTime": 1644032077.3186638, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 19}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.012054238608135051, "count": 1, "min": 0.012054238608135051, "max": 0.012054238608135051}}}
# #metrics {"StartTime": 1644032077.3187137, "EndTime": 1644032077.3187308, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 20}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.012039981996593762, "count": 1, "min": 0.012039981996593762, "max": 0.012039981996593762}}}
# #metrics {"StartTime": 1644032077.3187826, "EndTime": 1644032077.3187988, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 21}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.012189195263625389, "count": 1, "min": 0.012189195263625389, "max": 0.012189195263625389}}}
# #metrics {"StartTime": 1644032077.318842, "EndTime": 1644032077.3188565, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 22}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.012040088680521328, "count": 1, "min": 0.012040088680521328, "max": 0.012040088680521328}}}
# #metrics {"StartTime": 1644032077.3189063, "EndTime": 1644032077.3189216, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 23}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.012187875629968979, "count": 1, "min": 0.012187875629968979, "max": 0.012187875629968979}}}
# #metrics {"StartTime": 1644032077.3189735, "EndTime": 1644032077.31899, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 24}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.013193741987698042, "count": 1, "min": 0.013193741987698042, "max": 0.013193741987698042}}}
# #metrics {"StartTime": 1644032077.3190446, "EndTime": 1644032077.3190613, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 25}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.013127850090438997, "count": 1, "min": 0.013127850090438997, "max": 0.013127850090438997}}}
# #metrics {"StartTime": 1644032077.3191137, "EndTime": 1644032077.319129, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 26}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.013193773884270059, "count": 1, "min": 0.013193773884270059, "max": 0.013193773884270059}}}
# #metrics {"StartTime": 1644032077.319191, "EndTime": 1644032077.3192074, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 27}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.013127679164685196, "count": 1, "min": 0.013127679164685196, "max": 0.013127679164685196}}}
# #metrics {"StartTime": 1644032077.3192642, "EndTime": 1644032077.31928, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 28}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.013136238493512024, "count": 1, "min": 0.013136238493512024, "max": 0.013136238493512024}}}
# #metrics {"StartTime": 1644032077.3193326, "EndTime": 1644032077.3193483, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 29}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.013258359701190162, "count": 1, "min": 0.013258359701190162, "max": 0.013258359701190162}}}
# #metrics {"StartTime": 1644032077.3193996, "EndTime": 1644032077.3194153, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 30}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.013136125135062328, "count": 1, "min": 0.013136125135062328, "max": 0.013136125135062328}}}
# #metrics {"StartTime": 1644032077.319468, "EndTime": 1644032077.319485, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 31}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.013257740079757557, "count": 1, "min": 0.013257740079757557, "max": 0.013257740079757557}}}
# [02/05/2022 03:34:37 INFO 140328909731648] #quality_metric: host=algo-1, epoch=14, train binary_classification_cross_entropy_objective <loss>=0.004796242649830766
# [02/05/2022 03:34:37 INFO 140328909731648] #early_stopping_criteria_metric: host=algo-1, epoch=14, criteria=binary_classification_cross_entropy_objective, value=0.0040303359740044
# [02/05/2022 03:34:37 INFO 140328909731648] Epoch 14: Loss improved. Updating best model
# [02/05/2022 03:34:37 INFO 140328909731648] Saving model for epoch: 14
# [02/05/2022 03:34:37 INFO 140328909731648] Saved checkpoint to "/tmp/tmpb4xh9t9u/mx-mod-0000.params"
# [02/05/2022 03:34:37 INFO 140328909731648] #progress_metric: host=algo-1, completed 100.0 % of epochs
# #metrics {"StartTime": 1644032071.4172516, "EndTime": 1644032077.3272464, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 3002460.0, "count": 1, "min": 3002460, "max": 3002460}, "Total Batches Seen": {"sum": 3012.0, "count": 1, "min": 3012, "max": 3012}, "Max Records Seen Between Resets": {"sum": 199364.0, "count": 1, "min": 199364, "max": 199364}, "Max Batches Seen Between Resets": {"sum": 200.0, "count": 1, "min": 200, "max": 200}, "Reset Count": {"sum": 17.0, "count": 1, "min": 17, "max": 17}, "Number of Records Since Last Reset": {"sum": 199364.0, "count": 1, "min": 199364, "max": 199364}, "Number of Batches Since Last Reset": {"sum": 200.0, "count": 1, "min": 200, "max": 200}}}
# [02/05/2022 03:34:37 INFO 140328909731648] #throughput_metric: host=algo-1, train throughput=33732.538122817044 records/second
# [02/05/2022 03:34:37 WARNING 140328909731648] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [02/05/2022 03:34:37 WARNING 140328909731648] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [2022-02-05 03:34:37.331] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 33, "duration": 3, "num_examples": 1, "num_bytes": 168000}
# [2022-02-05 03:34:37.807] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 36, "duration": 474, "num_examples": 200, "num_bytes": 33493152}
# [2022-02-05 03:34:38.608] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 38, "duration": 731, "num_examples": 200, "num_bytes": 33493152}
# [02/05/2022 03:34:38 INFO 140328909731648] #train_score (algo-1) : ('binary_classification_cross_entropy_objective', 0.003960911865313041)
# [02/05/2022 03:34:38 INFO 140328909731648] #train_score (algo-1) : ('binary_classification_accuracy', 0.9992827190465681)
# [02/05/2022 03:34:38 INFO 140328909731648] #train_score (algo-1) : ('binary_f_1.000', 0.7971631205673759)
# [02/05/2022 03:34:38 INFO 140328909731648] #train_score (algo-1) : ('precision', 0.8074712643678161)
# [02/05/2022 03:34:38 INFO 140328909731648] #train_score (algo-1) : ('recall', 0.7871148459383753)
# [02/05/2022 03:34:38 INFO 140328909731648] #train_score (algo-1) : ('roc_auc_score', 0.9790894705377465)
# [02/05/2022 03:34:38 INFO 140328909731648] #train_score (algo-1) : ('binary_balanced_accuracy', 0.5)
# [02/05/2022 03:34:38 INFO 140328909731648] #train_score (algo-1) : ('binary_log_loss', 0.6930574032138126)
# [02/05/2022 03:34:38 INFO 140328909731648] #quality_metric: host=algo-1, train binary_classification_cross_entropy_objective <loss>=0.003960911865313041
# [02/05/2022 03:34:38 INFO 140328909731648] #quality_metric: host=algo-1, train binary_classification_accuracy <score>=0.9992827190465681
# [02/05/2022 03:34:38 INFO 140328909731648] #quality_metric: host=algo-1, train binary_f_1.000 <score>=0.7971631205673759
# [02/05/2022 03:34:38 INFO 140328909731648] #quality_metric: host=algo-1, train precision <score>=0.8074712643678161
# [02/05/2022 03:34:38 INFO 140328909731648] #quality_metric: host=algo-1, train recall <score>=0.7871148459383753
# [02/05/2022 03:34:38 INFO 140328909731648] #quality_metric: host=algo-1, train roc_auc_score <score>=0.9790894705377465
# [02/05/2022 03:34:38 INFO 140328909731648] #quality_metric: host=algo-1, train binary_balanced_accuracy <score>=0.5
# [02/05/2022 03:34:38 INFO 140328909731648] #quality_metric: host=algo-1, train binary_log_loss <score>=0.6930574032138126
# [02/05/2022 03:34:38 INFO 140328909731648] Best model found for hyperparameters: {"optimizer": "adam", "learning_rate": 0.1, "wd": 0.0001, "l1": 0.0, "lr_scheduler_step": 10, "lr_scheduler_factor": 0.99, "lr_scheduler_minimum_lr": 1e-05}
# [02/05/2022 03:34:38 INFO 140328909731648] Saved checkpoint to "/tmp/tmpltb5e4hi/mx-mod-0000.params"
# [02/05/2022 03:34:38 INFO 140328909731648] Test data is not provided.
# #metrics {"StartTime": 1644031979.5330727, "EndTime": 1644032078.8837578, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training"}, "Metrics": {"initialize.time": {"sum": 238.85154724121094, "count": 1, "min": 238.85154724121094, "max": 238.85154724121094}, "epochs": {"sum": 15.0, "count": 1, "min": 15, "max": 15}, "check_early_stopping.time": {"sum": 13.677120208740234, "count": 15, "min": 0.8087158203125, "max": 0.9794235229492188}, "update.time": {"sum": 97491.6262626648, "count": 15, "min": 5907.365560531616, "max": 7005.594491958618}, "finalize.time": {"sum": 1551.0191917419434, "count": 1, "min": 1551.0191917419434, "max": 1551.0191917419434}, "setuptime": {"sum": 25.261878967285156, "count": 1, "min": 25.261878967285156, "max": 25.261878967285156}, "totaltime": {"sum": 99622.14303016663, "count": 1, "min": 99622.14303016663, "max": 99622.14303016663}}}
#
# 2022-02-05 03:35:04 Uploading - Uploading generated training model
# 2022-02-05 03:35:04 Completed - Training job completed
# ProfilerReport-1644031771: NoIssuesFound
# Training seconds: 140
# Billable seconds: 140
# CPU times: user 836 ms, sys: 38.2 ms, total: 874 ms
# Wall time: 5min 44s

# %% [markdown]
# ### EXERCISE: Deploy the trained model
#
# Deploy your model to create a predictor. We'll use this to make predictions on our test data and evaluate the model.

# %%
# %%time 
# deploy and create a predictor
linear_predictor = lin_SM.deploy(initial_instance_count=1,
                                 instance_type='ml.t2.medium')
# Out:
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# -----------!CPU times: user 197 ms, sys: 8.78 ms, total: 206 ms
# Wall time: 5min 31s

# %% [markdown]
# ---
# # Evaluating Your Model
#
# Once your model is deployed, you can see how it performs when applied to the test data.
#
# According to the deployed [predictor documentation](https://sagemaker.readthedocs.io/en/stable/linear_learner.html#sagemaker.LinearLearnerPredictor), this predictor expects an `ndarray` of input features and returns a list of Records.
# > "The prediction is stored in the "predicted_label" key of the `Record.label` field."
#
# Let's first test our model on just one test point, to see the resulting list.

# %%
# test one prediction
test_x_np = test_features.values.astype('float32')
result = linear_predictor.predict(test_x_np[0])

print(result)
# Out:
# [label {
#   key: "predicted_label"
#   value {
#     float32_tensor {
#       values: 0.0
#     }
#   }
# }
# label {
#   key: "score"
#   value {
#     float32_tensor {
#       values: 0.0002751190622802824
#     }
#   }
# }
# ]

# %% [markdown]
# ### Helper function for evaluation
#
#
# The provided function below, takes in a deployed predictor, some test features and labels, and returns a dictionary of metrics; calculating false negatives and positives as well as recall, precision, and accuracy.

# %%
# code to evaluate the endpoint on test data
# returns a variety of model metrics
def evaluate(predictor, test_features, test_labels, verbose=True):
    """
    Evaluate a model on a test set given the prediction endpoint.  
    Return binary classification metrics.
    :param predictor: A prediction endpoint
    :param test_features: Test features
    :param test_labels: Class labels for test data
    :param verbose: If True, prints a table of all performance metrics
    :return: A dictionary of performance metrics.
    """
    
    # We have a lot of test data, so we'll split it into batches of 100
    # split the test data set into batches and evaluate using prediction endpoint    
    prediction_batches = [predictor.predict(batch) for batch in np.array_split(test_features, 100)]
    
    # LinearLearner produces a `predicted_label` for each data point in a batch
    # get the 'predicted_label' for every point in a batch
    test_preds = np.concatenate([np.array([x.label['predicted_label'].float32_tensor.values[0] for x in batch]) 
                                 for batch in prediction_batches])
    
    # calculate true positives, false positives, true negatives, false negatives
    tp = np.logical_and(test_labels, test_preds).sum()
    fp = np.logical_and(1-test_labels, test_preds).sum()
    tn = np.logical_and(1-test_labels, 1-test_preds).sum()
    fn = np.logical_and(test_labels, 1-test_preds).sum()
    
    # calculate binary classification metrics
    recall = tp / (tp + fn)
    precision = tp / (tp + fp)
    accuracy = (tp + tn) / (tp + fp + tn + fn)
    
    # printing a table of metrics
    if verbose:
        print(pd.crosstab(test_labels, test_preds, rownames=['actual (row)'], colnames=['prediction (col)']))
        print("\n{:<11} {:.3f}".format('Recall:', recall))
        print("{:<11} {:.3f}".format('Precision:', precision))
        print("{:<11} {:.3f}".format('Accuracy:', accuracy))
        print()
        
    return {'TP': tp, 'FP': fp, 'FN': fn, 'TN': tn, 
            'Precision': precision, 'Recall': recall, 'Accuracy': accuracy}

# %% [markdown]
# ### Test Results
#
# The cell below runs the `evaluate` function.
#
# The code assumes that you have a defined `predictor` and `test_features` and `test_labels` from previously-run cells.

# %%
print('Metrics for simple, LinearLearner.\n')

# get metrics for linear predictor
metrics = evaluate(linear_predictor, 
                   test_features.values.astype('float32'), 
                   test_labels, 
                   verbose=True) # verbose means we'll print out the metrics
# Out:
# Metrics for simple, LinearLearner.
#
# prediction (col)    0.0  1.0
# actual (row)
# 0                 85282   26
# 1                    36   99
#
# Recall:     0.733
# Precision:  0.792
# Accuracy:   0.999

# %% [markdown]
# ## Delete the Endpoint
#
# I've added a convenience function to delete prediction endpoints after we're done with them. And if you're done evaluating the model, you should delete your model endpoint!

# %%
# Deletes a precictor.endpoint
def delete_endpoint(predictor):
        try:
            boto3.client('sagemaker').delete_endpoint(EndpointName=predictor.endpoint)
            print('Deleted {}'.format(predictor.endpoint))
        except:
            print('Already deleted: {}'.format(predictor.endpoint))

# %%
# delete the predictor endpoint 
delete_endpoint(linear_predictor)
# Out:
# The endpoint attribute has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The endpoint attribute has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# Deleted linear-learner-2022-02-05-03-35-15-670

# %% [markdown]
# ---
#
# # Model Improvements
#
# The default LinearLearner got a high accuracy, but still classified fraudulent and valid data points incorrectly. Specifically classifying more than 30 points as false negatives (incorrectly labeled, fraudulent transactions), and a little over 30 points as false positives (incorrectly labeled, valid transactions). Let's think about what, during training, could cause this behavior and what we could improve.
#
# **1. Model optimization**
# * If we imagine that we are designing this model for use in a bank application, we know that users do *not* want any valid transactions to be categorized as fraudulent. That is, we want to have as few **false positives** (0s classified as 1s) as possible.
# * On the other hand, if our bank manager asks for an application that will catch almost *all* cases of fraud, even if it means a higher number of false positives, then we'd want as few **false negatives** as possible.
# * To train according to specific product demands and goals, we do not want to optimize for accuracy only. Instead, we want to optimize for a metric that can help us decrease the number of false positives or negatives.
#
# <img src='notebook_ims/precision_recall.png' width=40% />
#
# In this notebook, we'll look at different cases for tuning a model and make an optimization decision, accordingly.
#
# **2. Imbalanced training data**
# * At the start of this notebook, we saw that only about 0.17% of the training data was labeled as fraudulent. So, even if a model labels **all** of our data as valid, it will still have a high accuracy.
# * This may result in some overfitting towards valid data, which accounts for some **false negatives**; cases in which fraudulent data (1) is incorrectly characterized as valid (0).
#
# So, let's address these issues in order; first, tuning our model and optimizing for a specific metric during training, and second, accounting for class imbalance in the training set.

# %% [markdown]
# ## Improvement: Model Tuning
#
# Optimizing according to a specific metric is called **model tuning**, and SageMaker provides a number of ways to automatically tune a model.
#
#
# ### Create a LinearLearner and tune for higher precision
#
# **Scenario:**
# * A bank has asked you to build a model that detects cases of fraud with an accuracy of about 85%.
#
# In this case, we want to build a model that has as many true positives and as few false negatives, as possible. This corresponds to a model with a high **recall**: true positives / (true positives + false negatives).
#
# To aim for a specific metric, LinearLearner offers the hyperparameter `binary_classifier_model_selection_criteria`, which is the model evaluation criteria for the training dataset. A reference to this parameter is in [LinearLearner's documentation](https://sagemaker.readthedocs.io/en/stable/linear_learner.html#sagemaker.LinearLearner). We'll also have to further specify the exact value we want to aim for; read more about the details of the parameters, [here](https://docs.aws.amazon.com/sagemaker/latest/dg/ll_hyperparameters.html).
#
# I will assume that performance on a training set will be within about 5% of the performance on a test set. So, for a recall of about 85%, I'll aim for a bit higher, 90%.

# %%
# instantiate a LinearLearner
# tune the model for a higher recall
linear_recall = LinearLearner(role=role,
                              train_instance_count=1, 
                              train_instance_type='ml.c4.xlarge',
                              predictor_type='binary_classifier',
                              output_path=output_path,
                              sagemaker_session=sagemaker_session,
                              epochs=15,
                              binary_classifier_model_selection_criteria='precision_at_target_recall', # target recall
                              target_recall=0.9) # 90% recall
# Out:
# train_instance_count has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# train_instance_type has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.

# %% [markdown]
# ### Train the tuned estimator
#
# Fit the new, tuned estimator on the formatted training data.

# %%
# %%time 
# train the estimator on formatted training data
linear_recall.fit(formatted_train_data)
# Out:
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# 2022-02-05 03:40:57 Starting - Starting the training job...
# 2022-02-05 03:41:13 Starting - Preparing the instances for trainingProfilerReport-1644032457: InProgress
# .........
# 2022-02-05 03:42:55 Downloading - Downloading input data...
# 2022-02-05 03:43:17 Training - Training image download completed. Training in progress..Docker entrypoint called with argument(s): train
# Running default environment configuration script
# [02/05/2022 03:43:24 INFO 140573160814400 integration.py:636] worker started
# [02/05/2022 03:43:24 INFO 140573160814400] Reading default configuration from /opt/amazon/lib/python3.7/site-packages/algorithm/resources/default-input.json: {'mini_batch_size': '1000', 'epochs': '15', 'feature_dim': 'auto', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'accuracy', 'f_beta': '1.0', 'target_recall': '0.8', 'target_precision': '0.8', 'num_models': 'auto', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'auto', 'loss': 'auto', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '1', 'accuracy_top_k': '3', 'wd': 'auto', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': 'auto', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': 'auto', 'lr_scheduler_factor': 'auto', 'lr_scheduler_minimum_lr': 'auto', 'positive_example_weight_mult': '1.0', 'balance_multiclass_weights': 'false', 'normalize_data': 'true', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false'}
# [02/05/2022 03:43:24 INFO 140573160814400] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {'binary_classifier_model_selection_criteria': 'precision_at_target_recall', 'epochs': '15', 'feature_dim': '30', 'mini_batch_size': '1000', 'predictor_type': 'binary_classifier', 'target_recall': '0.9'}
# [02/05/2022 03:43:24 INFO 140573160814400] Final configuration: {'mini_batch_size': '1000', 'epochs': '15', 'feature_dim': '30', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'precision_at_target_recall', 'f_beta': '1.0', 'target_recall': '0.9', 'target_precision': '0.8', 'num_models': 'auto', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'auto', 'loss': 'auto', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '1', 'accuracy_top_k': '3', 'wd': 'auto', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': 'auto', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': 'auto', 'lr_scheduler_factor': 'auto', 'lr_scheduler_minimum_lr': 'auto', 'positive_example_weight_mult': '1.0', 'balance_multiclass_weights': 'false', 'normalize_data': 'true', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false', 'predictor_type': 'binary_classifier'}
# [02/05/2022 03:43:24 WARNING 140573160814400] Loggers have already been setup.
# Process 1 is a worker.
# [02/05/2022 03:43:24 INFO 140573160814400] Using default worker.
# [02/05/2022 03:43:24 INFO 140573160814400] Checkpoint loading and saving are disabled.
# [2022-02-05 03:43:24.740] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration": 31, "num_examples": 1, "num_bytes": 168000}
# [02/05/2022 03:43:24 INFO 140573160814400] Create Store: local
# [2022-02-05 03:43:24.833] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 1, "duration": 91, "num_examples": 11, "num_bytes": 1848000}
# [02/05/2022 03:43:24 INFO 140573160814400] Scaler algorithm parameters
#  <algorithm.scaler.ScalerAlgorithmStable object at 0x7fd965c5c050>
# [02/05/2022 03:43:24 INFO 140573160814400] Scaling model computed with parameters:
#  {'stdev_label': None, 'stdev_weight':
# [4.7823008e+04 1.8987731e+00 1.5821997e+00 1.5291911e+00 1.4364978e+00
#  1.3388461e+00 1.2955806e+00 1.1771069e+00 1.2127448e+00 1.0843055e+00
#  1.0475702e+00 1.0230465e+00 1.0090139e+00 1.0057642e+00 9.5122164e-01
#  9.2613727e-01 8.7072927e-01 8.6057234e-01 8.3151484e-01 8.2762748e-01
#  7.1313608e-01 7.3347980e-01 7.2524083e-01 5.6213826e-01 6.0201687e-01
#  5.1174247e-01 4.8000538e-01 3.7595215e-01 2.7081874e-01 2.3656270e+02]
# <NDArray 30 @cpu(0)>, 'mean_label': None, 'mean_weight':
# [ 9.4275984e+04 -1.7378727e-02  1.5538026e-02  2.5005125e-02
#   3.3166975e-02  1.8197566e-02  1.7799012e-03  6.9396999e-03
#   9.8540336e-03 -3.0757964e-02 -1.2736557e-02  4.0434714e-04
#  -1.4243029e-02  1.6704608e-02  2.2619881e-02 -9.6982103e-03
#  -4.7834702e-03 -1.6767335e-04 -9.0120723e-03 -3.0407687e-03
#   4.6031545e-03 -4.0078526e-03 -1.2586080e-04  1.2784966e-03
#   3.7617318e-03 -3.1254767e-03 -8.2200055e-04  3.4045519e-03
#  -1.0332187e-03  8.7559837e+01]
# <NDArray 30 @cpu(0)>}
# [02/05/2022 03:43:24 INFO 140573160814400] nvidia-smi: took 0.031 seconds to run.
# [02/05/2022 03:43:24 INFO 140573160814400] nvidia-smi identified 0 GPUs.
# [02/05/2022 03:43:24 INFO 140573160814400] Number of GPUs being used: 0
# #metrics {"StartTime": 1644032604.9806032, "EndTime": 1644032604.9806592, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "Meta": "init_train_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 12000.0, "count": 1, "min": 12000, "max": 12000}, "Total Batches Seen": {"sum": 12.0, "count": 1, "min": 12, "max": 12}, "Max Records Seen Between Resets": {"sum": 11000.0, "count": 1, "min": 11000, "max": 11000}, "Max Batches Seen Between Resets": {"sum": 11.0, "count": 1, "min": 11, "max": 11}, "Reset Count": {"sum": 2.0, "count": 1, "min": 2, "max": 2}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [2022-02-05 03:43:32.713] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 3, "duration": 7732, "num_examples": 200, "num_bytes": 33493152}
# #metrics {"StartTime": 1644032612.7134697, "EndTime": 1644032612.713569, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 0}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.12023840661743777, "count": 1, "min": 0.12023840661743777, "max": 0.12023840661743777}}}
# #metrics {"StartTime": 1644032612.7136583, "EndTime": 1644032612.7136796, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 1}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.1175625283514435, "count": 1, "min": 0.1175625283514435, "max": 0.1175625283514435}}}
# #metrics {"StartTime": 1644032612.7137384, "EndTime": 1644032612.713755, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 2}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.12012009677216036, "count": 1, "min": 0.12012009677216036, "max": 0.12012009677216036}}}
# #metrics {"StartTime": 1644032612.713805, "EndTime": 1644032612.7138221, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 3}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.11766779350395777, "count": 1, "min": 0.11766779350395777, "max": 0.11766779350395777}}}
# #metrics {"StartTime": 1644032612.7138753, "EndTime": 1644032612.7138917, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 4}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.012220082102483841, "count": 1, "min": 0.012220082102483841, "max": 0.012220082102483841}}}
# #metrics {"StartTime": 1644032612.7139444, "EndTime": 1644032612.7139606, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 5}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.012175582823441855, "count": 1, "min": 0.012175582823441855, "max": 0.012175582823441855}}}
# #metrics {"StartTime": 1644032612.7140129, "EndTime": 1644032612.714029, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 6}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.012201707582415348, "count": 1, "min": 0.012201707582415348, "max": 0.012201707582415348}}}
# #metrics {"StartTime": 1644032612.7140815, "EndTime": 1644032612.7140977, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 7}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.012345536659747811, "count": 1, "min": 0.012345536659747811, "max": 0.012345536659747811}}}
# #metrics {"StartTime": 1644032612.714158, "EndTime": 1644032612.7141743, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 8}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.12014251477035445, "count": 1, "min": 0.12014251477035445, "max": 0.12014251477035445}}}
# #metrics {"StartTime": 1644032612.7142246, "EndTime": 1644032612.7142413, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 9}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.11776210052643589, "count": 1, "min": 0.11776210052643589, "max": 0.11776210052643589}}}
# #metrics {"StartTime": 1644032612.714292, "EndTime": 1644032612.714307, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 10}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.12038165889912514, "count": 1, "min": 0.12038165889912514, "max": 0.12038165889912514}}}
# #metrics {"StartTime": 1644032612.714358, "EndTime": 1644032612.714375, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 11}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.11770791634602762, "count": 1, "min": 0.11770791634602762, "max": 0.11770791634602762}}}
# #metrics {"StartTime": 1644032612.7144244, "EndTime": 1644032612.7144408, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 12}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.01261257816119185, "count": 1, "min": 0.01261257816119185, "max": 0.01261257816119185}}}
# #metrics {"StartTime": 1644032612.7144897, "EndTime": 1644032612.7145069, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 13}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.012488340938866289, "count": 1, "min": 0.012488340938866289, "max": 0.012488340938866289}}}
# #metrics {"StartTime": 1644032612.7145596, "EndTime": 1644032612.7145767, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 14}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.012396600667237486, "count": 1, "min": 0.012396600667237486, "max": 0.012396600667237486}}}
# #metrics {"StartTime": 1644032612.7146275, "EndTime": 1644032612.714644, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 15}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.012499406192096035, "count": 1, "min": 0.012499406192096035, "max": 0.012499406192096035}}}
# #metrics {"StartTime": 1644032612.7146971, "EndTime": 1644032612.7147138, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 16}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.1228250465488913, "count": 1, "min": 0.1228250465488913, "max": 0.1228250465488913}}}
# #metrics {"StartTime": 1644032612.7147665, "EndTime": 1644032612.7147837, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 17}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.12008383270723735, "count": 1, "min": 0.12008383270723735, "max": 0.12008383270723735}}}
# #metrics {"StartTime": 1644032612.7148354, "EndTime": 1644032612.7148523, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 18}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.12283358952507901, "count": 1, "min": 0.12283358952507901, "max": 0.12283358952507901}}}
# #metrics {"StartTime": 1644032612.7149134, "EndTime": 1644032612.71493, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 19}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.12025850340109974, "count": 1, "min": 0.12025850340109974, "max": 0.12025850340109974}}}
# #metrics {"StartTime": 1644032612.714983, "EndTime": 1644032612.7149985, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 20}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.019943902858238126, "count": 1, "min": 0.019943902858238126, "max": 0.019943902858238126}}}
# #metrics {"StartTime": 1644032612.715059, "EndTime": 1644032612.7150774, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 21}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.01993385848758658, "count": 1, "min": 0.01993385848758658, "max": 0.01993385848758658}}}
# #metrics {"StartTime": 1644032612.7151656, "EndTime": 1644032612.7151859, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 22}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.019987651391170133, "count": 1, "min": 0.019987651391170133, "max": 0.019987651391170133}}}
# #metrics {"StartTime": 1644032612.7152598, "EndTime": 1644032612.7152755, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 23}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.01984426697302404, "count": 1, "min": 0.01984426697302404, "max": 0.01984426697302404}}}
# #metrics {"StartTime": 1644032612.7153354, "EndTime": 1644032612.7153516, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 24}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.12367208990739219, "count": 1, "min": 0.12367208990739219, "max": 0.12367208990739219}}}
# #metrics {"StartTime": 1644032612.7154105, "EndTime": 1644032612.7154264, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 25}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.12108522349985401, "count": 1, "min": 0.12108522349985401, "max": 0.12108522349985401}}}
# #metrics {"StartTime": 1644032612.7154863, "EndTime": 1644032612.7155042, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 26}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.12374423226399638, "count": 1, "min": 0.12374423226399638, "max": 0.12374423226399638}}}
# #metrics {"StartTime": 1644032612.715558, "EndTime": 1644032612.7155738, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 27}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.12116944918800239, "count": 1, "min": 0.12116944918800239, "max": 0.12116944918800239}}}
# #metrics {"StartTime": 1644032612.7156255, "EndTime": 1644032612.7156417, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 28}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.02103997616806821, "count": 1, "min": 0.02103997616806821, "max": 0.02103997616806821}}}
# #metrics {"StartTime": 1644032612.7156925, "EndTime": 1644032612.715709, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 29}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.020920196363487135, "count": 1, "min": 0.020920196363487135, "max": 0.020920196363487135}}}
# #metrics {"StartTime": 1644032612.7157626, "EndTime": 1644032612.715779, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 30}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.021012824348543756, "count": 1, "min": 0.021012824348543756, "max": 0.021012824348543756}}}
# #metrics {"StartTime": 1644032612.7158306, "EndTime": 1644032612.7158465, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 31}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.021031404245476327, "count": 1, "min": 0.021031404245476327, "max": 0.021031404245476327}}}
# [02/05/2022 03:43:32 INFO 140573160814400] #quality_metric: host=algo-1, epoch=0, train binary_classification_cross_entropy_objective <loss>=0.12023840661743777
# [02/05/2022 03:43:32 INFO 140573160814400] #early_stopping_criteria_metric: host=algo-1, epoch=0, criteria=binary_classification_cross_entropy_objective, value=0.012175582823441855
# [02/05/2022 03:43:32 INFO 140573160814400] Epoch 0: Loss improved. Updating best model
# [02/05/2022 03:43:32 INFO 140573160814400] Saving model for epoch: 0
# [02/05/2022 03:43:32 INFO 140573160814400] Saved checkpoint to "/tmp/tmpp62552l_/mx-mod-0000.params"
# [02/05/2022 03:43:32 INFO 140573160814400] #progress_metric: host=algo-1, completed 6.666666666666667 % of epochs
# #metrics {"StartTime": 1644032604.9809608, "EndTime": 1644032612.730748, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 211364.0, "count": 1, "min": 211364, "max": 211364}, "Total Batches Seen": {"sum": 212.0, "count": 1, "min": 212, "max": 212}, "Max Records Seen Between Resets": {"sum": 199364.0, "count": 1, "min": 199364, "max": 199364}, "Max Batches Seen Between Resets": {"sum": 200.0, "count": 1, "min": 200, "max": 200}, "Reset Count": {"sum": 3.0, "count": 1, "min": 3, "max": 3}, "Number of Records Since Last Reset": {"sum": 199364.0, "count": 1, "min": 199364, "max": 199364}, "Number of Batches Since Last Reset": {"sum": 200.0, "count": 1, "min": 200, "max": 200}}}
# [02/05/2022 03:43:32 INFO 140573160814400] #throughput_metric: host=algo-1, train throughput=25724.498681416484 records/second
# [2022-02-05 03:43:41.004] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 5, "duration": 8271, "num_examples": 200, "num_bytes": 33493152}
# #metrics {"StartTime": 1644032621.0047495, "EndTime": 1644032621.0048382, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 0}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.016883339575187645, "count": 1, "min": 0.016883339575187645, "max": 0.016883339575187645}}}
# #metrics {"StartTime": 1644032621.0049362, "EndTime": 1644032621.0049624, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 1}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.014893327607581363, "count": 1, "min": 0.014893327607581363, "max": 0.014893327607581363}}}
# #metrics {"StartTime": 1644032621.005025, "EndTime": 1644032621.005041, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 2}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.01687481061178236, "count": 1, "min": 0.01687481061178236, "max": 0.01687481061178236}}}
# #metrics {"StartTime": 1644032621.0050948, "EndTime": 1644032621.0051098, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 3}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.014889016120278056, "count": 1, "min": 0.014889016120278056, "max": 0.014889016120278056}}}
# #metrics {"StartTime": 1644032621.0051599, "EndTime": 1644032621.0051756, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 4}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.0054091289906046496, "count": 1, "min": 0.0054091289906046496, "max": 0.0054091289906046496}}}
# #metrics {"StartTime": 1644032621.0052257, "EndTime": 1644032621.0052402, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 5}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.0055940955086569094, "count": 1, "min": 0.0055940955086569094, "max": 0.0055940955086569094}}}
# #metrics {"StartTime": 1644032621.0052853, "EndTime": 1644032621.005299, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 6}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.00551705657522283, "count": 1, "min": 0.00551705657522283, "max": 0.00551705657522283}}}
# #metrics {"StartTime": 1644032621.0053575, "EndTime": 1644032621.0053728, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 7}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.005566651671825342, "count": 1, "min": 0.005566651671825342, "max": 0.005566651671825342}}}
# #metrics {"StartTime": 1644032621.0054255, "EndTime": 1644032621.0054412, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 8}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.0170403941312627, "count": 1, "min": 0.0170403941312627, "max": 0.0170403941312627}}}
# #metrics {"StartTime": 1644032621.0054915, "EndTime": 1644032621.005508, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 9}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.015086053342675444, "count": 1, "min": 0.015086053342675444, "max": 0.015086053342675444}}}
# #metrics {"StartTime": 1644032621.005557, "EndTime": 1644032621.005572, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 10}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.017052275235928484, "count": 1, "min": 0.017052275235928484, "max": 0.017052275235928484}}}
# #metrics {"StartTime": 1644032621.0056212, "EndTime": 1644032621.0056372, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 11}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.015078012080647837, "count": 1, "min": 0.015078012080647837, "max": 0.015078012080647837}}}
# #metrics {"StartTime": 1644032621.005676, "EndTime": 1644032621.0056906, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 12}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.005623061710715893, "count": 1, "min": 0.005623061710715893, "max": 0.005623061710715893}}}
# #metrics {"StartTime": 1644032621.0057378, "EndTime": 1644032621.0057526, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 13}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.005685889098512468, "count": 1, "min": 0.005685889098512468, "max": 0.005685889098512468}}}
# #metrics {"StartTime": 1644032621.005798, "EndTime": 1644032621.0058124, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 14}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.005619973746376421, "count": 1, "min": 0.005619973746376421, "max": 0.005619973746376421}}}
# #metrics {"StartTime": 1644032621.005861, "EndTime": 1644032621.0058773, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 15}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.005672148302122576, "count": 1, "min": 0.005672148302122576, "max": 0.005672148302122576}}}
# #metrics {"StartTime": 1644032621.005937, "EndTime": 1644032621.005954, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 16}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.02126987413665158, "count": 1, "min": 0.02126987413665158, "max": 0.02126987413665158}}}
# #metrics {"StartTime": 1644032621.0060058, "EndTime": 1644032621.0060227, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 17}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.019476390440859387, "count": 1, "min": 0.019476390440859387, "max": 0.019476390440859387}}}
# #metrics {"StartTime": 1644032621.0060768, "EndTime": 1644032621.0060933, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 18}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.02127108111932649, "count": 1, "min": 0.02127108111932649, "max": 0.02127108111932649}}}
# #metrics {"StartTime": 1644032621.006144, "EndTime": 1644032621.0061593, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 19}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.01948852028679009, "count": 1, "min": 0.01948852028679009, "max": 0.01948852028679009}}}
# #metrics {"StartTime": 1644032621.0062065, "EndTime": 1644032621.0062203, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 20}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.012074755899271174, "count": 1, "min": 0.012074755899271174, "max": 0.012074755899271174}}}
# #metrics {"StartTime": 1644032621.0062613, "EndTime": 1644032621.0062754, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 21}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.012111119604589951, "count": 1, "min": 0.012111119604589951, "max": 0.012111119604589951}}}
# #metrics {"StartTime": 1644032621.0063329, "EndTime": 1644032621.0063515, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 22}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.01207915733866955, "count": 1, "min": 0.01207915733866955, "max": 0.01207915733866955}}}
# #metrics {"StartTime": 1644032621.006411, "EndTime": 1644032621.0064263, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 23}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.01210820182843424, "count": 1, "min": 0.01210820182843424, "max": 0.01210820182843424}}}
# #metrics {"StartTime": 1644032621.0064769, "EndTime": 1644032621.0064914, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 24}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.022298133768627992, "count": 1, "min": 0.022298133768627992, "max": 0.022298133768627992}}}
# #metrics {"StartTime": 1644032621.006539, "EndTime": 1644032621.0065532, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 25}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.020528922866936306, "count": 1, "min": 0.020528922866936306, "max": 0.020528922866936306}}}
# #metrics {"StartTime": 1644032621.0066, "EndTime": 1644032621.0066156, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 26}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.022301760285343957, "count": 1, "min": 0.022301760285343957, "max": 0.022301760285343957}}}
# #metrics {"StartTime": 1644032621.0066648, "EndTime": 1644032621.0066798, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 27}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.020534939981585173, "count": 1, "min": 0.020534939981585173, "max": 0.020534939981585173}}}
# #metrics {"StartTime": 1644032621.0067103, "EndTime": 1644032621.006718, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 28}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.01314413232719479, "count": 1, "min": 0.01314413232719479, "max": 0.01314413232719479}}}
# #metrics {"StartTime": 1644032621.0067415, "EndTime": 1644032621.0067487, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 29}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.013147845992490874, "count": 1, "min": 0.013147845992490874, "max": 0.013147845992490874}}}
# #metrics {"StartTime": 1644032621.006771, "EndTime": 1644032621.0067785, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 30}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.013144269559251603, "count": 1, "min": 0.013144269559251603, "max": 0.013144269559251603}}}
# #metrics {"StartTime": 1644032621.006823, "EndTime": 1644032621.0068383, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 31}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.013148174486567627, "count": 1, "min": 0.013148174486567627, "max": 0.013148174486567627}}}
# [02/05/2022 03:43:41 INFO 140573160814400] #quality_metric: host=algo-1, epoch=1, train binary_classification_cross_entropy_objective <loss>=0.016883339575187645
# [02/05/2022 03:43:41 INFO 140573160814400] #early_stopping_criteria_metric: host=algo-1, epoch=1, criteria=binary_classification_cross_entropy_objective, value=0.0054091289906046496
# [02/05/2022 03:43:41 INFO 140573160814400] Epoch 1: Loss improved. Updating best model
# [02/05/2022 03:43:41 INFO 140573160814400] Saving model for epoch: 1
# [02/05/2022 03:43:41 INFO 140573160814400] Saved checkpoint to "/tmp/tmpwpt46q7f/mx-mod-0000.params"
# [02/05/2022 03:43:41 INFO 140573160814400] #progress_metric: host=algo-1, completed 13.333333333333334 % of epochs
# #metrics {"StartTime": 1644032612.732806, "EndTime": 1644032621.0173252, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 410728.0, "count": 1, "min": 410728, "max": 410728}, "Total Batches Seen": {"sum": 412.0, "count": 1, "min": 412, "max": 412}, "Max Records Seen Between Resets": {"sum": 199364.0, "count": 1, "min": 199364, "max": 199364}, "Max Batches Seen Between Resets": {"sum": 200.0, "count": 1, "min": 200, "max": 200}, "Reset Count": {"sum": 4.0, "count": 1, "min": 4, "max": 4}, "Number of Records Since Last Reset": {"sum": 199364.0, "count": 1, "min": 199364, "max": 199364}, "Number of Batches Since Last Reset": {"sum": 200.0, "count": 1, "min": 200, "max": 200}}}
# [02/05/2022 03:43:41 INFO 140573160814400] #throughput_metric: host=algo-1, train throughput=24064.214003678786 records/second
# [2022-02-05 03:43:48.922] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 7, "duration": 7904, "num_examples": 200, "num_bytes": 33493152}
# #metrics {"StartTime": 1644032628.9225497, "EndTime": 1644032628.9226453, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 0}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.010249469512671083, "count": 1, "min": 0.010249469512671083, "max": 0.010249469512671083}}}
# #metrics {"StartTime": 1644032628.9227457, "EndTime": 1644032628.9227676, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 1}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.008671593309047832, "count": 1, "min": 0.008671593309047832, "max": 0.008671593309047832}}}
# #metrics {"StartTime": 1644032628.9228282, "EndTime": 1644032628.9228463, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 2}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.010244108916527063, "count": 1, "min": 0.010244108916527063, "max": 0.010244108916527063}}}
# #metrics {"StartTime": 1644032628.9228988, "EndTime": 1644032628.9229136, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 3}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.00867205645930228, "count": 1, "min": 0.00867205645930228, "max": 0.00867205645930228}}}
# #metrics {"StartTime": 1644032628.9229615, "EndTime": 1644032628.9229758, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 4}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.004918119081076066, "count": 1, "min": 0.004918119081076066, "max": 0.004918119081076066}}}
# #metrics {"StartTime": 1644032628.9230244, "EndTime": 1644032628.923039, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 5}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.005651303291320801, "count": 1, "min": 0.005651303291320801, "max": 0.005651303291320801}}}
# #metrics {"StartTime": 1644032628.923091, "EndTime": 1644032628.9231052, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 6}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.0049273479259643125, "count": 1, "min": 0.0049273479259643125, "max": 0.0049273479259643125}}}
# #metrics {"StartTime": 1644032628.923189, "EndTime": 1644032628.9232075, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 7}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.005490868361226878, "count": 1, "min": 0.005490868361226878, "max": 0.005490868361226878}}}
# #metrics {"StartTime": 1644032628.9232602, "EndTime": 1644032628.9232757, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 8}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.010515944255656334, "count": 1, "min": 0.010515944255656334, "max": 0.010515944255656334}}}
# #metrics {"StartTime": 1644032628.9233413, "EndTime": 1644032628.9233575, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 9}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.009003221483086821, "count": 1, "min": 0.009003221483086821, "max": 0.009003221483086821}}}
# #metrics {"StartTime": 1644032628.9234061, "EndTime": 1644032628.9234216, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 10}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.010521823832737141, "count": 1, "min": 0.010521823832737141, "max": 0.010521823832737141}}}
# #metrics {"StartTime": 1644032628.92347, "EndTime": 1644032628.9234846, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 11}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.008999888767549142, "count": 1, "min": 0.008999888767549142, "max": 0.008999888767549142}}}
# #metrics {"StartTime": 1644032628.9235363, "EndTime": 1644032628.9235547, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 12}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.005593623910117988, "count": 1, "min": 0.005593623910117988, "max": 0.005593623910117988}}}
# #metrics {"StartTime": 1644032628.9236057, "EndTime": 1644032628.923621, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 13}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.005721277174338624, "count": 1, "min": 0.005721277174338624, "max": 0.005721277174338624}}}
# #metrics {"StartTime": 1644032628.923677, "EndTime": 1644032628.923694, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 14}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.005546630558656089, "count": 1, "min": 0.005546630558656089, "max": 0.005546630558656089}}}
# #metrics {"StartTime": 1644032628.923742, "EndTime": 1644032628.923757, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 15}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.005712993024581641, "count": 1, "min": 0.005712993024581641, "max": 0.005712993024581641}}}
# #metrics {"StartTime": 1644032628.9238002, "EndTime": 1644032628.9238148, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 16}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.015533093172102119, "count": 1, "min": 0.015533093172102119, "max": 0.015533093172102119}}}
# #metrics {"StartTime": 1644032628.9238584, "EndTime": 1644032628.9238708, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 17}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.0142904183541111, "count": 1, "min": 0.0142904183541111, "max": 0.0142904183541111}}}
# #metrics {"StartTime": 1644032628.9239619, "EndTime": 1644032628.9239872, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 18}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.01553408638556399, "count": 1, "min": 0.01553408638556399, "max": 0.01553408638556399}}}
# #metrics {"StartTime": 1644032628.924046, "EndTime": 1644032628.9240608, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 19}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.014295967495022108, "count": 1, "min": 0.014295967495022108, "max": 0.014295967495022108}}}
# #metrics {"StartTime": 1644032628.924109, "EndTime": 1644032628.9241233, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 20}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.012072144002171617, "count": 1, "min": 0.012072144002171617, "max": 0.012072144002171617}}}
# #metrics {"StartTime": 1644032628.9241686, "EndTime": 1644032628.9241788, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 21}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.0121305170963757, "count": 1, "min": 0.0121305170963757, "max": 0.0121305170963757}}}
# #metrics {"StartTime": 1644032628.924216, "EndTime": 1644032628.9242306, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 22}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.012072037987373583, "count": 1, "min": 0.012072037987373583, "max": 0.012072037987373583}}}
# #metrics {"StartTime": 1644032628.9242864, "EndTime": 1644032628.9243019, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 23}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.012126008991021007, "count": 1, "min": 0.012126008991021007, "max": 0.012126008991021007}}}
# #metrics {"StartTime": 1644032628.9243608, "EndTime": 1644032628.9243789, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 24}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.016575735899671238, "count": 1, "min": 0.016575735899671238, "max": 0.016575735899671238}}}
# #metrics {"StartTime": 1644032628.924428, "EndTime": 1644032628.924444, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 25}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.01536184029123891, "count": 1, "min": 0.01536184029123891, "max": 0.01536184029123891}}}
# #metrics {"StartTime": 1644032628.9244921, "EndTime": 1644032628.9245076, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 26}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.01657752835451059, "count": 1, "min": 0.01657752835451059, "max": 0.01657752835451059}}}
# #metrics {"StartTime": 1644032628.924553, "EndTime": 1644032628.9245682, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 27}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.01536392712712887, "count": 1, "min": 0.01536392712712887, "max": 0.01536392712712887}}}
# #metrics {"StartTime": 1644032628.9246187, "EndTime": 1644032628.9246352, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 28}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.013144806580327862, "count": 1, "min": 0.013144806580327862, "max": 0.013144806580327862}}}
# #metrics {"StartTime": 1644032628.924683, "EndTime": 1644032628.9246988, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 29}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.013156182020153832, "count": 1, "min": 0.013156182020153832, "max": 0.013156182020153832}}}
# #metrics {"StartTime": 1644032628.92475, "EndTime": 1644032628.924765, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 30}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.013145586877012972, "count": 1, "min": 0.013145586877012972, "max": 0.013145586877012972}}}
# #metrics {"StartTime": 1644032628.92482, "EndTime": 1644032628.9248369, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 31}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.01315547815998595, "count": 1, "min": 0.01315547815998595, "max": 0.01315547815998595}}}
# [02/05/2022 03:43:48 INFO 140573160814400] #quality_metric: host=algo-1, epoch=2, train binary_classification_cross_entropy_objective <loss>=0.010249469512671083
# [02/05/2022 03:43:48 INFO 140573160814400] #early_stopping_criteria_metric: host=algo-1, epoch=2, criteria=binary_classification_cross_entropy_objective, value=0.004918119081076066
# [02/05/2022 03:43:48 INFO 140573160814400] Epoch 2: Loss improved. Updating best model
# [02/05/2022 03:43:48 INFO 140573160814400] Saving model for epoch: 2
# [02/05/2022 03:43:48 INFO 140573160814400] Saved checkpoint to "/tmp/tmpuxios6_n/mx-mod-0000.params"
# [02/05/2022 03:43:48 INFO 140573160814400] #progress_metric: host=algo-1, completed 20.0 % of epochs
# #metrics {"StartTime": 1644032621.017631, "EndTime": 1644032628.9354043, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 610092.0, "count": 1, "min": 610092, "max": 610092}, "Total Batches Seen": {"sum": 612.0, "count": 1, "min": 612, "max": 612}, "Max Records Seen Between Resets": {"sum": 199364.0, "count": 1, "min": 199364, "max": 199364}, "Max Batches Seen Between Resets": {"sum": 200.0, "count": 1, "min": 200, "max": 200}, "Reset Count": {"sum": 5.0, "count": 1, "min": 5, "max": 5}, "Number of Records Since Last Reset": {"sum": 199364.0, "count": 1, "min": 199364, "max": 199364}, "Number of Batches Since Last Reset": {"sum": 200.0, "count": 1, "min": 200, "max": 200}}}
# [02/05/2022 03:43:48 INFO 140573160814400] #throughput_metric: host=algo-1, train throughput=25178.863297778516 records/second
# [2022-02-05 03:43:56.664] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 9, "duration": 7726, "num_examples": 200, "num_bytes": 33493152}
# #metrics {"StartTime": 1644032636.6646483, "EndTime": 1644032636.6647415, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 0}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.00796071047279703, "count": 1, "min": 0.00796071047279703, "max": 0.00796071047279703}}}
# #metrics {"StartTime": 1644032636.665129, "EndTime": 1644032636.6651604, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 1}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.0066089136300973555, "count": 1, "min": 0.0066089136300973555, "max": 0.0066089136300973555}}}
# #metrics {"StartTime": 1644032636.6654644, "EndTime": 1644032636.665483, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 2}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.007957086086273194, "count": 1, "min": 0.007957086086273194, "max": 0.007957086086273194}}}
# #metrics {"StartTime": 1644032636.6657686, "EndTime": 1644032636.665785, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 3}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.006610484449108642, "count": 1, "min": 0.006610484449108642, "max": 0.006610484449108642}}}
# ...
# #metrics {"StartTime": 1644032723.711766, "EndTime": 1644032723.7117836, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 5}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.005875211362862707, "count": 1, "min": 0.005875211362862707, "max": 0.005875211362862707}}}
# #metrics {"StartTime": 1644032723.7118351, "EndTime": 1644032723.7118523, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 6}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.00404278004139512, "count": 1, "min": 0.00404278004139512, "max": 0.00404278004139512}}}
# #metrics {"StartTime": 1644032723.711902, "EndTime": 1644032723.7119174, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 7}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.005471848284853763, "count": 1, "min": 0.005471848284853763, "max": 0.005471848284853763}}}
# #metrics {"StartTime": 1644032723.7119696, "EndTime": 1644032723.7119844, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 8}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.0055071240819279275, "count": 1, "min": 0.0055071240819279275, "max": 0.0055071240819279275}}}
# #metrics {"StartTime": 1644032723.7120368, "EndTime": 1644032723.7120512, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 9}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.005093599353004341, "count": 1, "min": 0.005093599353004341, "max": 0.005093599353004341}}}
# #metrics {"StartTime": 1644032723.7121022, "EndTime": 1644032723.712118, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 10}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.005507833725243956, "count": 1, "min": 0.005507833725243956, "max": 0.005507833725243956}}}
# #metrics {"StartTime": 1644032723.7121725, "EndTime": 1644032723.7121894, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 11}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.005093542199638022, "count": 1, "min": 0.005093542199638022, "max": 0.005093542199638022}}}
# #metrics {"StartTime": 1644032723.712244, "EndTime": 1644032723.7122617, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 12}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.0050990720678813495, "count": 1, "min": 0.0050990720678813495, "max": 0.0050990720678813495}}}
# #metrics {"StartTime": 1644032723.7123146, "EndTime": 1644032723.7123313, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 13}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.005519994659040441, "count": 1, "min": 0.005519994659040441, "max": 0.005519994659040441}}}
# #metrics {"StartTime": 1644032723.7123842, "EndTime": 1644032723.7124, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 14}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.005098994569862308, "count": 1, "min": 0.005098994569862308, "max": 0.005098994569862308}}}
# #metrics {"StartTime": 1644032723.7124531, "EndTime": 1644032723.712475, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 15}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.005520632858851448, "count": 1, "min": 0.005520632858851448, "max": 0.005520632858851448}}}
# #metrics {"StartTime": 1644032723.7125282, "EndTime": 1644032723.7125456, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 16}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.012167769629751617, "count": 1, "min": 0.012167769629751617, "max": 0.012167769629751617}}}
# #metrics {"StartTime": 1644032723.7125988, "EndTime": 1644032723.7126153, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 17}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.012054018840118868, "count": 1, "min": 0.012054018840118868, "max": 0.012054018840118868}}}
# #metrics {"StartTime": 1644032723.7126703, "EndTime": 1644032723.7126856, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 18}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.012167777455631811, "count": 1, "min": 0.012167777455631811, "max": 0.012167777455631811}}}
# #metrics {"StartTime": 1644032723.712749, "EndTime": 1644032723.7127664, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 19}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.012054238608135051, "count": 1, "min": 0.012054238608135051, "max": 0.012054238608135051}}}
# #metrics {"StartTime": 1644032723.712817, "EndTime": 1644032723.7128325, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 20}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.012039981996593762, "count": 1, "min": 0.012039981996593762, "max": 0.012039981996593762}}}
# #metrics {"StartTime": 1644032723.7128918, "EndTime": 1644032723.712909, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 21}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.012189195263625389, "count": 1, "min": 0.012189195263625389, "max": 0.012189195263625389}}}
# #metrics {"StartTime": 1644032723.712965, "EndTime": 1644032723.7129824, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 22}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.012040088680521328, "count": 1, "min": 0.012040088680521328, "max": 0.012040088680521328}}}
# #metrics {"StartTime": 1644032723.7130358, "EndTime": 1644032723.713053, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 23}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.012187875629968979, "count": 1, "min": 0.012187875629968979, "max": 0.012187875629968979}}}
# #metrics {"StartTime": 1644032723.7131069, "EndTime": 1644032723.7131252, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 24}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.013193741987698042, "count": 1, "min": 0.013193741987698042, "max": 0.013193741987698042}}}
# #metrics {"StartTime": 1644032723.7131789, "EndTime": 1644032723.713196, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 25}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.013127850090438997, "count": 1, "min": 0.013127850090438997, "max": 0.013127850090438997}}}
# #metrics {"StartTime": 1644032723.7132475, "EndTime": 1644032723.7132633, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 26}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.013193773884270059, "count": 1, "min": 0.013193773884270059, "max": 0.013193773884270059}}}
# #metrics {"StartTime": 1644032723.7133148, "EndTime": 1644032723.7133303, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 27}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.013127679164685196, "count": 1, "min": 0.013127679164685196, "max": 0.013127679164685196}}}
# #metrics {"StartTime": 1644032723.7133808, "EndTime": 1644032723.7133968, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 28}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.013136238493512024, "count": 1, "min": 0.013136238493512024, "max": 0.013136238493512024}}}
# #metrics {"StartTime": 1644032723.713449, "EndTime": 1644032723.7134655, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 29}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.013258359701190162, "count": 1, "min": 0.013258359701190162, "max": 0.013258359701190162}}}
# #metrics {"StartTime": 1644032723.7135153, "EndTime": 1644032723.7135303, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 30}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.013136125135062328, "count": 1, "min": 0.013136125135062328, "max": 0.013136125135062328}}}
# #metrics {"StartTime": 1644032723.7135842, "EndTime": 1644032723.7136014, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 31}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.013257740079757557, "count": 1, "min": 0.013257740079757557, "max": 0.013257740079757557}}}
# [02/05/2022 03:45:23 INFO 140573160814400] #quality_metric: host=algo-1, epoch=14, train binary_classification_cross_entropy_objective <loss>=0.004796242649830766
# [02/05/2022 03:45:23 INFO 140573160814400] #early_stopping_criteria_metric: host=algo-1, epoch=14, criteria=binary_classification_cross_entropy_objective, value=0.0040303359740044
# [02/05/2022 03:45:23 INFO 140573160814400] Epoch 14: Loss improved. Updating best model
# [02/05/2022 03:45:23 INFO 140573160814400] Saving model for epoch: 14
# [02/05/2022 03:45:23 INFO 140573160814400] Saved checkpoint to "/tmp/tmp_ko92e0x/mx-mod-0000.params"
# [02/05/2022 03:45:23 INFO 140573160814400] #progress_metric: host=algo-1, completed 100.0 % of epochs
# #metrics {"StartTime": 1644032715.837242, "EndTime": 1644032723.7227895, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 3002460.0, "count": 1, "min": 3002460, "max": 3002460}, "Total Batches Seen": {"sum": 3012.0, "count": 1, "min": 3012, "max": 3012}, "Max Records Seen Between Resets": {"sum": 199364.0, "count": 1, "min": 199364, "max": 199364}, "Max Batches Seen Between Resets": {"sum": 200.0, "count": 1, "min": 200, "max": 200}, "Reset Count": {"sum": 17.0, "count": 1, "min": 17, "max": 17}, "Number of Records Since Last Reset": {"sum": 199364.0, "count": 1, "min": 199364, "max": 199364}, "Number of Batches Since Last Reset": {"sum": 200.0, "count": 1, "min": 200, "max": 200}}}
# [02/05/2022 03:45:23 INFO 140573160814400] #throughput_metric: host=algo-1, train throughput=25281.774421735947 records/second
# [02/05/2022 03:45:23 WARNING 140573160814400] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [02/05/2022 03:45:23 WARNING 140573160814400] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [2022-02-05 03:45:23.726] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 33, "duration": 3, "num_examples": 1, "num_bytes": 168000}
# [2022-02-05 03:45:24.342] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 36, "duration": 612, "num_examples": 200, "num_bytes": 33493152}
# [2022-02-05 03:45:25.394] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 38, "duration": 952, "num_examples": 200, "num_bytes": 33493152}
# [02/05/2022 03:45:25 INFO 140573160814400] #train_score (algo-1) : ('binary_classification_cross_entropy_objective', 0.003960911865313041)
# [02/05/2022 03:45:25 INFO 140573160814400] #train_score (algo-1) : ('binary_classification_accuracy', 0.9879416544611865)
# [02/05/2022 03:45:25 INFO 140573160814400] #train_score (algo-1) : ('binary_f_1.000', 0.21180327868852458)
# [02/05/2022 03:45:25 INFO 140573160814400] #train_score (algo-1) : ('precision', 0.11994058670627553)
# [02/05/2022 03:45:25 INFO 140573160814400] #train_score (algo-1) : ('recall', 0.9047619047619048)
# [02/05/2022 03:45:25 INFO 140573160814400] #train_score (algo-1) : ('roc_auc_score', 0.9790894705377465)
# [02/05/2022 03:45:25 INFO 140573160814400] #train_score (algo-1) : ('binary_balanced_accuracy', 0.5)
# [02/05/2022 03:45:25 INFO 140573160814400] #train_score (algo-1) : ('binary_log_loss', 0.6930574032138126)
# [02/05/2022 03:45:25 INFO 140573160814400] #quality_metric: host=algo-1, train binary_classification_cross_entropy_objective <loss>=0.003960911865313041
# [02/05/2022 03:45:25 INFO 140573160814400] #quality_metric: host=algo-1, train binary_classification_accuracy <score>=0.9879416544611865
# [02/05/2022 03:45:25 INFO 140573160814400] #quality_metric: host=algo-1, train binary_f_1.000 <score>=0.21180327868852458
# [02/05/2022 03:45:25 INFO 140573160814400] #quality_metric: host=algo-1, train precision <score>=0.11994058670627553
# [02/05/2022 03:45:25 INFO 140573160814400] #quality_metric: host=algo-1, train recall <score>=0.9047619047619048
# [02/05/2022 03:45:25 INFO 140573160814400] #quality_metric: host=algo-1, train roc_auc_score <score>=0.9790894705377465
# [02/05/2022 03:45:25 INFO 140573160814400] #quality_metric: host=algo-1, train binary_balanced_accuracy <score>=0.5
# [02/05/2022 03:45:25 INFO 140573160814400] #quality_metric: host=algo-1, train binary_log_loss <score>=0.6930574032138126
# [02/05/2022 03:45:25 INFO 140573160814400] Best model found for hyperparameters: {"optimizer": "adam", "learning_rate": 0.1, "wd": 0.0001, "l1": 0.0, "lr_scheduler_step": 10, "lr_scheduler_factor": 0.99, "lr_scheduler_minimum_lr": 1e-05}
# [02/05/2022 03:45:25 INFO 140573160814400] Saved checkpoint to "/tmp/tmp1fbd1_ni/mx-mod-0000.params"
# [02/05/2022 03:45:25 INFO 140573160814400] Test data is not provided.
# #metrics {"StartTime": 1644032604.7085397, "EndTime": 1644032725.749611, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training"}, "Metrics": {"initialize.time": {"sum": 268.27096939086914, "count": 1, "min": 268.27096939086914, "max": 268.27096939086914}, "epochs": {"sum": 15.0, "count": 1, "min": 15, "max": 15}, "check_early_stopping.time": {"sum": 16.058683395385742, "count": 15, "min": 0.8070468902587891, "max": 1.300811767578125}, "update.time": {"sum": 118673.83623123169, "count": 15, "min": 7731.14013671875, "max": 8362.704753875732}, "finalize.time": {"sum": 2020.080327987671, "count": 1, "min": 2020.080327987671, "max": 2020.080327987671}, "setuptime": {"sum": 37.01043128967285, "count": 1, "min": 37.01043128967285, "max": 37.01043128967285}, "totaltime": {"sum": 121299.41725730896, "count": 1, "min": 121299.41725730896, "max": 121299.41725730896}}}
# [02/05/2022 03:45:25 INFO 140573160814400 integration.py:636] worker closed
#
# 2022-02-05 03:45:55 Uploading - Uploading generated training model
# 2022-02-05 03:45:55 Completed - Training job completed
# ProfilerReport-1644032457: NoIssuesFound
# Training seconds: 193
# Billable seconds: 193
# CPU times: user 750 ms, sys: 64.9 ms, total: 815 ms
# Wall time: 5min 13s

# %% [markdown]
# ### Deploy and evaluate the tuned estimator
#
# Deploy the tuned predictor and evaluate it.
#
# We hypothesized that a tuned model, optimized for a higher recall, would have fewer false negatives (fraudulent transactions incorrectly labeled as valid); did the number of false negatives get reduced after tuning the model?

# %%
# %%time 
# deploy and create a predictor
recall_predictor = linear_recall.deploy(initial_instance_count=1, instance_type='ml.t2.medium')
# Out:
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# ----------!CPU times: user 182 ms, sys: 8.73 ms, total: 191 ms
# Wall time: 5min 1s

# %%
print('Metrics for tuned (recall), LinearLearner.\n')

# get metrics for tuned predictor
metrics = evaluate(recall_predictor, 
                   test_features.values.astype('float32'), 
                   test_labels, 
                   verbose=True)
# Out:
# Metrics for tuned (recall), LinearLearner.
#
# prediction (col)    0.0  1.0
# actual (row)
# 0                 84317  991
# 1                    20  115
#
# Recall:     0.852
# Precision:  0.104
# Accuracy:   0.988

# %% [markdown]
# **My notes:** The **false negatives** (1s predicted to be 0s) fell from 36 with the `linear_predictor` to 20 with the `recall_predictor`. As predicted, our recall-optimized model resulted in fewer false negatives.

# %% [markdown]
# ## Delete the endpoint
#
# As always, when you're done evaluating a model, you should delete the endpoint. Below, I'm using the `delete_endpoint` helper function I defined earlier. The model fell short of our target recall of 0.9, however.

# %%
# delete the predictor endpoint 
delete_endpoint(recall_predictor)
# Out:
# The endpoint attribute has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The endpoint attribute has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# Deleted linear-learner-2022-02-05-03-46-11-365

# %% [markdown]
# ---
# ## Improvement: Managing Class Imbalance
#
# We have a model that is tuned to get a higher recall, which aims to reduce the number of false negatives. Earlier, we discussed how class imbalance may actually bias our model towards predicting that all transactions are valid, resulting in higher false negatives and true negatives. It stands to reason that this model could be further improved if we account for this imbalance.
#
# To account for class imbalance during training of a binary classifier, LinearLearner offers the hyperparameter, `positive_example_weight_mult`, which is the weight assigned to positive (1, fraudulent) examples when training a binary classifier. The weight of negative examples (0, valid) is fixed at 1.
#
# ### EXERCISE: Create a LinearLearner with a `positive_example_weight_mult` parameter
#
# In **addition** to tuning a model for higher recall (you may use `linear_recall` as a starting point), you should *add* a parameter that helps account for class imbalance. From the [hyperparameter documentation](https://docs.aws.amazon.com/sagemaker/latest/dg/ll_hyperparameters.html) on `positive_example_weight_mult`, it reads:
# > "If you want the algorithm to choose a weight so that errors in classifying negative vs. positive examples have equal impact on training loss, specify `balanced`."
#
# You could also put in a specific float value, in which case you'd want to weight positive examples more heavily than negative examples, since there are fewer of them.

# %%
# instantiate a LinearLearner

# include params for tuning for higher recall
# *and* account for class imbalance in training data
linear_balanced = LinearLearner(role=role,
                              train_instance_count=1, 
                              train_instance_type='ml.c4.xlarge',
                              predictor_type='binary_classifier',
                              output_path=output_path,
                              sagemaker_session=sagemaker_session,
                              epochs=15,
                              binary_classifier_model_selection_criteria='precision_at_target_recall', # target recall
                              positive_example_weight_mult='balanced',
                              target_recall=0.9) # 90% recall
# Out:
# train_instance_count has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# train_instance_type has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.

# %% [markdown]
# ### EXERCISE: Train the balanced estimator
#
# Fit the new, balanced estimator on the formatted training data.

# %%
# %%time 
# train the estimator on formatted training data
linear_balanced.fit(formatted_train_data)
# Out:
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# 2022-02-05 04:52:45 Starting - Starting the training job...
# 2022-02-05 04:52:46 Starting - Launching requested ML instancesProfilerReport-1644036764: InProgress
# ...
# 2022-02-05 04:53:35 Starting - Preparing the instances for training............
# 2022-02-05 04:55:44 Downloading - Downloading input data
# 2022-02-05 04:55:44 Training - Downloading the training image..Docker entrypoint called with argument(s): train
# Running default environment configuration script
# [02/05/2022 04:56:02 INFO 140327059244864] Reading default configuration from /opt/amazon/lib/python3.7/site-packages/algorithm/resources/default-input.json: {'mini_batch_size': '1000', 'epochs': '15', 'feature_dim': 'auto', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'accuracy', 'f_beta': '1.0', 'target_recall': '0.8', 'target_precision': '0.8', 'num_models': 'auto', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'auto', 'loss': 'auto', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '1', 'accuracy_top_k': '3', 'wd': 'auto', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': 'auto', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': 'auto', 'lr_scheduler_factor': 'auto', 'lr_scheduler_minimum_lr': 'auto', 'positive_example_weight_mult': '1.0', 'balance_multiclass_weights': 'false', 'normalize_data': 'true', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false'}
# [02/05/2022 04:56:02 INFO 140327059244864] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {'positive_example_weight_mult': 'balanced', 'feature_dim': '30', 'predictor_type': 'binary_classifier', 'epochs': '15', 'target_recall': '0.9', 'binary_classifier_model_selection_criteria': 'precision_at_target_recall', 'mini_batch_size': '1000'}
# [02/05/2022 04:56:02 INFO 140327059244864] Final configuration: {'mini_batch_size': '1000', 'epochs': '15', 'feature_dim': '30', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'precision_at_target_recall', 'f_beta': '1.0', 'target_recall': '0.9', 'target_precision': '0.8', 'num_models': 'auto', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'auto', 'loss': 'auto', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '1', 'accuracy_top_k': '3', 'wd': 'auto', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': 'auto', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': 'auto', 'lr_scheduler_factor': 'auto', 'lr_scheduler_minimum_lr': 'auto', 'positive_example_weight_mult': 'balanced', 'balance_multiclass_weights': 'false', 'normalize_data': 'true', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false', 'predictor_type': 'binary_classifier'}
# [02/05/2022 04:56:02 WARNING 140327059244864] Loggers have already been setup.
# Process 1 is a worker.
# [02/05/2022 04:56:02 INFO 140327059244864] Using default worker.
# [02/05/2022 04:56:02 INFO 140327059244864] Checkpoint loading and saving are disabled.
# [2022-02-05 04:56:02.634] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration": 29, "num_examples": 1, "num_bytes": 168000}
# [02/05/2022 04:56:02 INFO 140327059244864] Create Store: local
# [2022-02-05 04:56:02.717] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 1, "duration": 82, "num_examples": 11, "num_bytes": 1848000}
# [02/05/2022 04:56:02 INFO 140327059244864] Scaler algorithm parameters
#  <algorithm.scaler.ScalerAlgorithmStable object at 0x7fa018433dd0>
# [02/05/2022 04:56:02 INFO 140327059244864] Scaling model computed with parameters:
#  {'stdev_label': None, 'stdev_weight':
# [4.7823008e+04 1.8987731e+00 1.5821997e+00 1.5291911e+00 1.4364978e+00
#  1.3388461e+00 1.2955806e+00 1.1771069e+00 1.2127448e+00 1.0843055e+00
#  1.0475702e+00 1.0230465e+00 1.0090139e+00 1.0057642e+00 9.5122164e-01
#  9.2613727e-01 8.7072927e-01 8.6057234e-01 8.3151484e-01 8.2762748e-01
#  7.1313608e-01 7.3347980e-01 7.2524083e-01 5.6213826e-01 6.0201687e-01
#  5.1174247e-01 4.8000538e-01 3.7595215e-01 2.7081874e-01 2.3656270e+02]
# <NDArray 30 @cpu(0)>, 'mean_label': None, 'mean_weight':
# [ 9.4275984e+04 -1.7378727e-02  1.5538026e-02  2.5005125e-02
#   3.3166975e-02  1.8197566e-02  1.7799012e-03  6.9396999e-03
#   9.8540336e-03 -3.0757964e-02 -1.2736557e-02  4.0434714e-04
#  -1.4243029e-02  1.6704608e-02  2.2619881e-02 -9.6982103e-03
#  -4.7834702e-03 -1.6767335e-04 -9.0120723e-03 -3.0407687e-03
#   4.6031545e-03 -4.0078526e-03 -1.2586080e-04  1.2784966e-03
#   3.7617318e-03 -3.1254767e-03 -8.2200055e-04  3.4045519e-03
#  -1.0332187e-03  8.7559837e+01]
# <NDArray 30 @cpu(0)>}
# [02/05/2022 04:56:02 INFO 140327059244864] nvidia-smi: took 0.030 seconds to run.
# [02/05/2022 04:56:02 INFO 140327059244864] nvidia-smi identified 0 GPUs.
# [02/05/2022 04:56:02 INFO 140327059244864] Number of GPUs being used: 0
# #metrics {"StartTime": 1644036962.8998091, "EndTime": 1644036962.8998432, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "Meta": "init_train_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 12000.0, "count": 1, "min": 12000, "max": 12000}, "Total Batches Seen": {"sum": 12.0, "count": 1, "min": 12, "max": 12}, "Max Records Seen Between Resets": {"sum": 11000.0, "count": 1, "min": 11000, "max": 11000}, "Max Batches Seen Between Resets": {"sum": 11.0, "count": 1, "min": 11, "max": 11}, "Reset Count": {"sum": 2.0, "count": 1, "min": 2, "max": 2}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [2022-02-05 04:56:10.231] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 3, "duration": 7331, "num_examples": 200, "num_bytes": 33493152}
# #metrics {"StartTime": 1644036970.2315614, "EndTime": 1644036970.231663, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 0}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5791407177028943, "count": 1, "min": 0.5791407177028943, "max": 0.5791407177028943}}}
# #metrics {"StartTime": 1644036970.231756, "EndTime": 1644036970.231777, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 1}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.4759549259971734, "count": 1, "min": 0.4759549259971734, "max": 0.4759549259971734}}}
# #metrics {"StartTime": 1644036970.2318351, "EndTime": 1644036970.2318532, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 2}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.4948354150206599, "count": 1, "min": 0.4948354150206599, "max": 0.4948354150206599}}}
# #metrics {"StartTime": 1644036970.2319102, "EndTime": 1644036970.2319283, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 3}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5374999441789023, "count": 1, "min": 0.5374999441789023, "max": 0.5374999441789023}}}
# #metrics {"StartTime": 1644036970.2319815, "EndTime": 1644036970.231999, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 4}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6132990110579447, "count": 1, "min": 0.6132990110579447, "max": 0.6132990110579447}}}
# #metrics {"StartTime": 1644036970.2320611, "EndTime": 1644036970.2320793, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 5}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.650242357378629, "count": 1, "min": 0.650242357378629, "max": 0.650242357378629}}}
# #metrics {"StartTime": 1644036970.2321336, "EndTime": 1644036970.232151, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 6}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6198758794314897, "count": 1, "min": 0.6198758794314897, "max": 0.6198758794314897}}}
# #metrics {"StartTime": 1644036970.232205, "EndTime": 1644036970.2322223, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 7}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.642763320194417, "count": 1, "min": 0.642763320194417, "max": 0.642763320194417}}}
# #metrics {"StartTime": 1644036970.232275, "EndTime": 1644036970.23229, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 8}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.4923872120919539, "count": 1, "min": 0.4923872120919539, "max": 0.4923872120919539}}}
# #metrics {"StartTime": 1644036970.2323503, "EndTime": 1644036970.232367, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 9}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5910773196579823, "count": 1, "min": 0.5910773196579823, "max": 0.5910773196579823}}}
# #metrics {"StartTime": 1644036970.2324245, "EndTime": 1644036970.2324412, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 10}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5660034152850434, "count": 1, "min": 0.5660034152850434, "max": 0.5660034152850434}}}
# #metrics {"StartTime": 1644036970.2324924, "EndTime": 1644036970.2325091, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 11}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.570866738247512, "count": 1, "min": 0.570866738247512, "max": 0.570866738247512}}}
# #metrics {"StartTime": 1644036970.2325618, "EndTime": 1644036970.2325776, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 12}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.603102036327573, "count": 1, "min": 0.603102036327573, "max": 0.603102036327573}}}
# #metrics {"StartTime": 1644036970.2326286, "EndTime": 1644036970.2326431, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 13}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6313092581015736, "count": 1, "min": 0.6313092581015736, "max": 0.6313092581015736}}}
# #metrics {"StartTime": 1644036970.2326944, "EndTime": 1644036970.2327106, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 14}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6069122777967597, "count": 1, "min": 0.6069122777967597, "max": 0.6069122777967597}}}
# #metrics {"StartTime": 1644036970.23276, "EndTime": 1644036970.2327757, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 15}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6302709089116235, "count": 1, "min": 0.6302709089116235, "max": 0.6302709089116235}}}
# #metrics {"StartTime": 1644036970.2328258, "EndTime": 1644036970.232842, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 16}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6274360078591198, "count": 1, "min": 0.6274360078591198, "max": 0.6274360078591198}}}
# #metrics {"StartTime": 1644036970.2328913, "EndTime": 1644036970.2329073, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 17}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.512769868476906, "count": 1, "min": 0.512769868476906, "max": 0.512769868476906}}}
# #metrics {"StartTime": 1644036970.2329617, "EndTime": 1644036970.2329774, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 18}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5364223231790054, "count": 1, "min": 0.5364223231790054, "max": 0.5364223231790054}}}
# #metrics {"StartTime": 1644036970.2330265, "EndTime": 1644036970.2330427, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 19}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5448161246141596, "count": 1, "min": 0.5448161246141596, "max": 0.5448161246141596}}}
# #metrics {"StartTime": 1644036970.233093, "EndTime": 1644036970.2331083, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 20}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.540332931163922, "count": 1, "min": 0.540332931163922, "max": 0.540332931163922}}}
# #metrics {"StartTime": 1644036970.2331526, "EndTime": 1644036970.2331674, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 21}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.541313360655128, "count": 1, "min": 0.541313360655128, "max": 0.541313360655128}}}
# #metrics {"StartTime": 1644036970.23322, "EndTime": 1644036970.2332356, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 22}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.536809625117623, "count": 1, "min": 0.536809625117623, "max": 0.536809625117623}}}
# #metrics {"StartTime": 1644036970.233286, "EndTime": 1644036970.2333024, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 23}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5356268091920632, "count": 1, "min": 0.5356268091920632, "max": 0.5356268091920632}}}
# #metrics {"StartTime": 1644036970.2333639, "EndTime": 1644036970.2333794, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 24}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.081357410986819, "count": 1, "min": 1.081357410986819, "max": 1.081357410986819}}}
# #metrics {"StartTime": 1644036970.2334292, "EndTime": 1644036970.2334442, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 25}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.0807654687315975, "count": 1, "min": 1.0807654687315975, "max": 1.0807654687315975}}}
# #metrics {"StartTime": 1644036970.2334929, "EndTime": 1644036970.2335086, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 26}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.107846775994229, "count": 1, "min": 1.107846775994229, "max": 1.107846775994229}}}
# #metrics {"StartTime": 1644036970.2335572, "EndTime": 1644036970.233572, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 27}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.0852037635688208, "count": 1, "min": 1.0852037635688208, "max": 1.0852037635688208}}}
# #metrics {"StartTime": 1644036970.233621, "EndTime": 1644036970.2336361, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 28}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.2230319136423082, "count": 1, "min": 1.2230319136423082, "max": 1.2230319136423082}}}
# #metrics {"StartTime": 1644036970.2336853, "EndTime": 1644036970.2337008, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 29}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.240264271721768, "count": 1, "min": 1.240264271721768, "max": 1.240264271721768}}}
# #metrics {"StartTime": 1644036970.233747, "EndTime": 1644036970.2337623, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 30}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.2185808203615736, "count": 1, "min": 1.2185808203615736, "max": 1.2185808203615736}}}
# #metrics {"StartTime": 1644036970.233813, "EndTime": 1644036970.2338293, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 31}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.2268015014801792, "count": 1, "min": 1.2268015014801792, "max": 1.2268015014801792}}}
# [02/05/2022 04:56:10 INFO 140327059244864] #quality_metric: host=algo-1, epoch=0, train binary_classification_weighted_cross_entropy_objective <loss>=0.5791407177028943
# [02/05/2022 04:56:10 INFO 140327059244864] #early_stopping_criteria_metric: host=algo-1, epoch=0, criteria=binary_classification_weighted_cross_entropy_objective, value=0.4759549259971734
# [02/05/2022 04:56:10 INFO 140327059244864] Epoch 0: Loss improved. Updating best model
# [02/05/2022 04:56:10 INFO 140327059244864] Saving model for epoch: 0
# [02/05/2022 04:56:10 INFO 140327059244864] Saved checkpoint to "/tmp/tmp1wjldfxw/mx-mod-0000.params"
# [02/05/2022 04:56:10 INFO 140327059244864] #progress_metric: host=algo-1, completed 6.666666666666667 % of epochs
# #metrics {"StartTime": 1644036962.9001017, "EndTime": 1644036970.2466235, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 211364.0, "count": 1, "min": 211364, "max": 211364}, "Total Batches Seen": {"sum": 212.0, "count": 1, "min": 212, "max": 212}, "Max Records Seen Between Resets": {"sum": 199364.0, "count": 1, "min": 199364, "max": 199364}, "Max Batches Seen Between Resets": {"sum": 200.0, "count": 1, "min": 200, "max": 200}, "Reset Count": {"sum": 3.0, "count": 1, "min": 3, "max": 3}, "Number of Records Since Last Reset": {"sum": 199364.0, "count": 1, "min": 199364, "max": 199364}, "Number of Batches Since Last Reset": {"sum": 200.0, "count": 1, "min": 200, "max": 200}}}
# [02/05/2022 04:56:10 INFO 140327059244864] #throughput_metric: host=algo-1, train throughput=27136.78865326445 records/second
# [2022-02-05 04:56:17.535] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 5, "duration": 7287, "num_examples": 200, "num_bytes": 33493152}
# #metrics {"StartTime": 1644036977.5359437, "EndTime": 1644036977.5360272, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 0}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.3762333395109704, "count": 1, "min": 0.3762333395109704, "max": 0.3762333395109704}}}
# #metrics {"StartTime": 1644036977.5361254, "EndTime": 1644036977.5361464, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 1}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.3452077499849712, "count": 1, "min": 0.3452077499849712, "max": 0.3452077499849712}}}
# #metrics {"StartTime": 1644036977.5362117, "EndTime": 1644036977.5362291, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 2}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.3545212267391646, "count": 1, "min": 0.3545212267391646, "max": 0.3545212267391646}}}
# #metrics {"StartTime": 1644036977.5362854, "EndTime": 1644036977.5363028, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 3}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.358282039009746, "count": 1, "min": 0.358282039009746, "max": 0.358282039009746}}}
# #metrics {"StartTime": 1644036977.5363588, "EndTime": 1644036977.5363758, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 4}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.503855560801137, "count": 1, "min": 0.503855560801137, "max": 0.503855560801137}}}
# #metrics {"StartTime": 1644036977.5364332, "EndTime": 1644036977.5364501, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 5}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5762882809279553, "count": 1, "min": 0.5762882809279553, "max": 0.5762882809279553}}}
# #metrics {"StartTime": 1644036977.5365071, "EndTime": 1644036977.5365236, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 6}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5095617222809912, "count": 1, "min": 0.5095617222809912, "max": 0.5095617222809912}}}
# #metrics {"StartTime": 1644036977.5365844, "EndTime": 1644036977.5366013, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 7}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5621733702846508, "count": 1, "min": 0.5621733702846508, "max": 0.5621733702846508}}}
# #metrics {"StartTime": 1644036977.5366623, "EndTime": 1644036977.5366793, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 8}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.35608179332023887, "count": 1, "min": 0.35608179332023887, "max": 0.35608179332023887}}}
# #metrics {"StartTime": 1644036977.5367346, "EndTime": 1644036977.5367503, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 9}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.37639001955578677, "count": 1, "min": 0.37639001955578677, "max": 0.37639001955578677}}}
# #metrics {"StartTime": 1644036977.5368123, "EndTime": 1644036977.5368278, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 10}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.3734735677901225, "count": 1, "min": 0.3734735677901225, "max": 0.3734735677901225}}}
# #metrics {"StartTime": 1644036977.536879, "EndTime": 1644036977.5368948, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 11}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.3714105723778806, "count": 1, "min": 0.3714105723778806, "max": 0.3714105723778806}}}
# #metrics {"StartTime": 1644036977.536945, "EndTime": 1644036977.5369604, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 12}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.4968251642581806, "count": 1, "min": 0.4968251642581806, "max": 0.4968251642581806}}}
# #metrics {"StartTime": 1644036977.5370097, "EndTime": 1644036977.5370257, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 13}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5793348179342759, "count": 1, "min": 0.5793348179342759, "max": 0.5793348179342759}}}
# #metrics {"StartTime": 1644036977.537076, "EndTime": 1644036977.5370915, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 14}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5010429530119777, "count": 1, "min": 0.5010429530119777, "max": 0.5010429530119777}}}
# #metrics {"StartTime": 1644036977.537141, "EndTime": 1644036977.537156, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 15}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5806286224671944, "count": 1, "min": 0.5806286224671944, "max": 0.5806286224671944}}}
# #metrics {"StartTime": 1644036977.5372071, "EndTime": 1644036977.5372224, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 16}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.45959482746986885, "count": 1, "min": 0.45959482746986885, "max": 0.45959482746986885}}}
# #metrics {"StartTime": 1644036977.5372798, "EndTime": 1644036977.537297, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 17}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.45221469054869073, "count": 1, "min": 0.45221469054869073, "max": 0.45221469054869073}}}
# #metrics {"StartTime": 1644036977.537372, "EndTime": 1644036977.5373886, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 18}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.4510753076447913, "count": 1, "min": 0.4510753076447913, "max": 0.4510753076447913}}}
# #metrics {"StartTime": 1644036977.5374327, "EndTime": 1644036977.5374432, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 19}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.45293791068379, "count": 1, "min": 0.45293791068379, "max": 0.45293791068379}}}
# #metrics {"StartTime": 1644036977.5374732, "EndTime": 1644036977.5374818, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 20}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.513988640119083, "count": 1, "min": 0.513988640119083, "max": 0.513988640119083}}}
# #metrics {"StartTime": 1644036977.5375164, "EndTime": 1644036977.5375304, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 21}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5301194904844965, "count": 1, "min": 0.5301194904844965, "max": 0.5301194904844965}}}
# #metrics {"StartTime": 1644036977.5375767, "EndTime": 1644036977.5375867, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 22}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5141575448309357, "count": 1, "min": 0.5141575448309357, "max": 0.5141575448309357}}}
# #metrics {"StartTime": 1644036977.537623, "EndTime": 1644036977.5376377, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 23}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5306000879949062, "count": 1, "min": 0.5306000879949062, "max": 0.5306000879949062}}}
# #metrics {"StartTime": 1644036977.5376937, "EndTime": 1644036977.5377092, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 24}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.0809531622651833, "count": 1, "min": 1.0809531622651833, "max": 1.0809531622651833}}}
# #metrics {"StartTime": 1644036977.537767, "EndTime": 1644036977.5377836, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 25}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.0806157694294225, "count": 1, "min": 1.0806157694294225, "max": 1.0806157694294225}}}
# #metrics {"StartTime": 1644036977.537836, "EndTime": 1644036977.5378528, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 26}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.0811927944164181, "count": 1, "min": 1.0811927944164181, "max": 1.0811927944164181}}}
# #metrics {"StartTime": 1644036977.537911, "EndTime": 1644036977.537928, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 27}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.0806420212942152, "count": 1, "min": 1.0806420212942152, "max": 1.0806420212942152}}}
# #metrics {"StartTime": 1644036977.5379794, "EndTime": 1644036977.5379963, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 28}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.1822309901558574, "count": 1, "min": 1.1822309901558574, "max": 1.1822309901558574}}}
# #metrics {"StartTime": 1644036977.5380464, "EndTime": 1644036977.538061, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 29}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.2228483647485475, "count": 1, "min": 1.2228483647485475, "max": 1.2228483647485475}}}
# #metrics {"StartTime": 1644036977.538102, "EndTime": 1644036977.5381172, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 30}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.1816888533549093, "count": 1, "min": 1.1816888533549093, "max": 1.1816888533549093}}}
# #metrics {"StartTime": 1644036977.538165, "EndTime": 1644036977.5381804, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 31}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.2195927194566583, "count": 1, "min": 1.2195927194566583, "max": 1.2195927194566583}}}
# [02/05/2022 04:56:17 INFO 140327059244864] #quality_metric: host=algo-1, epoch=1, train binary_classification_weighted_cross_entropy_objective <loss>=0.3762333395109704
# [02/05/2022 04:56:17 INFO 140327059244864] #early_stopping_criteria_metric: host=algo-1, epoch=1, criteria=binary_classification_weighted_cross_entropy_objective, value=0.3452077499849712
# [02/05/2022 04:56:17 INFO 140327059244864] Epoch 1: Loss improved. Updating best model
# [02/05/2022 04:56:17 INFO 140327059244864] Saving model for epoch: 1
# [02/05/2022 04:56:17 INFO 140327059244864] Saved checkpoint to "/tmp/tmpepluqat6/mx-mod-0000.params"
# [02/05/2022 04:56:17 INFO 140327059244864] #progress_metric: host=algo-1, completed 13.333333333333334 % of epochs
# #metrics {"StartTime": 1644036970.2478676, "EndTime": 1644036977.546439, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 410728.0, "count": 1, "min": 410728, "max": 410728}, "Total Batches Seen": {"sum": 412.0, "count": 1, "min": 412, "max": 412}, "Max Records Seen Between Resets": {"sum": 199364.0, "count": 1, "min": 199364, "max": 199364}, "Max Batches Seen Between Resets": {"sum": 200.0, "count": 1, "min": 200, "max": 200}, "Reset Count": {"sum": 4.0, "count": 1, "min": 4, "max": 4}, "Number of Records Since Last Reset": {"sum": 199364.0, "count": 1, "min": 199364, "max": 199364}, "Number of Batches Since Last Reset": {"sum": 200.0, "count": 1, "min": 200, "max": 200}}}
# [02/05/2022 04:56:17 INFO 140327059244864] #throughput_metric: host=algo-1, train throughput=27315.010763939295 records/second
# [2022-02-05 04:56:24.149] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 7, "duration": 6602, "num_examples": 200, "num_bytes": 33493152}
# #metrics {"StartTime": 1644036984.149829, "EndTime": 1644036984.1501, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 0}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.3391149269755761, "count": 1, "min": 0.3391149269755761, "max": 0.3391149269755761}}}
# #metrics {"StartTime": 1644036984.1501796, "EndTime": 1644036984.1502001, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 1}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.3195404147047493, "count": 1, "min": 0.3195404147047493, "max": 0.3195404147047493}}}
# #metrics {"StartTime": 1644036984.150258, "EndTime": 1644036984.1502745, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 2}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.32698557615040535, "count": 1, "min": 0.32698557615040535, "max": 0.32698557615040535}}}
# #metrics {"StartTime": 1644036984.1503303, "EndTime": 1644036984.1503475, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 3}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.3274032881846979, "count": 1, "min": 0.3274032881846979, "max": 0.3274032881846979}}}
# #metrics {"StartTime": 1644036984.1503997, "EndTime": 1644036984.150416, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 4}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.4777964639903313, "count": 1, "min": 0.4777964639903313, "max": 0.4777964639903313}}}
# #metrics {"StartTime": 1644036984.1504679, "EndTime": 1644036984.150484, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 5}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.590638911990065, "count": 1, "min": 0.590638911990065, "max": 0.590638911990065}}}
# #metrics {"StartTime": 1644036984.1505458, "EndTime": 1644036984.150563, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 6}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.48253254189802774, "count": 1, "min": 0.48253254189802774, "max": 0.48253254189802774}}}
# #metrics {"StartTime": 1644036984.1506352, "EndTime": 1644036984.150652, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 7}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6031271160259918, "count": 1, "min": 0.6031271160259918, "max": 0.6031271160259918}}}
# #metrics {"StartTime": 1644036984.1507106, "EndTime": 1644036984.1507275, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 8}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.3290663219432735, "count": 1, "min": 0.3290663219432735, "max": 0.3290663219432735}}}
# #metrics {"StartTime": 1644036984.1507802, "EndTime": 1644036984.1507955, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 9}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.33843334504707373, "count": 1, "min": 0.33843334504707373, "max": 0.33843334504707373}}}
# #metrics {"StartTime": 1644036984.150851, "EndTime": 1644036984.150867, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 10}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.33953402284401746, "count": 1, "min": 0.33953402284401746, "max": 0.33953402284401746}}}
# #metrics {"StartTime": 1644036984.1509192, "EndTime": 1644036984.150934, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 11}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.3347382457100566, "count": 1, "min": 0.3347382457100566, "max": 0.3347382457100566}}}
# #metrics {"StartTime": 1644036984.1509855, "EndTime": 1644036984.1510007, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 12}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.43369665937567475, "count": 1, "min": 0.43369665937567475, "max": 0.43369665937567475}}}
# #metrics {"StartTime": 1644036984.1510613, "EndTime": 1644036984.1510782, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 13}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5582932119513276, "count": 1, "min": 0.5582932119513276, "max": 0.5582932119513276}}}
# #metrics {"StartTime": 1644036984.1511364, "EndTime": 1644036984.1511533, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 14}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.40992417111229057, "count": 1, "min": 0.40992417111229057, "max": 0.40992417111229057}}}
# #metrics {"StartTime": 1644036984.1512153, "EndTime": 1644036984.1512318, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 15}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5464452117843245, "count": 1, "min": 0.5464452117843245, "max": 0.5464452117843245}}}
# #metrics {"StartTime": 1644036984.1512833, "EndTime": 1644036984.1513004, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 16}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.44801290402819766, "count": 1, "min": 0.44801290402819766, "max": 0.44801290402819766}}}
# #metrics {"StartTime": 1644036984.1513531, "EndTime": 1644036984.1513705, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 17}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.4507313074466571, "count": 1, "min": 0.4507313074466571, "max": 0.4507313074466571}}}
# #metrics {"StartTime": 1644036984.1514235, "EndTime": 1644036984.1514397, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 18}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.4471608550872036, "count": 1, "min": 0.4471608550872036, "max": 0.4471608550872036}}}
# #metrics {"StartTime": 1644036984.1514914, "EndTime": 1644036984.1515064, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 19}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.4506483911868915, "count": 1, "min": 0.4506483911868915, "max": 0.4506483911868915}}}
# #metrics {"StartTime": 1644036984.1515615, "EndTime": 1644036984.1515784, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 20}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5034817837087353, "count": 1, "min": 0.5034817837087353, "max": 0.5034817837087353}}}
# #metrics {"StartTime": 1644036984.1516285, "EndTime": 1644036984.1516445, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 21}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5302559648638394, "count": 1, "min": 0.5302559648638394, "max": 0.5302559648638394}}}
# #metrics {"StartTime": 1644036984.151698, "EndTime": 1644036984.151714, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 22}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5034230974091957, "count": 1, "min": 0.5034230974091957, "max": 0.5034230974091957}}}
# #metrics {"StartTime": 1644036984.1517498, "EndTime": 1644036984.151759, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 23}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.531876334511455, "count": 1, "min": 0.531876334511455, "max": 0.531876334511455}}}
# #metrics {"StartTime": 1644036984.1517832, "EndTime": 1644036984.151794, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 24}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.080485231179089, "count": 1, "min": 1.080485231179089, "max": 1.080485231179089}}}
# #metrics {"StartTime": 1644036984.1518445, "EndTime": 1644036984.1518602, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 25}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.0806065483668341, "count": 1, "min": 1.0806065483668341, "max": 1.0806065483668341}}}
# #metrics {"StartTime": 1644036984.1519089, "EndTime": 1644036984.1519191, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 26}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.080347275623724, "count": 1, "min": 1.080347275623724, "max": 1.080347275623724}}}
# #metrics {"StartTime": 1644036984.1519504, "EndTime": 1644036984.1519582, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 27}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.0807068119528305, "count": 1, "min": 1.0807068119528305, "max": 1.0807068119528305}}}
# #metrics {"StartTime": 1644036984.151989, "EndTime": 1644036984.152002, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 28}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.1454150128388525, "count": 1, "min": 1.1454150128388525, "max": 1.1454150128388525}}}
# #metrics {"StartTime": 1644036984.1520464, "EndTime": 1644036984.152061, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 29}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.2139291877171503, "count": 1, "min": 1.2139291877171503, "max": 1.2139291877171503}}}
# #metrics {"StartTime": 1644036984.152111, "EndTime": 1644036984.1521268, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 30}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.1451639179632291, "count": 1, "min": 1.1451639179632291, "max": 1.1451639179632291}}}
# #metrics {"StartTime": 1644036984.1521716, "EndTime": 1644036984.1521857, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 31}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.2131926508764526, "count": 1, "min": 1.2131926508764526, "max": 1.2131926508764526}}}
# [02/05/2022 04:56:24 INFO 140327059244864] #quality_metric: host=algo-1, epoch=2, train binary_classification_weighted_cross_entropy_objective <loss>=0.3391149269755761
# [02/05/2022 04:56:24 INFO 140327059244864] #early_stopping_criteria_metric: host=algo-1, epoch=2, criteria=binary_classification_weighted_cross_entropy_objective, value=0.3195404147047493
# [02/05/2022 04:56:24 INFO 140327059244864] Epoch 2: Loss improved. Updating best model
# [02/05/2022 04:56:24 INFO 140327059244864] Saving model for epoch: 2
# [02/05/2022 04:56:24 INFO 140327059244864] Saved checkpoint to "/tmp/tmph0dy4bgz/mx-mod-0000.params"
# [02/05/2022 04:56:24 INFO 140327059244864] #progress_metric: host=algo-1, completed 20.0 % of epochs
# #metrics {"StartTime": 1644036977.5469387, "EndTime": 1644036984.1617208, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 610092.0, "count": 1, "min": 610092, "max": 610092}, "Total Batches Seen": {"sum": 612.0, "count": 1, "min": 612, "max": 612}, "Max Records Seen Between Resets": {"sum": 199364.0, "count": 1, "min": 199364, "max": 199364}, "Max Batches Seen Between Resets": {"sum": 200.0, "count": 1, "min": 200, "max": 200}, "Reset Count": {"sum": 5.0, "count": 1, "min": 5, "max": 5}, "Number of Records Since Last Reset": {"sum": 199364.0, "count": 1, "min": 199364, "max": 199364}, "Number of Batches Since Last Reset": {"sum": 200.0, "count": 1, "min": 200, "max": 200}}}
# [02/05/2022 04:56:24 INFO 140327059244864] #throughput_metric: host=algo-1, train throughput=30138.598766397907 records/second
#
# 2022-02-05 04:56:40 Training - Training image download completed. Training in progress.[2022-02-05 04:56:31.298] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 9, "duration": 7134, "num_examples": 200, "num_bytes": 33493152}
# #metrics {"StartTime": 1644036991.2983632, "EndTime": 1644036991.2984452, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 0}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.32226599174767884, "count": 1, "min": 0.32226599174767884, "max": 0.32226599174767884}}}
# #metrics {"StartTime": 1644036991.2985194, "EndTime": 1644036991.298537, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 1}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.3074733453491824, "count": 1, "min": 0.3074733453491824, "max": 0.3074733453491824}}}
# ...
# #metrics {"StartTime": 1644037067.0299158, "EndTime": 1644037067.029932, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 5}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5330752930856829, "count": 1, "min": 0.5330752930856829, "max": 0.5330752930856829}}}
# #metrics {"StartTime": 1644037067.029987, "EndTime": 1644037067.030004, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 6}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.28378996158005604, "count": 1, "min": 0.28378996158005604, "max": 0.28378996158005604}}}
# #metrics {"StartTime": 1644037067.0300505, "EndTime": 1644037067.0300665, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 7}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.47326236121019527, "count": 1, "min": 0.47326236121019527, "max": 0.47326236121019527}}}
# #metrics {"StartTime": 1644037067.03012, "EndTime": 1644037067.0301356, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 8}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.29130650279749576, "count": 1, "min": 0.29130650279749576, "max": 0.29130650279749576}}}
# #metrics {"StartTime": 1644037067.0301857, "EndTime": 1644037067.0302017, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 9}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.29114658903955815, "count": 1, "min": 0.29114658903955815, "max": 0.29114658903955815}}}
# #metrics {"StartTime": 1644037067.0302382, "EndTime": 1644037067.0302532, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 10}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.29353761303005504, "count": 1, "min": 0.29353761303005504, "max": 0.29353761303005504}}}
# #metrics {"StartTime": 1644037067.030301, "EndTime": 1644037067.030317, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 11}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.2908794963204082, "count": 1, "min": 0.2908794963204082, "max": 0.2908794963204082}}}
# #metrics {"StartTime": 1644037067.0303845, "EndTime": 1644037067.0304015, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 12}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.2914942595515419, "count": 1, "min": 0.2914942595515419, "max": 0.2914942595515419}}}
# #metrics {"StartTime": 1644037067.0304418, "EndTime": 1644037067.0304568, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 13}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.4870187229367357, "count": 1, "min": 0.4870187229367357, "max": 0.4870187229367357}}}
# #metrics {"StartTime": 1644037067.030507, "EndTime": 1644037067.0305233, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 14}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.2914134636116986, "count": 1, "min": 0.2914134636116986, "max": 0.2914134636116986}}}
# #metrics {"StartTime": 1644037067.0305686, "EndTime": 1644037067.030584, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 15}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.49398941992754913, "count": 1, "min": 0.49398941992754913, "max": 0.49398941992754913}}}
# #metrics {"StartTime": 1644037067.030633, "EndTime": 1644037067.0306473, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 16}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.4376009713177705, "count": 1, "min": 0.4376009713177705, "max": 0.4376009713177705}}}
# #metrics {"StartTime": 1644037067.0306997, "EndTime": 1644037067.0307157, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 17}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.4484181482516342, "count": 1, "min": 0.4484181482516342, "max": 0.4484181482516342}}}
# #metrics {"StartTime": 1644037067.0307684, "EndTime": 1644037067.0307848, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 18}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.43762711445410646, "count": 1, "min": 0.43762711445410646, "max": 0.43762711445410646}}}
# #metrics {"StartTime": 1644037067.0308354, "EndTime": 1644037067.0308492, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 19}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.44841468803367424, "count": 1, "min": 0.44841468803367424, "max": 0.44841468803367424}}}
# #metrics {"StartTime": 1644037067.0308897, "EndTime": 1644037067.030904, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 20}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.45202172866897966, "count": 1, "min": 0.45202172866897966, "max": 0.45202172866897966}}}
# #metrics {"StartTime": 1644037067.0309458, "EndTime": 1644037067.0309596, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 21}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5203195825893077, "count": 1, "min": 0.5203195825893077, "max": 0.5203195825893077}}}
# #metrics {"StartTime": 1644037067.0310123, "EndTime": 1644037067.0310285, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 22}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.4520227471739803, "count": 1, "min": 0.4520227471739803, "max": 0.4520227471739803}}}
# #metrics {"StartTime": 1644037067.0310745, "EndTime": 1644037067.0310848, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 23}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5202868180394772, "count": 1, "min": 0.5202868180394772, "max": 0.5202868180394772}}}
# #metrics {"StartTime": 1644037067.0311236, "EndTime": 1644037067.0311387, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 24}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.0734474260339786, "count": 1, "min": 1.0734474260339786, "max": 1.0734474260339786}}}
# #metrics {"StartTime": 1644037067.0311804, "EndTime": 1644037067.031195, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 25}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.0808105422743601, "count": 1, "min": 1.0808105422743601, "max": 1.0808105422743601}}}
# #metrics {"StartTime": 1644037067.0312524, "EndTime": 1644037067.0312681, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 26}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.073446477075318, "count": 1, "min": 1.073446477075318, "max": 1.073446477075318}}}
# #metrics {"StartTime": 1644037067.0313194, "EndTime": 1644037067.0313346, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 27}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.0808158106204853, "count": 1, "min": 1.0808158106204853, "max": 1.0808158106204853}}}
# #metrics {"StartTime": 1644037067.031384, "EndTime": 1644037067.0313945, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 28}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.081110000226965, "count": 1, "min": 1.081110000226965, "max": 1.081110000226965}}}
# #metrics {"StartTime": 1644037067.0314379, "EndTime": 1644037067.0314524, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 29}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.178819695554187, "count": 1, "min": 1.178819695554187, "max": 1.178819695554187}}}
# #metrics {"StartTime": 1644037067.0314996, "EndTime": 1644037067.0315158, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 30}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.0811094335814817, "count": 1, "min": 1.0811094335814817, "max": 1.0811094335814817}}}
# #metrics {"StartTime": 1644037067.0315657, "EndTime": 1644037067.031581, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 31}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.1788132949905779, "count": 1, "min": 1.1788132949905779, "max": 1.1788132949905779}}}
# [02/05/2022 04:57:47 INFO 140327059244864] #quality_metric: host=algo-1, epoch=14, train binary_classification_weighted_cross_entropy_objective <loss>=0.29068308453583835
# [02/05/2022 04:57:47 INFO 140327059244864] #early_stopping_criteria_metric: host=algo-1, epoch=14, criteria=binary_classification_weighted_cross_entropy_objective, value=0.28373790798474796
# [02/05/2022 04:57:47 INFO 140327059244864] Epoch 14: Loss improved. Updating best model
# [02/05/2022 04:57:47 INFO 140327059244864] Saving model for epoch: 14
# [02/05/2022 04:57:47 INFO 140327059244864] Saved checkpoint to "/tmp/tmp7281bizl/mx-mod-0000.params"
# [02/05/2022 04:57:47 INFO 140327059244864] #progress_metric: host=algo-1, completed 100.0 % of epochs
# #metrics {"StartTime": 1644037059.950264, "EndTime": 1644037067.0406158, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 3002460.0, "count": 1, "min": 3002460, "max": 3002460}, "Total Batches Seen": {"sum": 3012.0, "count": 1, "min": 3012, "max": 3012}, "Max Records Seen Between Resets": {"sum": 199364.0, "count": 1, "min": 199364, "max": 199364}, "Max Batches Seen Between Resets": {"sum": 200.0, "count": 1, "min": 200, "max": 200}, "Reset Count": {"sum": 17.0, "count": 1, "min": 17, "max": 17}, "Number of Records Since Last Reset": {"sum": 199364.0, "count": 1, "min": 199364, "max": 199364}, "Number of Batches Since Last Reset": {"sum": 200.0, "count": 1, "min": 200, "max": 200}}}
# [02/05/2022 04:57:47 INFO 140327059244864] #throughput_metric: host=algo-1, train throughput=28117.162518045803 records/second
# [02/05/2022 04:57:47 WARNING 140327059244864] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [02/05/2022 04:57:47 WARNING 140327059244864] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [2022-02-05 04:57:47.046] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 33, "duration": 3, "num_examples": 1, "num_bytes": 168000}
# [2022-02-05 04:57:47.536] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 36, "duration": 486, "num_examples": 200, "num_bytes": 33493152}
# [2022-02-05 04:57:48.323] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 38, "duration": 717, "num_examples": 200, "num_bytes": 33493152}
# [02/05/2022 04:57:48 INFO 140327059244864] #train_score (algo-1) : ('binary_classification_weighted_cross_entropy_objective', 0.2687483957430368)
# [02/05/2022 04:57:48 INFO 140327059244864] #train_score (algo-1) : ('binary_classification_accuracy', 0.9913173892979675)
# [02/05/2022 04:57:48 INFO 140327059244864] #train_score (algo-1) : ('binary_f_1.000', 0.27177114009255365)
# [02/05/2022 04:57:48 INFO 140327059244864] #train_score (algo-1) : ('precision', 0.1599009900990099)
# [02/05/2022 04:57:48 INFO 140327059244864] #train_score (algo-1) : ('recall', 0.9047619047619048)
# [02/05/2022 04:57:48 INFO 140327059244864] #train_score (algo-1) : ('roc_auc_score', 0.9883347149127631)
# [02/05/2022 04:57:48 INFO 140327059244864] #train_score (algo-1) : ('binary_balanced_accuracy', 0.5)
# [02/05/2022 04:57:48 INFO 140327059244864] #train_score (algo-1) : ('binary_log_loss', 0.7326821872687728)
# [02/05/2022 04:57:48 INFO 140327059244864] #quality_metric: host=algo-1, train binary_classification_weighted_cross_entropy_objective <loss>=0.2687483957430368
# [02/05/2022 04:57:48 INFO 140327059244864] #quality_metric: host=algo-1, train binary_classification_accuracy <score>=0.9913173892979675
# [02/05/2022 04:57:48 INFO 140327059244864] #quality_metric: host=algo-1, train binary_f_1.000 <score>=0.27177114009255365
# [02/05/2022 04:57:48 INFO 140327059244864] #quality_metric: host=algo-1, train precision <score>=0.1599009900990099
# [02/05/2022 04:57:48 INFO 140327059244864] #quality_metric: host=algo-1, train recall <score>=0.9047619047619048
# [02/05/2022 04:57:48 INFO 140327059244864] #quality_metric: host=algo-1, train roc_auc_score <score>=0.9883347149127631
# [02/05/2022 04:57:48 INFO 140327059244864] #quality_metric: host=algo-1, train binary_balanced_accuracy <score>=0.5
# [02/05/2022 04:57:48 INFO 140327059244864] #quality_metric: host=algo-1, train binary_log_loss <score>=0.7326821872687728
# [02/05/2022 04:57:48 INFO 140327059244864] Best model found for hyperparameters: {"optimizer": "adam", "learning_rate": 0.1, "wd": 0.0001, "l1": 0.0, "lr_scheduler_step": 10, "lr_scheduler_factor": 0.99, "lr_scheduler_minimum_lr": 1e-05}
# [02/05/2022 04:57:48 INFO 140327059244864] Saved checkpoint to "/tmp/tmpif5eod0x/mx-mod-0000.params"
# [02/05/2022 04:57:48 INFO 140327059244864] Test data is not provided.
# #metrics {"StartTime": 1644036962.6041048, "EndTime": 1644037068.6204379, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training"}, "Metrics": {"initialize.time": {"sum": 292.28997230529785, "count": 1, "min": 292.28997230529785, "max": 292.28997230529785}, "epochs": {"sum": 15.0, "count": 1, "min": 15, "max": 15}, "check_early_stopping.time": {"sum": 13.659954071044922, "count": 15, "min": 0.7812976837158203, "max": 1.028299331665039}, "update.time": {"sum": 104084.39660072327, "count": 15, "min": 6536.560773849487, "max": 7409.201622009277}, "finalize.time": {"sum": 1570.2908039093018, "count": 1, "min": 1570.2908039093018, "max": 1570.2908039093018}, "setuptime": {"sum": 23.314714431762695, "count": 1, "min": 23.314714431762695, "max": 23.314714431762695}, "totaltime": {"sum": 106298.35295677185, "count": 1, "min": 106298.35295677185, "max": 106298.35295677185}}}
#
# 2022-02-05 04:58:00 Uploading - Uploading generated training model
# 2022-02-05 04:58:00 Completed - Training job completed
# Training seconds: 139
# Billable seconds: 139
# CPU times: user 821 ms, sys: 44.8 ms, total: 866 ms
# Wall time: 5min 44s

# %% [markdown]
# ### EXERCISE: Deploy and evaluate the balanced estimator
#
# Deploy the balanced predictor and evaluate it. Do the results match with your expectations?

# %%
# %%time 
# deploy and create a predictor
balanced_predictor = linear_balanced.deploy(initial_instance_count=1, instance_type='ml.t2.medium')
# Out:
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# -----------!CPU times: user 205 ms, sys: 5.19 ms, total: 210 ms
# Wall time: 5min 31s

# %%
print('Metrics for balanced, LinearLearner.\n')

# get metrics for balanced predictor
metrics = evaluate(balanced_predictor, 
                   test_features.values.astype('float32'), 
                   test_labels, 
                   verbose=True)
# Out:
# Metrics for balanced, LinearLearner.
#
# prediction (col)    0.0  1.0
# actual (row)
# 0                 84629  679
# 1                    18  117
#
# Recall:     0.867
# Precision:  0.147
# Accuracy:   0.992

# %% [markdown]
# **My notes:** Although still below our target recall of 0.9, our balanced recall-optimized model has improved recall (0.852 up to 0.867), precision (0.104 up to 0.147) and accuracy (0.988 up to 0.992) from the unbalanced, recall-optimized model. False negatives have fallen slightly from 20 to 18.

# %% [markdown]
# ## Delete the endpoint
#
# When you're done evaluating a model, you should delete the endpoint.

# %%
# delete the predictor endpoint 
delete_endpoint(balanced_predictor)
# Out:
# The endpoint attribute has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The endpoint attribute has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# Deleted linear-learner-2022-02-05-05-00-51-135

# %% [markdown]
# A note on metric variability:
#
# The above model is tuned for the best possible precision with recall fixed at about 90%. The recall is fixed at 90% during training, but may vary when we apply our trained model to a test set of data.

# %% [markdown]
# ---
# ## Model Design
#
# Now that you've seen how to tune and balance a LinearLearner. Create, train and deploy your own model. This exercise is meant to be more open-ended, so that you get practice with the steps involved in designing a model and deploying it.
#
# ### EXERCISE: Train and deploy a LinearLearner with appropriate hyperparameters, according to the given scenario
#
# **Scenario:**
# * A bank has asked you to build a model that optimizes for a good user experience; users should only ever have up to about 15% of their valid transactions flagged as fraudulent.
#
# This requires that you make a design decision: Given the above scenario, what metric (and value) should you aim for during training?
#
# You may assume that performance on a training set will be within about 5-10% of the performance on a test set. For example, if you get 80% on a training set, you can assume that you'll get between about 70-90% accuracy on a test set.
#
# Your final model should account for class imbalance and be appropriately tuned.

# %%
# %%time
# instantiate and train a LinearLearner of my own. Attempted both lower and higher target recall and more epochs. 
# Also tried 'auto' for the positive_example_weight_mult (identical results to those above).


# include params for tuning for higher precision
# *and* account for class imbalance in training data

my_learner=LinearLearner(role=role,
                              train_instance_count=1, 
                              train_instance_type='ml.c4.xlarge',
                              predictor_type='binary_classifier',
                              output_path=output_path,
                              sagemaker_session=sagemaker_session,
                              epochs=15,
                              binary_classifier_model_selection_criteria='precision_at_target_recall', # target recall
                              positive_example_weight_mult='auto',
                              target_recall=0.9)

my_learner.fit(formatted_train_data)
# Out:
# train_instance_count has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# train_instance_type has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# 2022-02-05 06:12:06 Starting - Starting the training job...
# 2022-02-05 06:12:29 Starting - Launching requested ML instancesProfilerReport-1644041525: InProgress
# ...
# 2022-02-05 06:13:04 Starting - Preparing the instances for training...............
# 2022-02-05 06:15:29 Downloading - Downloading input data
# 2022-02-05 06:15:29 Training - Downloading the training image..Docker entrypoint called with argument(s): train
# Running default environment configuration script
# [02/05/2022 06:15:44 INFO 140641976874816] Reading default configuration from /opt/amazon/lib/python3.7/site-packages/algorithm/resources/default-input.json: {'mini_batch_size': '1000', 'epochs': '15', 'feature_dim': 'auto', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'accuracy', 'f_beta': '1.0', 'target_recall': '0.8', 'target_precision': '0.8', 'num_models': 'auto', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'auto', 'loss': 'auto', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '1', 'accuracy_top_k': '3', 'wd': 'auto', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': 'auto', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': 'auto', 'lr_scheduler_factor': 'auto', 'lr_scheduler_minimum_lr': 'auto', 'positive_example_weight_mult': '1.0', 'balance_multiclass_weights': 'false', 'normalize_data': 'true', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false'}
# [02/05/2022 06:15:44 INFO 140641976874816] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {'positive_example_weight_mult': 'auto', 'feature_dim': '30', 'predictor_type': 'binary_classifier', 'epochs': '15', 'target_recall': '0.9', 'binary_classifier_model_selection_criteria': 'precision_at_target_recall', 'mini_batch_size': '1000'}
# [02/05/2022 06:15:44 INFO 140641976874816] Final configuration: {'mini_batch_size': '1000', 'epochs': '15', 'feature_dim': '30', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'precision_at_target_recall', 'f_beta': '1.0', 'target_recall': '0.9', 'target_precision': '0.8', 'num_models': 'auto', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'auto', 'loss': 'auto', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '1', 'accuracy_top_k': '3', 'wd': 'auto', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': 'auto', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': 'auto', 'lr_scheduler_factor': 'auto', 'lr_scheduler_minimum_lr': 'auto', 'positive_example_weight_mult': 'auto', 'balance_multiclass_weights': 'false', 'normalize_data': 'true', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false', 'predictor_type': 'binary_classifier'}
# [02/05/2022 06:15:44 WARNING 140641976874816] Loggers have already been setup.
# Process 1 is a worker.
# [02/05/2022 06:15:44 INFO 140641976874816] Using default worker.
# [02/05/2022 06:15:44 INFO 140641976874816] Checkpoint loading and saving are disabled.
# [2022-02-05 06:15:44.728] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration": 25, "num_examples": 1, "num_bytes": 168000}
# [02/05/2022 06:15:44 INFO 140641976874816] Create Store: local
# [2022-02-05 06:15:44.821] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 1, "duration": 91, "num_examples": 11, "num_bytes": 1848000}
# [02/05/2022 06:15:44 INFO 140641976874816] Scaler algorithm parameters
#  <algorithm.scaler.ScalerAlgorithmStable object at 0x7fe962d3e490>
# [02/05/2022 06:15:44 INFO 140641976874816] Scaling model computed with parameters:
#  {'stdev_label': None, 'stdev_weight':
# [4.7823008e+04 1.8987731e+00 1.5821997e+00 1.5291911e+00 1.4364978e+00
#  1.3388461e+00 1.2955806e+00 1.1771069e+00 1.2127448e+00 1.0843055e+00
#  1.0475702e+00 1.0230465e+00 1.0090139e+00 1.0057642e+00 9.5122164e-01
#  9.2613727e-01 8.7072927e-01 8.6057234e-01 8.3151484e-01 8.2762748e-01
#  7.1313608e-01 7.3347980e-01 7.2524083e-01 5.6213826e-01 6.0201687e-01
#  5.1174247e-01 4.8000538e-01 3.7595215e-01 2.7081874e-01 2.3656270e+02]
# <NDArray 30 @cpu(0)>, 'mean_label': None, 'mean_weight':
# [ 9.4275984e+04 -1.7378727e-02  1.5538026e-02  2.5005125e-02
#   3.3166975e-02  1.8197566e-02  1.7799012e-03  6.9396999e-03
#   9.8540336e-03 -3.0757964e-02 -1.2736557e-02  4.0434714e-04
#  -1.4243029e-02  1.6704608e-02  2.2619881e-02 -9.6982103e-03
#  -4.7834702e-03 -1.6767335e-04 -9.0120723e-03 -3.0407687e-03
#   4.6031545e-03 -4.0078526e-03 -1.2586080e-04  1.2784966e-03
#   3.7617318e-03 -3.1254767e-03 -8.2200055e-04  3.4045519e-03
#  -1.0332187e-03  8.7559837e+01]
# <NDArray 30 @cpu(0)>}
# [02/05/2022 06:15:44 INFO 140641976874816] nvidia-smi: took 0.030 seconds to run.
# [02/05/2022 06:15:44 INFO 140641976874816] nvidia-smi identified 0 GPUs.
# [02/05/2022 06:15:44 INFO 140641976874816] Number of GPUs being used: 0
# #metrics {"StartTime": 1644041745.0427694, "EndTime": 1644041745.0428035, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "Meta": "init_train_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 12000.0, "count": 1, "min": 12000, "max": 12000}, "Total Batches Seen": {"sum": 12.0, "count": 1, "min": 12, "max": 12}, "Max Records Seen Between Resets": {"sum": 11000.0, "count": 1, "min": 11000, "max": 11000}, "Max Batches Seen Between Resets": {"sum": 11.0, "count": 1, "min": 11, "max": 11}, "Reset Count": {"sum": 2.0, "count": 1, "min": 2, "max": 2}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
#
# 2022-02-05 06:15:49 Training - Training image download completed. Training in progress.[2022-02-05 06:15:52.178] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 3, "duration": 7135, "num_examples": 200, "num_bytes": 33493152}
# #metrics {"StartTime": 1644041752.1788602, "EndTime": 1644041752.178947, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 0}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5791407177028943, "count": 1, "min": 0.5791407177028943, "max": 0.5791407177028943}}}
# #metrics {"StartTime": 1644041752.1790264, "EndTime": 1644041752.1790407, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 1}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.4759549259971734, "count": 1, "min": 0.4759549259971734, "max": 0.4759549259971734}}}
# #metrics {"StartTime": 1644041752.179081, "EndTime": 1644041752.1790912, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 2}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.4948354150206599, "count": 1, "min": 0.4948354150206599, "max": 0.4948354150206599}}}
# #metrics {"StartTime": 1644041752.1791265, "EndTime": 1644041752.1791365, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 3}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5374999441789023, "count": 1, "min": 0.5374999441789023, "max": 0.5374999441789023}}}
# #metrics {"StartTime": 1644041752.1791704, "EndTime": 1644041752.1791794, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 4}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6132990110579447, "count": 1, "min": 0.6132990110579447, "max": 0.6132990110579447}}}
# #metrics {"StartTime": 1644041752.1792405, "EndTime": 1644041752.1792533, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 5}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.650242357378629, "count": 1, "min": 0.650242357378629, "max": 0.650242357378629}}}
# #metrics {"StartTime": 1644041752.1792903, "EndTime": 1644041752.1793, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 6}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6198758794314897, "count": 1, "min": 0.6198758794314897, "max": 0.6198758794314897}}}
# #metrics {"StartTime": 1644041752.1793332, "EndTime": 1644041752.1793423, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 7}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.642763320194417, "count": 1, "min": 0.642763320194417, "max": 0.642763320194417}}}
# #metrics {"StartTime": 1644041752.179375, "EndTime": 1644041752.179384, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 8}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.4923872120919539, "count": 1, "min": 0.4923872120919539, "max": 0.4923872120919539}}}
# #metrics {"StartTime": 1644041752.1794164, "EndTime": 1644041752.1794255, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 9}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5910773196579823, "count": 1, "min": 0.5910773196579823, "max": 0.5910773196579823}}}
# #metrics {"StartTime": 1644041752.179458, "EndTime": 1644041752.1794667, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 10}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5660034152850434, "count": 1, "min": 0.5660034152850434, "max": 0.5660034152850434}}}
# #metrics {"StartTime": 1644041752.179499, "EndTime": 1644041752.1795187, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 11}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.570866738247512, "count": 1, "min": 0.570866738247512, "max": 0.570866738247512}}}
# #metrics {"StartTime": 1644041752.1795497, "EndTime": 1644041752.1795585, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 12}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.603102036327573, "count": 1, "min": 0.603102036327573, "max": 0.603102036327573}}}
# #metrics {"StartTime": 1644041752.1795924, "EndTime": 1644041752.1796021, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 13}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6313092581015736, "count": 1, "min": 0.6313092581015736, "max": 0.6313092581015736}}}
# #metrics {"StartTime": 1644041752.1796346, "EndTime": 1644041752.1796434, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 14}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6069122777967597, "count": 1, "min": 0.6069122777967597, "max": 0.6069122777967597}}}
# #metrics {"StartTime": 1644041752.1796749, "EndTime": 1644041752.179684, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 15}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6302709089116235, "count": 1, "min": 0.6302709089116235, "max": 0.6302709089116235}}}
# #metrics {"StartTime": 1644041752.1797154, "EndTime": 1644041752.1797242, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 16}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6274360078591198, "count": 1, "min": 0.6274360078591198, "max": 0.6274360078591198}}}
# #metrics {"StartTime": 1644041752.1797552, "EndTime": 1644041752.179764, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 17}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.512769868476906, "count": 1, "min": 0.512769868476906, "max": 0.512769868476906}}}
# #metrics {"StartTime": 1644041752.179795, "EndTime": 1644041752.1798036, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 18}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5364223231790054, "count": 1, "min": 0.5364223231790054, "max": 0.5364223231790054}}}
# #metrics {"StartTime": 1644041752.179835, "EndTime": 1644041752.179844, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 19}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5448161246141596, "count": 1, "min": 0.5448161246141596, "max": 0.5448161246141596}}}
# #metrics {"StartTime": 1644041752.179875, "EndTime": 1644041752.1798835, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 20}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.540332931163922, "count": 1, "min": 0.540332931163922, "max": 0.540332931163922}}}
# #metrics {"StartTime": 1644041752.1799147, "EndTime": 1644041752.1799233, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 21}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.541313360655128, "count": 1, "min": 0.541313360655128, "max": 0.541313360655128}}}
# #metrics {"StartTime": 1644041752.1799545, "EndTime": 1644041752.1799629, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 22}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.536809625117623, "count": 1, "min": 0.536809625117623, "max": 0.536809625117623}}}
# #metrics {"StartTime": 1644041752.179996, "EndTime": 1644041752.180005, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 23}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5356268091920632, "count": 1, "min": 0.5356268091920632, "max": 0.5356268091920632}}}
# #metrics {"StartTime": 1644041752.1800368, "EndTime": 1644041752.1800456, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 24}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.081357410986819, "count": 1, "min": 1.081357410986819, "max": 1.081357410986819}}}
# #metrics {"StartTime": 1644041752.180077, "EndTime": 1644041752.1800857, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 25}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.0807654687315975, "count": 1, "min": 1.0807654687315975, "max": 1.0807654687315975}}}
# #metrics {"StartTime": 1644041752.180117, "EndTime": 1644041752.180126, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 26}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.107846775994229, "count": 1, "min": 1.107846775994229, "max": 1.107846775994229}}}
# #metrics {"StartTime": 1644041752.1801593, "EndTime": 1644041752.1801713, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 27}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.0852037635688208, "count": 1, "min": 1.0852037635688208, "max": 1.0852037635688208}}}
# #metrics {"StartTime": 1644041752.1801999, "EndTime": 1644041752.180208, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 28}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.2230319136423082, "count": 1, "min": 1.2230319136423082, "max": 1.2230319136423082}}}
# #metrics {"StartTime": 1644041752.1802301, "EndTime": 1644041752.180237, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 29}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.240264271721768, "count": 1, "min": 1.240264271721768, "max": 1.240264271721768}}}
# #metrics {"StartTime": 1644041752.1802583, "EndTime": 1644041752.180265, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 30}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.2185808203615736, "count": 1, "min": 1.2185808203615736, "max": 1.2185808203615736}}}
# #metrics {"StartTime": 1644041752.1802864, "EndTime": 1644041752.180293, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 31}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.2268015014801792, "count": 1, "min": 1.2268015014801792, "max": 1.2268015014801792}}}
# [02/05/2022 06:15:52 INFO 140641976874816] #quality_metric: host=algo-1, epoch=0, train binary_classification_weighted_cross_entropy_objective <loss>=0.5791407177028943
# [02/05/2022 06:15:52 INFO 140641976874816] #early_stopping_criteria_metric: host=algo-1, epoch=0, criteria=binary_classification_weighted_cross_entropy_objective, value=0.4759549259971734
# [02/05/2022 06:15:52 INFO 140641976874816] Epoch 0: Loss improved. Updating best model
# [02/05/2022 06:15:52 INFO 140641976874816] Saving model for epoch: 0
# [02/05/2022 06:15:52 INFO 140641976874816] Saved checkpoint to "/tmp/tmp9464npt9/mx-mod-0000.params"
# [02/05/2022 06:15:52 INFO 140641976874816] #progress_metric: host=algo-1, completed 6.666666666666667 % of epochs
# #metrics {"StartTime": 1644041745.0430667, "EndTime": 1644041752.1936922, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 211364.0, "count": 1, "min": 211364, "max": 211364}, "Total Batches Seen": {"sum": 212.0, "count": 1, "min": 212, "max": 212}, "Max Records Seen Between Resets": {"sum": 199364.0, "count": 1, "min": 199364, "max": 199364}, "Max Batches Seen Between Resets": {"sum": 200.0, "count": 1, "min": 200, "max": 200}, "Reset Count": {"sum": 3.0, "count": 1, "min": 3, "max": 3}, "Number of Records Since Last Reset": {"sum": 199364.0, "count": 1, "min": 199364, "max": 199364}, "Number of Batches Since Last Reset": {"sum": 200.0, "count": 1, "min": 200, "max": 200}}}
# [02/05/2022 06:15:52 INFO 140641976874816] #throughput_metric: host=algo-1, train throughput=27880.229891262887 records/second
# [2022-02-05 06:15:59.352] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 5, "duration": 7157, "num_examples": 200, "num_bytes": 33493152}
# #metrics {"StartTime": 1644041759.3523293, "EndTime": 1644041759.352413, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 0}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.3762333395109704, "count": 1, "min": 0.3762333395109704, "max": 0.3762333395109704}}}
# #metrics {"StartTime": 1644041759.3524837, "EndTime": 1644041759.3525019, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 1}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.3452077499849712, "count": 1, "min": 0.3452077499849712, "max": 0.3452077499849712}}}
# #metrics {"StartTime": 1644041759.352553, "EndTime": 1644041759.3525686, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 2}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.3545212267391646, "count": 1, "min": 0.3545212267391646, "max": 0.3545212267391646}}}
# #metrics {"StartTime": 1644041759.352614, "EndTime": 1644041759.3526244, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 3}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.358282039009746, "count": 1, "min": 0.358282039009746, "max": 0.358282039009746}}}
# #metrics {"StartTime": 1644041759.352668, "EndTime": 1644041759.3526835, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 4}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.503855560801137, "count": 1, "min": 0.503855560801137, "max": 0.503855560801137}}}
# #metrics {"StartTime": 1644041759.3527267, "EndTime": 1644041759.3527365, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 5}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5762882809279553, "count": 1, "min": 0.5762882809279553, "max": 0.5762882809279553}}}
# #metrics {"StartTime": 1644041759.3527822, "EndTime": 1644041759.3527977, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 6}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5095617222809912, "count": 1, "min": 0.5095617222809912, "max": 0.5095617222809912}}}
# #metrics {"StartTime": 1644041759.3528326, "EndTime": 1644041759.3528416, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 7}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5621733702846508, "count": 1, "min": 0.5621733702846508, "max": 0.5621733702846508}}}
# #metrics {"StartTime": 1644041759.3528678, "EndTime": 1644041759.3528788, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 8}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.35608179332023887, "count": 1, "min": 0.35608179332023887, "max": 0.35608179332023887}}}
# #metrics {"StartTime": 1644041759.3529139, "EndTime": 1644041759.3529272, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 9}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.37639001955578677, "count": 1, "min": 0.37639001955578677, "max": 0.37639001955578677}}}
# #metrics {"StartTime": 1644041759.3529732, "EndTime": 1644041759.3529894, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 10}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.3734735677901225, "count": 1, "min": 0.3734735677901225, "max": 0.3734735677901225}}}
# #metrics {"StartTime": 1644041759.3530273, "EndTime": 1644041759.3530364, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 11}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.3714105723778806, "count": 1, "min": 0.3714105723778806, "max": 0.3714105723778806}}}
# #metrics {"StartTime": 1644041759.353085, "EndTime": 1644041759.353094, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 12}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.4968251642581806, "count": 1, "min": 0.4968251642581806, "max": 0.4968251642581806}}}
# #metrics {"StartTime": 1644041759.3531203, "EndTime": 1644041759.3531275, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 13}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5793348179342759, "count": 1, "min": 0.5793348179342759, "max": 0.5793348179342759}}}
# #metrics {"StartTime": 1644041759.3531601, "EndTime": 1644041759.3531737, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 14}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5010429530119777, "count": 1, "min": 0.5010429530119777, "max": 0.5010429530119777}}}
# #metrics {"StartTime": 1644041759.353215, "EndTime": 1644041759.3532243, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 15}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5806286224671944, "count": 1, "min": 0.5806286224671944, "max": 0.5806286224671944}}}
# #metrics {"StartTime": 1644041759.3532476, "EndTime": 1644041759.3532546, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 16}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.45959482746986885, "count": 1, "min": 0.45959482746986885, "max": 0.45959482746986885}}}
# #metrics {"StartTime": 1644041759.353277, "EndTime": 1644041759.3532836, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 17}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.45221469054869073, "count": 1, "min": 0.45221469054869073, "max": 0.45221469054869073}}}
# #metrics {"StartTime": 1644041759.3533053, "EndTime": 1644041759.3533118, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 18}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.4510753076447913, "count": 1, "min": 0.4510753076447913, "max": 0.4510753076447913}}}
# #metrics {"StartTime": 1644041759.353334, "EndTime": 1644041759.3533459, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 19}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.45293791068379, "count": 1, "min": 0.45293791068379, "max": 0.45293791068379}}}
# #metrics {"StartTime": 1644041759.353392, "EndTime": 1644041759.3534067, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 20}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.513988640119083, "count": 1, "min": 0.513988640119083, "max": 0.513988640119083}}}
# #metrics {"StartTime": 1644041759.3534546, "EndTime": 1644041759.3534706, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 21}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5301194904844965, "count": 1, "min": 0.5301194904844965, "max": 0.5301194904844965}}}
# #metrics {"StartTime": 1644041759.3535197, "EndTime": 1644041759.3535345, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 22}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5141575448309357, "count": 1, "min": 0.5141575448309357, "max": 0.5141575448309357}}}
# #metrics {"StartTime": 1644041759.3535836, "EndTime": 1644041759.353628, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 23}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5306000879949062, "count": 1, "min": 0.5306000879949062, "max": 0.5306000879949062}}}
# #metrics {"StartTime": 1644041759.353685, "EndTime": 1644041759.3537016, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 24}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.0809531622651833, "count": 1, "min": 1.0809531622651833, "max": 1.0809531622651833}}}
# #metrics {"StartTime": 1644041759.353752, "EndTime": 1644041759.3537667, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 25}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.0806157694294225, "count": 1, "min": 1.0806157694294225, "max": 1.0806157694294225}}}
# #metrics {"StartTime": 1644041759.3538268, "EndTime": 1644041759.3538437, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 26}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.0811927944164181, "count": 1, "min": 1.0811927944164181, "max": 1.0811927944164181}}}
# #metrics {"StartTime": 1644041759.353895, "EndTime": 1644041759.3539116, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 27}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.0806420212942152, "count": 1, "min": 1.0806420212942152, "max": 1.0806420212942152}}}
# #metrics {"StartTime": 1644041759.353969, "EndTime": 1644041759.3539858, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 28}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.1822309901558574, "count": 1, "min": 1.1822309901558574, "max": 1.1822309901558574}}}
# #metrics {"StartTime": 1644041759.3540435, "EndTime": 1644041759.35406, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 29}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.2228483647485475, "count": 1, "min": 1.2228483647485475, "max": 1.2228483647485475}}}
# #metrics {"StartTime": 1644041759.3541107, "EndTime": 1644041759.3541255, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 30}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.1816888533549093, "count": 1, "min": 1.1816888533549093, "max": 1.1816888533549093}}}
# #metrics {"StartTime": 1644041759.354176, "EndTime": 1644041759.354191, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 31}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.2195927194566583, "count": 1, "min": 1.2195927194566583, "max": 1.2195927194566583}}}
# [02/05/2022 06:15:59 INFO 140641976874816] #quality_metric: host=algo-1, epoch=1, train binary_classification_weighted_cross_entropy_objective <loss>=0.3762333395109704
# [02/05/2022 06:15:59 INFO 140641976874816] #early_stopping_criteria_metric: host=algo-1, epoch=1, criteria=binary_classification_weighted_cross_entropy_objective, value=0.3452077499849712
# [02/05/2022 06:15:59 INFO 140641976874816] Epoch 1: Loss improved. Updating best model
# [02/05/2022 06:15:59 INFO 140641976874816] Saving model for epoch: 1
# [02/05/2022 06:15:59 INFO 140641976874816] Saved checkpoint to "/tmp/tmpwsoq01je/mx-mod-0000.params"
# [02/05/2022 06:15:59 INFO 140641976874816] #progress_metric: host=algo-1, completed 13.333333333333334 % of epochs
# #metrics {"StartTime": 1644041752.1949744, "EndTime": 1644041759.3630176, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 410728.0, "count": 1, "min": 410728, "max": 410728}, "Total Batches Seen": {"sum": 412.0, "count": 1, "min": 412, "max": 412}, "Max Records Seen Between Resets": {"sum": 199364.0, "count": 1, "min": 199364, "max": 199364}, "Max Batches Seen Between Resets": {"sum": 200.0, "count": 1, "min": 200, "max": 200}, "Reset Count": {"sum": 4.0, "count": 1, "min": 4, "max": 4}, "Number of Records Since Last Reset": {"sum": 199364.0, "count": 1, "min": 199364, "max": 199364}, "Number of Batches Since Last Reset": {"sum": 200.0, "count": 1, "min": 200, "max": 200}}}
# [02/05/2022 06:15:59 INFO 140641976874816] #throughput_metric: host=algo-1, train throughput=27812.493799962154 records/second
# [2022-02-05 06:16:06.789] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 7, "duration": 7426, "num_examples": 200, "num_bytes": 33493152}
# #metrics {"StartTime": 1644041766.78996, "EndTime": 1644041766.7900755, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 0}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.3391149269755761, "count": 1, "min": 0.3391149269755761, "max": 0.3391149269755761}}}
# #metrics {"StartTime": 1644041766.7901607, "EndTime": 1644041766.790182, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 1}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.3195404147047493, "count": 1, "min": 0.3195404147047493, "max": 0.3195404147047493}}}
# #metrics {"StartTime": 1644041766.79024, "EndTime": 1644041766.7902584, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 2}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.32698557615040535, "count": 1, "min": 0.32698557615040535, "max": 0.32698557615040535}}}
# #metrics {"StartTime": 1644041766.790315, "EndTime": 1644041766.7903342, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 3}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.3274032881846979, "count": 1, "min": 0.3274032881846979, "max": 0.3274032881846979}}}
# #metrics {"StartTime": 1644041766.7903862, "EndTime": 1644041766.790402, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 4}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.4777964639903313, "count": 1, "min": 0.4777964639903313, "max": 0.4777964639903313}}}
# #metrics {"StartTime": 1644041766.7904534, "EndTime": 1644041766.7904701, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 5}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.590638911990065, "count": 1, "min": 0.590638911990065, "max": 0.590638911990065}}}
# #metrics {"StartTime": 1644041766.7905219, "EndTime": 1644041766.790539, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 6}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.48253254189802774, "count": 1, "min": 0.48253254189802774, "max": 0.48253254189802774}}}
# #metrics {"StartTime": 1644041766.79059, "EndTime": 1644041766.7906058, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 7}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6031271160259918, "count": 1, "min": 0.6031271160259918, "max": 0.6031271160259918}}}
# #metrics {"StartTime": 1644041766.7906675, "EndTime": 1644041766.7906823, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 8}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.3290663219432735, "count": 1, "min": 0.3290663219432735, "max": 0.3290663219432735}}}
# #metrics {"StartTime": 1644041766.7907324, "EndTime": 1644041766.7907481, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 9}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.33843334504707373, "count": 1, "min": 0.33843334504707373, "max": 0.33843334504707373}}}
# #metrics {"StartTime": 1644041766.7907972, "EndTime": 1644041766.7908132, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 10}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.33953402284401746, "count": 1, "min": 0.33953402284401746, "max": 0.33953402284401746}}}
# #metrics {"StartTime": 1644041766.7908626, "EndTime": 1644041766.7908795, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 11}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.3347382457100566, "count": 1, "min": 0.3347382457100566, "max": 0.3347382457100566}}}
# #metrics {"StartTime": 1644041766.7909288, "EndTime": 1644041766.7909439, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 12}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.43369665937567475, "count": 1, "min": 0.43369665937567475, "max": 0.43369665937567475}}}
# #metrics {"StartTime": 1644041766.7909913, "EndTime": 1644041766.7910073, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 13}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5582932119513276, "count": 1, "min": 0.5582932119513276, "max": 0.5582932119513276}}}
# #metrics {"StartTime": 1644041766.791054, "EndTime": 1644041766.7910686, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 14}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.40992417111229057, "count": 1, "min": 0.40992417111229057, "max": 0.40992417111229057}}}
# #metrics {"StartTime": 1644041766.791117, "EndTime": 1644041766.7911327, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 15}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5464452117843245, "count": 1, "min": 0.5464452117843245, "max": 0.5464452117843245}}}
# #metrics {"StartTime": 1644041766.7911909, "EndTime": 1644041766.7912292, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 16}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.44801290402819766, "count": 1, "min": 0.44801290402819766, "max": 0.44801290402819766}}}
# #metrics {"StartTime": 1644041766.7912862, "EndTime": 1644041766.7913034, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 17}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.4507313074466571, "count": 1, "min": 0.4507313074466571, "max": 0.4507313074466571}}}
# #metrics {"StartTime": 1644041766.7913623, "EndTime": 1644041766.7913792, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 18}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.4471608550872036, "count": 1, "min": 0.4471608550872036, "max": 0.4471608550872036}}}
# #metrics {"StartTime": 1644041766.791432, "EndTime": 1644041766.791448, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 19}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.4506483911868915, "count": 1, "min": 0.4506483911868915, "max": 0.4506483911868915}}}
# #metrics {"StartTime": 1644041766.791507, "EndTime": 1644041766.7915244, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 20}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5034817837087353, "count": 1, "min": 0.5034817837087353, "max": 0.5034817837087353}}}
# #metrics {"StartTime": 1644041766.7915773, "EndTime": 1644041766.7915943, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 21}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5302559648638394, "count": 1, "min": 0.5302559648638394, "max": 0.5302559648638394}}}
# #metrics {"StartTime": 1644041766.7916524, "EndTime": 1644041766.7916691, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 22}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5034230974091957, "count": 1, "min": 0.5034230974091957, "max": 0.5034230974091957}}}
# #metrics {"StartTime": 1644041766.7917223, "EndTime": 1644041766.7917395, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 23}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.531876334511455, "count": 1, "min": 0.531876334511455, "max": 0.531876334511455}}}
# #metrics {"StartTime": 1644041766.7917888, "EndTime": 1644041766.7918053, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 24}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.080485231179089, "count": 1, "min": 1.080485231179089, "max": 1.080485231179089}}}
# #metrics {"StartTime": 1644041766.79185, "EndTime": 1644041766.7918658, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 25}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.0806065483668341, "count": 1, "min": 1.0806065483668341, "max": 1.0806065483668341}}}
# #metrics {"StartTime": 1644041766.7919142, "EndTime": 1644041766.7919307, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 26}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.080347275623724, "count": 1, "min": 1.080347275623724, "max": 1.080347275623724}}}
# #metrics {"StartTime": 1644041766.791981, "EndTime": 1644041766.7919972, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 27}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.0807068119528305, "count": 1, "min": 1.0807068119528305, "max": 1.0807068119528305}}}
# #metrics {"StartTime": 1644041766.792046, "EndTime": 1644041766.7920625, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 28}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.1454150128388525, "count": 1, "min": 1.1454150128388525, "max": 1.1454150128388525}}}
# #metrics {"StartTime": 1644041766.7921154, "EndTime": 1644041766.7921307, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 29}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.2139291877171503, "count": 1, "min": 1.2139291877171503, "max": 1.2139291877171503}}}
# #metrics {"StartTime": 1644041766.7921848, "EndTime": 1644041766.7921996, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 30}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.1451639179632291, "count": 1, "min": 1.1451639179632291, "max": 1.1451639179632291}}}
# #metrics {"StartTime": 1644041766.792248, "EndTime": 1644041766.7922637, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 31}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.2131926508764526, "count": 1, "min": 1.2131926508764526, "max": 1.2131926508764526}}}
# [02/05/2022 06:16:06 INFO 140641976874816] #quality_metric: host=algo-1, epoch=2, train binary_classification_weighted_cross_entropy_objective <loss>=0.3391149269755761
# [02/05/2022 06:16:06 INFO 140641976874816] #early_stopping_criteria_metric: host=algo-1, epoch=2, criteria=binary_classification_weighted_cross_entropy_objective, value=0.3195404147047493
# [02/05/2022 06:16:06 INFO 140641976874816] Epoch 2: Loss improved. Updating best model
# [02/05/2022 06:16:06 INFO 140641976874816] Saving model for epoch: 2
# [02/05/2022 06:16:06 INFO 140641976874816] Saved checkpoint to "/tmp/tmpkvqo1oir/mx-mod-0000.params"
# [02/05/2022 06:16:06 INFO 140641976874816] #progress_metric: host=algo-1, completed 20.0 % of epochs
# #metrics {"StartTime": 1644041759.3632834, "EndTime": 1644041766.8018477, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 610092.0, "count": 1, "min": 610092, "max": 610092}, "Total Batches Seen": {"sum": 612.0, "count": 1, "min": 612, "max": 612}, "Max Records Seen Between Resets": {"sum": 199364.0, "count": 1, "min": 199364, "max": 199364}, "Max Batches Seen Between Resets": {"sum": 200.0, "count": 1, "min": 200, "max": 200}, "Reset Count": {"sum": 5.0, "count": 1, "min": 5, "max": 5}, "Number of Records Since Last Reset": {"sum": 199364.0, "count": 1, "min": 199364, "max": 199364}, "Number of Batches Since Last Reset": {"sum": 200.0, "count": 1, "min": 200, "max": 200}}}
# [02/05/2022 06:16:06 INFO 140641976874816] #throughput_metric: host=algo-1, train throughput=26800.87584818312 records/second
# [2022-02-05 06:16:13.378] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 9, "duration": 6574, "num_examples": 200, "num_bytes": 33493152}
# #metrics {"StartTime": 1644041773.3781104, "EndTime": 1644041773.378194, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 0}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.32226599174767884, "count": 1, "min": 0.32226599174767884, "max": 0.32226599174767884}}}
# #metrics {"StartTime": 1644041773.3782804, "EndTime": 1644041773.3782992, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 1}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.3074733453491824, "count": 1, "min": 0.3074733453491824, "max": 0.3074733453491824}}}
# ...
# #metrics {"StartTime": 1644041847.8301787, "EndTime": 1644041847.830197, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 5}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5330752930856829, "count": 1, "min": 0.5330752930856829, "max": 0.5330752930856829}}}
# #metrics {"StartTime": 1644041847.83026, "EndTime": 1644041847.8302782, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 6}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.28378996158005604, "count": 1, "min": 0.28378996158005604, "max": 0.28378996158005604}}}
# #metrics {"StartTime": 1644041847.8303313, "EndTime": 1644041847.8303585, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 7}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.47326236121019527, "count": 1, "min": 0.47326236121019527, "max": 0.47326236121019527}}}
# #metrics {"StartTime": 1644041847.8304071, "EndTime": 1644041847.8304236, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 8}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.29130650279749576, "count": 1, "min": 0.29130650279749576, "max": 0.29130650279749576}}}
# #metrics {"StartTime": 1644041847.8304737, "EndTime": 1644041847.8304908, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 9}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.29114658903955815, "count": 1, "min": 0.29114658903955815, "max": 0.29114658903955815}}}
# #metrics {"StartTime": 1644041847.83054, "EndTime": 1644041847.8305564, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 10}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.29353761303005504, "count": 1, "min": 0.29353761303005504, "max": 0.29353761303005504}}}
# #metrics {"StartTime": 1644041847.8306048, "EndTime": 1644041847.8306208, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 11}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.2908794963204082, "count": 1, "min": 0.2908794963204082, "max": 0.2908794963204082}}}
# #metrics {"StartTime": 1644041847.8306732, "EndTime": 1644041847.8306887, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 12}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.2914942595515419, "count": 1, "min": 0.2914942595515419, "max": 0.2914942595515419}}}
# #metrics {"StartTime": 1644041847.83075, "EndTime": 1644041847.8307676, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 13}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.4870187229367357, "count": 1, "min": 0.4870187229367357, "max": 0.4870187229367357}}}
# #metrics {"StartTime": 1644041847.8308272, "EndTime": 1644041847.8308442, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 14}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.2914134636116986, "count": 1, "min": 0.2914134636116986, "max": 0.2914134636116986}}}
# #metrics {"StartTime": 1644041847.8308978, "EndTime": 1644041847.830909, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 15}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.49398941992754913, "count": 1, "min": 0.49398941992754913, "max": 0.49398941992754913}}}
# #metrics {"StartTime": 1644041847.8309422, "EndTime": 1644041847.830951, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 16}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.4376009713177705, "count": 1, "min": 0.4376009713177705, "max": 0.4376009713177705}}}
# #metrics {"StartTime": 1644041847.8309963, "EndTime": 1644041847.831011, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 17}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.4484181482516342, "count": 1, "min": 0.4484181482516342, "max": 0.4484181482516342}}}
# #metrics {"StartTime": 1644041847.831062, "EndTime": 1644041847.8310783, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 18}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.43762711445410646, "count": 1, "min": 0.43762711445410646, "max": 0.43762711445410646}}}
# #metrics {"StartTime": 1644041847.8311253, "EndTime": 1644041847.8311417, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 19}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.44841468803367424, "count": 1, "min": 0.44841468803367424, "max": 0.44841468803367424}}}
# #metrics {"StartTime": 1644041847.8312235, "EndTime": 1644041847.8312404, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 20}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.45202172866897966, "count": 1, "min": 0.45202172866897966, "max": 0.45202172866897966}}}
# #metrics {"StartTime": 1644041847.8312788, "EndTime": 1644041847.831288, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 21}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5203195825893077, "count": 1, "min": 0.5203195825893077, "max": 0.5203195825893077}}}
# #metrics {"StartTime": 1644041847.83132, "EndTime": 1644041847.8313332, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 22}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.4520227471739803, "count": 1, "min": 0.4520227471739803, "max": 0.4520227471739803}}}
# #metrics {"StartTime": 1644041847.8313606, "EndTime": 1644041847.8313732, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 23}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5202868180394772, "count": 1, "min": 0.5202868180394772, "max": 0.5202868180394772}}}
# #metrics {"StartTime": 1644041847.831426, "EndTime": 1644041847.831441, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 24}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.0734474260339786, "count": 1, "min": 1.0734474260339786, "max": 1.0734474260339786}}}
# #metrics {"StartTime": 1644041847.8314912, "EndTime": 1644041847.8315077, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 25}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.0808105422743601, "count": 1, "min": 1.0808105422743601, "max": 1.0808105422743601}}}
# #metrics {"StartTime": 1644041847.831558, "EndTime": 1644041847.8315723, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 26}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.073446477075318, "count": 1, "min": 1.073446477075318, "max": 1.073446477075318}}}
# #metrics {"StartTime": 1644041847.8316183, "EndTime": 1644041847.8316336, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 27}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.0808158106204853, "count": 1, "min": 1.0808158106204853, "max": 1.0808158106204853}}}
# #metrics {"StartTime": 1644041847.8316813, "EndTime": 1644041847.831697, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 28}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.081110000226965, "count": 1, "min": 1.081110000226965, "max": 1.081110000226965}}}
# #metrics {"StartTime": 1644041847.8317463, "EndTime": 1644041847.8317623, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 29}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.178819695554187, "count": 1, "min": 1.178819695554187, "max": 1.178819695554187}}}
# #metrics {"StartTime": 1644041847.83181, "EndTime": 1644041847.8318255, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 30}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.0811094335814817, "count": 1, "min": 1.0811094335814817, "max": 1.0811094335814817}}}
# #metrics {"StartTime": 1644041847.8318725, "EndTime": 1644041847.8318884, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 31}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.1788132949905779, "count": 1, "min": 1.1788132949905779, "max": 1.1788132949905779}}}
# [02/05/2022 06:17:27 INFO 140641976874816] #quality_metric: host=algo-1, epoch=14, train binary_classification_weighted_cross_entropy_objective <loss>=0.29068308453583835
# [02/05/2022 06:17:27 INFO 140641976874816] #early_stopping_criteria_metric: host=algo-1, epoch=14, criteria=binary_classification_weighted_cross_entropy_objective, value=0.28373790798474796
# [02/05/2022 06:17:27 INFO 140641976874816] Epoch 14: Loss improved. Updating best model
# [02/05/2022 06:17:27 INFO 140641976874816] Saving model for epoch: 14
# [02/05/2022 06:17:27 INFO 140641976874816] Saved checkpoint to "/tmp/tmphs08qu4g/mx-mod-0000.params"
# [02/05/2022 06:17:27 INFO 140641976874816] #progress_metric: host=algo-1, completed 100.0 % of epochs
# #metrics {"StartTime": 1644041841.175253, "EndTime": 1644041847.8406935, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 3002460.0, "count": 1, "min": 3002460, "max": 3002460}, "Total Batches Seen": {"sum": 3012.0, "count": 1, "min": 3012, "max": 3012}, "Max Records Seen Between Resets": {"sum": 199364.0, "count": 1, "min": 199364, "max": 199364}, "Max Batches Seen Between Resets": {"sum": 200.0, "count": 1, "min": 200, "max": 200}, "Reset Count": {"sum": 17.0, "count": 1, "min": 17, "max": 17}, "Number of Records Since Last Reset": {"sum": 199364.0, "count": 1, "min": 199364, "max": 199364}, "Number of Batches Since Last Reset": {"sum": 200.0, "count": 1, "min": 200, "max": 200}}}
# [02/05/2022 06:17:27 INFO 140641976874816] #throughput_metric: host=algo-1, train throughput=29909.538210299164 records/second
# [02/05/2022 06:17:27 WARNING 140641976874816] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [02/05/2022 06:17:27 WARNING 140641976874816] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [2022-02-05 06:17:27.845] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 33, "duration": 4, "num_examples": 1, "num_bytes": 168000}
# [2022-02-05 06:17:28.331] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 36, "duration": 482, "num_examples": 200, "num_bytes": 33493152}
# [2022-02-05 06:17:29.146] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 38, "duration": 740, "num_examples": 200, "num_bytes": 33493152}
# [02/05/2022 06:17:29 INFO 140641976874816] #train_score (algo-1) : ('binary_classification_weighted_cross_entropy_objective', 0.2687483957430368)
# [02/05/2022 06:17:29 INFO 140641976874816] #train_score (algo-1) : ('binary_classification_accuracy', 0.9913173892979675)
# [02/05/2022 06:17:29 INFO 140641976874816] #train_score (algo-1) : ('binary_f_1.000', 0.27177114009255365)
# [02/05/2022 06:17:29 INFO 140641976874816] #train_score (algo-1) : ('precision', 0.1599009900990099)
# [02/05/2022 06:17:29 INFO 140641976874816] #train_score (algo-1) : ('recall', 0.9047619047619048)
# [02/05/2022 06:17:29 INFO 140641976874816] #train_score (algo-1) : ('roc_auc_score', 0.9883347149127631)
# [02/05/2022 06:17:29 INFO 140641976874816] #train_score (algo-1) : ('binary_balanced_accuracy', 0.5)
# [02/05/2022 06:17:29 INFO 140641976874816] #train_score (algo-1) : ('binary_log_loss', 0.7326821872687728)
# [02/05/2022 06:17:29 INFO 140641976874816] #quality_metric: host=algo-1, train binary_classification_weighted_cross_entropy_objective <loss>=0.2687483957430368
# [02/05/2022 06:17:29 INFO 140641976874816] #quality_metric: host=algo-1, train binary_classification_accuracy <score>=0.9913173892979675
# [02/05/2022 06:17:29 INFO 140641976874816] #quality_metric: host=algo-1, train binary_f_1.000 <score>=0.27177114009255365
# [02/05/2022 06:17:29 INFO 140641976874816] #quality_metric: host=algo-1, train precision <score>=0.1599009900990099
# [02/05/2022 06:17:29 INFO 140641976874816] #quality_metric: host=algo-1, train recall <score>=0.9047619047619048
# [02/05/2022 06:17:29 INFO 140641976874816] #quality_metric: host=algo-1, train roc_auc_score <score>=0.9883347149127631
# [02/05/2022 06:17:29 INFO 140641976874816] #quality_metric: host=algo-1, train binary_balanced_accuracy <score>=0.5
# [02/05/2022 06:17:29 INFO 140641976874816] #quality_metric: host=algo-1, train binary_log_loss <score>=0.7326821872687728
# [02/05/2022 06:17:29 INFO 140641976874816] Best model found for hyperparameters: {"optimizer": "adam", "learning_rate": 0.1, "wd": 0.0001, "l1": 0.0, "lr_scheduler_step": 10, "lr_scheduler_factor": 0.99, "lr_scheduler_minimum_lr": 1e-05}
# [02/05/2022 06:17:29 INFO 140641976874816] Saved checkpoint to "/tmp/tmp85xg8c7t/mx-mod-0000.params"
# [02/05/2022 06:17:29 INFO 140641976874816] Test data is not provided.
# #metrics {"StartTime": 1644041744.7028008, "EndTime": 1644041849.4259408, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training"}, "Metrics": {"initialize.time": {"sum": 337.146520614624, "count": 1, "min": 337.146520614624, "max": 337.146520614624}, "epochs": {"sum": 15.0, "count": 1, "min": 15, "max": 15}, "check_early_stopping.time": {"sum": 14.511346817016602, "count": 15, "min": 0.8356571197509766, "max": 1.4789104461669922}, "update.time": {"sum": 102740.50426483154, "count": 15, "min": 6450.884819030762, "max": 7435.72998046875}, "finalize.time": {"sum": 1575.7887363433838, "count": 1, "min": 1575.7887363433838, "max": 1575.7887363433838}, "setuptime": {"sum": 24.166107177734375, "count": 1, "min": 24.166107177734375, "max": 24.166107177734375}, "totaltime": {"sum": 104943.90845298767, "count": 1, "min": 104943.90845298767, "max": 104943.90845298767}}}
#
# 2022-02-05 06:17:50 Completed - Training job completed
# ProfilerReport-1644041525: NoIssuesFound
# Training seconds: 147
# Billable seconds: 147
# CPU times: user 855 ms, sys: 60.8 ms, total: 916 ms
# Wall time: 6min 14s

# %%
# %%time 
# deploy and evaluate a predictor
my_predictor = my_learner.deploy(initial_instance_count=1, instance_type='ml.t2.medium')
# Out:
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# -------!CPU times: user 287 ms, sys: 12.8 ms, total: 300 ms
# Wall time: 3min 31s

# %%
print('Metrics for balanced, LinearLearner.\n')

# get metrics for balanced predictor
metrics = evaluate(my_predictor, 
                   test_features.values.astype('float32'), 
                   test_labels, 
                   verbose=True)
# Out:
# Metrics for balanced, LinearLearner.
#
# prediction (col)    0.0  1.0
# actual (row)
# 0                 84629  679
# 1                    18  117
#
# Recall:     0.867
# Precision:  0.147
# Accuracy:   0.992

# %%
## IMPORTANT
# delete the predictor endpoint after evaluation 
delete_endpoint(my_predictor)
# Out:
# The endpoint attribute has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The endpoint attribute has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# Deleted linear-learner-2022-02-05-06-18-20-000

# %% [markdown]
# ## Final Cleanup!
#
# * Double check that you have deleted all your endpoints.
# * I'd also suggest manually deleting your S3 bucket, models, and endpoint configurations directly from your AWS console.
#
# You can find thorough cleanup instructions, [in the documentation](https://docs.aws.amazon.com/sagemaker/latest/dg/ex1-cleanup.html).

# %% [markdown]
# ---
# # Conclusion
#
# In this notebook, you saw how to train and deploy a LinearLearner in SageMaker. This model is well-suited for a binary classification task that involves specific design decisions and managing class imbalance in the training set.
#
# Following the steps of a machine learning workflow, you loaded in some credit card transaction data, explored that data and prepared it for model training. Then trained, deployed, and evaluated several models, according to different design considerations!
