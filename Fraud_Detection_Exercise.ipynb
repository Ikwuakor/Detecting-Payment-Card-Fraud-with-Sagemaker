# %% [markdown]
# # Detecting Payment Card Fraud
#
# In this section, we'll look at a credit card fraud detection dataset, and build a binary classification model that can identify transactions as either fraudulent or valid, based on provided, *historical* data. In a [2016 study](https://nilsonreport.com/upload/content_promo/The_Nilson_Report_10-17-2016.pdf), it was estimated that credit card fraud was responsible for over 20 billion dollars in loss, worldwide. Accurately detecting cases of fraud is an ongoing area of research.
#
# <img src=notebook_ims/fraud_detection.png width=50% />
#
# ### Labeled Data
#
# The payment fraud data set (Dal Pozzolo et al. 2015) was downloaded from [Kaggle](https://www.kaggle.com/mlg-ulb/creditcardfraud/data). This has features and labels for thousands of credit card transactions, each of which is labeled as fraudulent or valid. In this notebook, we'd like to train a model based on the features of these transactions so that we can predict risky or fraudulent transactions in the future.
#
# ### Binary Classification
#
# Since we have true labels to aim for, we'll take a **supervised learning** approach and train a binary classifier to sort data into one of our two transaction classes: fraudulent or valid.  We'll train a model on training data and see how well it generalizes on some test data.
#
# The notebook will be broken down into a few steps:
# * Loading and exploring the data
# * Splitting the data into train/test sets
# * Defining and training a LinearLearner, binary classifier
# * Making improvements on the model
# * Evaluating and comparing model test performance
#
# ### Making Improvements
#
# A lot of this notebook will focus on making improvements, as discussed in [this SageMaker blog post](https://aws.amazon.com/blogs/machine-learning/train-faster-more-flexible-models-with-amazon-sagemaker-linear-learner/). Specifically, we'll address techniques for:
#
# 1. **Tuning a model's hyperparameters** and aiming for a specific metric, such as high recall or precision.
# 2. **Managing class imbalance**, which is when we have many more training examples in one class than another (in this case, many more valid transactions than fraudulent).
#
# ---

# %% [markdown]
# First, import the usual resources.

# %%
import io
import os
import matplotlib.pyplot as plt
import numpy as np 
import pandas as pd
from sklearn.model_selection import train_test_split

import boto3
import sagemaker
from sagemaker import get_execution_role

# %matplotlib inline

# %% [markdown]
# I'm storing my **SageMaker variables** in the next cell:
# * sagemaker_session: The SageMaker session we'll use for training models.
# * bucket: The name of the default S3 bucket that we'll use for data storage.
# * role: The IAM role that defines our data and model permissions.

# %%
# sagemaker session, role
sagemaker_session = sagemaker.Session()
role = sagemaker.get_execution_role()

# S3 bucket name
bucket = sagemaker_session.default_bucket()

# %% [markdown]
# ## Loading and Exploring the Data
#
# Next, I am loading the data and unzipping the data in the file `creditcardfraud.zip`. This directory will hold one csv file of all the transaction data, `creditcard.csv`.
#
# As in previous notebooks, it's important to look at the distribution of data since this will inform how we develop a fraud detection model. We'll want to know: How many data points we have to work with, the number and type of features, and finally, the distribution of data over the classes (valid or fraudulent).

# %%
# only have to run once
#!wget https://s3.amazonaws.com/video.udacity-data.com/topher/2019/January/5c534768_creditcardfraud/creditcardfraud.zip
#!unzip creditcardfraud

# %%
# read in the csv file
local_data = 'creditcard.csv'

# print out some data
transaction_df = pd.read_csv(local_data)
print('Data shape (rows, cols): ', transaction_df.shape)
print()
transaction_df.head()
# Out:
# Data shape (rows, cols):  (284807, 31)
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %% [markdown]
# ### EXERCISE: Calculate the percentage of fraudulent data
#
# Take a look at the distribution of this transaction data over the classes, valid and fraudulent.
#
# Complete the function `fraudulent_percentage`, below. Count up the number of data points in each class and calculate the *percentage* of the data points that are fraudulent.

# %%
# Calculate the fraction of data points that are fraudulent
def fraudulent_percentage(transaction_df):
    '''Calculate the fraction of all data points that have a 'Class' label of 1; fraudulent.
       :param transaction_df: Dataframe of all transaction data points; has a column 'Class'
       :return: A fractional percentage of fraudulent data points/all points
    '''
    
    # your code here
    
    return transaction_df[transaction_df['Class']==1].shape[0]/transaction_df.shape[0]

# %% [markdown]
# Test out your code by calling your function and printing the result.

# %%
# call the function to calculate the fraud percentage
fraud_percentage = fraudulent_percentage(transaction_df)

print('Fraudulent percentage = ', fraud_percentage)
print('Total # of fraudulent pts: ', fraud_percentage*transaction_df.shape[0])
print('Out of (total) pts: ', transaction_df.shape[0])
# Out:
# Fraudulent percentage =  0.001727485630620034
# Total # of fraudulent pts:  492.0
# Out of (total) pts:  284807

# %% [markdown]
# ### EXERCISE: Split into train/test datasets
#
# In this example, we'll want to evaluate the performance of a fraud classifier; training it on some training data and testing it on *test data* that it did not see during the training process. So, we'll need to split the data into separate training and test sets.
#
# Complete the `train_test_split` function, below. This function should:
# * Shuffle the transaction data, randomly
# * Split it into two sets according to the parameter `train_frac`
# * Get train/test features and labels
# * Return the tuples: (train_features, train_labels), (test_features, test_labels)

# %%
# split into train/test
def split_data(transaction_df, test_size= 0.3, random_state=1):
    '''Shuffle the data and randomly split into train and test sets;
       separate the class labels (the column in transaction_df) from the features.
       :param df: Dataframe of all credit card transaction data
       :param train_frac: The decimal fraction of data that should be training data
       :param seed: Random seed for shuffling and reproducibility, default = 1
       :return: train_features, train_labels test_features, test_labels
       '''
    X = transaction_df.drop('Class', axis=1)
    y = transaction_df['Class']
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=random_state)
    
    # shuffle and split the data
    train_features = X_train
    train_labels = y_train
    test_features = X_test
    test_labels = y_test
    
    return train_features, test_features, train_labels, test_labels

# %% [markdown]
# ### Test Cell
#
# In the cells below, I'm creating the train/test data and checking to see that result makes sense. The tests below test that the above function splits the data into the expected number of points and that the labels are indeed, class labels (0, 1).

# %%
# get train/test data
train_features, test_features, train_labels, test_labels = split_data(transaction_df, test_size=0.3, random_state=1)

# %%
# manual test

# for a split of 0.7:0.3 there should be ~2.33x as many training as test pts
print('Training data pts: ', len(train_features))
print('Test data pts: ', len(test_features))
print()

# take a look at first item and see that it aligns with first row of data
print('First item: \n', train_features.iloc[0,:].values)
print('Label: ', train_labels[0])
print()

# test split
assert len(train_features) > 2.333*len(test_features), \
        'Unexpected number of train/test points for a train_frac=0.7'
# test labels
assert np.all(train_labels)== 0 or np.all(train_labels)== 1, \
        'Train labels should be 0s or 1s.'
assert np.all(test_labels)== 0 or np.all(test_labels)== 1, \
        'Test labels should be 0s or 1s.'
print('Tests passed!')
# Out:
# Training data pts:  199364
# Test data pts:  85443
#
# First item:
#  [ 1.29124000e+05 -1.90075436e-01  2.03322731e-01 -9.96232474e-01
#  -1.59698524e+00  3.19257862e+00  3.35693491e+00  2.88299308e-01
#   8.95002799e-01 -3.30023995e-01 -6.46900440e-01 -2.82784848e-01
#   2.32409086e-02 -4.21091590e-01  3.68246970e-01 -1.58464836e-01
#  -3.34755915e-01 -3.37179916e-01 -8.42032397e-01 -3.30126357e-02
#  -7.49605900e-03 -1.70598909e-01 -6.19723542e-01  3.96512932e-02
#   7.06805166e-01 -1.60869712e-01  2.74824647e-01 -1.05414134e-02
#   2.21991577e-02  1.43700000e+01]
# Label:  0
#
# Tests passed!

# %% [markdown]
# ---
# # Modeling
#
# Now that you've uploaded your training data, it's time to define and train a model!
#
# In this notebook, you'll define and train the SageMaker, built-in algorithm, [LinearLearner](https://sagemaker.readthedocs.io/en/stable/linear_learner.html).
#
# A LinearLearner has two main applications:
# 1. For regression tasks in which a linear line is fit to some data points, and you want to produce a predicted output value given some data point (example: predicting house prices given square area).
# 2. For binary classification, in which a line is separating two classes of data and effectively outputs labels; either 1 for data that falls above the line or 0 for points that fall on or below the line.
#
# <img src='notebook_ims/linear_separator.png' width=50% />
#
# In this case, we'll be using it for case 2, and we'll train it to separate data into our two classes: valid or fraudulent.

# %% [markdown]
# ### EXERCISE: Create a LinearLearner Estimator
#
# You've had some practice instantiating built-in models in SageMaker. All estimators require some constructor arguments to be passed in. See if you can complete this task, instantiating a LinearLearner estimator, using only the [LinearLearner documentation](https://sagemaker.readthedocs.io/en/stable/linear_learner.html) as a resource. This takes in a lot of arguments, but not all are required. My suggestion is to start with a simple model, utilizing default values where applicable. Later, we will discuss some specific hyperparameters and their use cases.
#
# #### Instance Types
#
# It is suggested that you use instances that are available in the free tier of usage: `'ml.c4.xlarge'` for training and `'ml.t2.medium'` for deployment.

# %%
# import LinearLearner
from sagemaker import LinearLearner

prefix = 'creditcard'
output_path = f's3://{bucket}/{prefix}'

# instantiate LinearLearner
lin_SM = LinearLearner(role=role,
                       instance_count=1,
                       instance_type='ml.c4.xlarge',
                       predictor_type='binary_classifier',
                       output_path=output_path,
                       sagemaker_session=sagemaker_session,
                       epochs=15)

# %% [markdown]
# ### EXERCISE: Convert data into a RecordSet format
#
# Next, prepare the data for a built-in model by converting the train features and labels into numpy array's of float values. Then you can use the [record_set function](https://sagemaker.readthedocs.io/en/stable/linear_learner.html#sagemaker.LinearLearner.record_set) to format the data as a RecordSet and prepare it for training!

# %%
# create RecordSet of training data
train_features_np = train_features.values.astype('float32')
train_labels_np = train_labels.values.astype('float32')

formatted_train_data = lin_SM.record_set(train_features_np, train_labels_np)

# %% [markdown]
# ### EXERCISE: Train the Estimator
#
# After instantiating your estimator, train it with a call to `.fit()`, passing in the formatted training data.

# %%
# %%time 
# train the estimator on formatted training data
lin_SM.fit(formatted_train_data)
# Out:
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# 2022-02-07 05:01:13 Starting - Starting the training job...
# 2022-02-07 05:01:36 Starting - Launching requested ML instancesProfilerReport-1644210073: InProgress
# ...
# 2022-02-07 05:02:09 Starting - Preparing the instances for training.........
# 2022-02-07 05:03:37 Downloading - Downloading input data...
# 2022-02-07 05:03:57 Training - Downloading the training image..Docker entrypoint called with argument(s): train
# Running default environment configuration script
# [02/07/2022 05:04:27 INFO 139740920325952] Reading default configuration from /opt/amazon/lib/python3.7/site-packages/algorithm/resources/default-input.json: {'mini_batch_size': '1000', 'epochs': '15', 'feature_dim': 'auto', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'accuracy', 'f_beta': '1.0', 'target_recall': '0.8', 'target_precision': '0.8', 'num_models': 'auto', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'auto', 'loss': 'auto', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '1', 'accuracy_top_k': '3', 'wd': 'auto', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': 'auto', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': 'auto', 'lr_scheduler_factor': 'auto', 'lr_scheduler_minimum_lr': 'auto', 'positive_example_weight_mult': '1.0', 'balance_multiclass_weights': 'false', 'normalize_data': 'true', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false'}
# [02/07/2022 05:04:27 INFO 139740920325952] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {'feature_dim': '30', 'predictor_type': 'binary_classifier', 'epochs': '15', 'mini_batch_size': '1000'}
# [02/07/2022 05:04:27 INFO 139740920325952] Final configuration: {'mini_batch_size': '1000', 'epochs': '15', 'feature_dim': '30', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'accuracy', 'f_beta': '1.0', 'target_recall': '0.8', 'target_precision': '0.8', 'num_models': 'auto', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'auto', 'loss': 'auto', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '1', 'accuracy_top_k': '3', 'wd': 'auto', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': 'auto', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': 'auto', 'lr_scheduler_factor': 'auto', 'lr_scheduler_minimum_lr': 'auto', 'positive_example_weight_mult': '1.0', 'balance_multiclass_weights': 'false', 'normalize_data': 'true', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false', 'predictor_type': 'binary_classifier'}
# [02/07/2022 05:04:27 WARNING 139740920325952] Loggers have already been setup.
# Process 1 is a worker.
# [02/07/2022 05:04:27 INFO 139740920325952] Using default worker.
# [02/07/2022 05:04:28 INFO 139740920325952] Checkpoint loading and saving are disabled.
# [2022-02-07 05:04:28.217] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration": 40, "num_examples": 1, "num_bytes": 168000}
# [02/07/2022 05:04:28 INFO 139740920325952] Create Store: local
# [2022-02-07 05:04:28.401] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 1, "duration": 182, "num_examples": 11, "num_bytes": 1848000}
# [02/07/2022 05:04:28 INFO 139740920325952] Scaler algorithm parameters
#  <algorithm.scaler.ScalerAlgorithmStable object at 0x7f17a8daa7d0>
# [02/07/2022 05:04:28 INFO 139740920325952] Scaling model computed with parameters:
#  {'stdev_label': None, 'stdev_weight':
# [4.7823008e+04 1.8987731e+00 1.5821997e+00 1.5291911e+00 1.4364978e+00
#  1.3388461e+00 1.2955806e+00 1.1771069e+00 1.2127448e+00 1.0843055e+00
#  1.0475702e+00 1.0230465e+00 1.0090139e+00 1.0057642e+00 9.5122164e-01
#  9.2613727e-01 8.7072927e-01 8.6057234e-01 8.3151484e-01 8.2762748e-01
#  7.1313608e-01 7.3347980e-01 7.2524083e-01 5.6213826e-01 6.0201687e-01
#  5.1174247e-01 4.8000538e-01 3.7595215e-01 2.7081874e-01 2.3656270e+02]
# <NDArray 30 @cpu(0)>, 'mean_label': None, 'mean_weight':
# [ 9.4275984e+04 -1.7378727e-02  1.5538026e-02  2.5005125e-02
#   3.3166975e-02  1.8197566e-02  1.7799012e-03  6.9396999e-03
#   9.8540336e-03 -3.0757964e-02 -1.2736557e-02  4.0434714e-04
#  -1.4243029e-02  1.6704608e-02  2.2619881e-02 -9.6982103e-03
#  -4.7834702e-03 -1.6767335e-04 -9.0120723e-03 -3.0407687e-03
#   4.6031545e-03 -4.0078526e-03 -1.2586080e-04  1.2784966e-03
#   3.7617318e-03 -3.1254767e-03 -8.2200055e-04  3.4045519e-03
#  -1.0332187e-03  8.7559837e+01]
# <NDArray 30 @cpu(0)>}
# [02/07/2022 05:04:28 INFO 139740920325952] nvidia-smi: took 0.034 seconds to run.
# [02/07/2022 05:04:28 INFO 139740920325952] nvidia-smi identified 0 GPUs.
# [02/07/2022 05:04:28 INFO 139740920325952] Number of GPUs being used: 0
# #metrics {"StartTime": 1644210268.5609763, "EndTime": 1644210268.561021, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "Meta": "init_train_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 12000.0, "count": 1, "min": 12000, "max": 12000}, "Total Batches Seen": {"sum": 12.0, "count": 1, "min": 12, "max": 12}, "Max Records Seen Between Resets": {"sum": 11000.0, "count": 1, "min": 11000, "max": 11000}, "Max Batches Seen Between Resets": {"sum": 11.0, "count": 1, "min": 11, "max": 11}, "Reset Count": {"sum": 2.0, "count": 1, "min": 2, "max": 2}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
#
# 2022-02-07 05:04:37 Training - Training image download completed. Training in progress.[2022-02-07 05:04:38.197] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 3, "duration": 9635, "num_examples": 200, "num_bytes": 33493152}
# #metrics {"StartTime": 1644210278.1975806, "EndTime": 1644210278.1977744, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 0}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.12023840661743777, "count": 1, "min": 0.12023840661743777, "max": 0.12023840661743777}}}
# #metrics {"StartTime": 1644210278.197917, "EndTime": 1644210278.197949, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 1}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.1175625283514435, "count": 1, "min": 0.1175625283514435, "max": 0.1175625283514435}}}
# #metrics {"StartTime": 1644210278.1980317, "EndTime": 1644210278.1980593, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 2}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.12012009677216036, "count": 1, "min": 0.12012009677216036, "max": 0.12012009677216036}}}
# #metrics {"StartTime": 1644210278.1981318, "EndTime": 1644210278.1981552, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 3}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.11766779350395777, "count": 1, "min": 0.11766779350395777, "max": 0.11766779350395777}}}
# #metrics {"StartTime": 1644210278.1982255, "EndTime": 1644210278.198249, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 4}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.012220082102483841, "count": 1, "min": 0.012220082102483841, "max": 0.012220082102483841}}}
# #metrics {"StartTime": 1644210278.1983192, "EndTime": 1644210278.1983423, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 5}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.012175582823441855, "count": 1, "min": 0.012175582823441855, "max": 0.012175582823441855}}}
# #metrics {"StartTime": 1644210278.1984103, "EndTime": 1644210278.1984327, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 6}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.012201707582415348, "count": 1, "min": 0.012201707582415348, "max": 0.012201707582415348}}}
# #metrics {"StartTime": 1644210278.1985052, "EndTime": 1644210278.198528, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 7}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.012345536659747811, "count": 1, "min": 0.012345536659747811, "max": 0.012345536659747811}}}
# #metrics {"StartTime": 1644210278.1986017, "EndTime": 1644210278.1986256, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 8}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.12014251477035445, "count": 1, "min": 0.12014251477035445, "max": 0.12014251477035445}}}
# #metrics {"StartTime": 1644210278.1986945, "EndTime": 1644210278.198718, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 9}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.11776210052643589, "count": 1, "min": 0.11776210052643589, "max": 0.11776210052643589}}}
# #metrics {"StartTime": 1644210278.1987824, "EndTime": 1644210278.198804, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 10}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.12038165889912514, "count": 1, "min": 0.12038165889912514, "max": 0.12038165889912514}}}
# #metrics {"StartTime": 1644210278.1988835, "EndTime": 1644210278.198904, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 11}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.11770791634602762, "count": 1, "min": 0.11770791634602762, "max": 0.11770791634602762}}}
# #metrics {"StartTime": 1644210278.198971, "EndTime": 1644210278.1989932, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 12}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.01261257816119185, "count": 1, "min": 0.01261257816119185, "max": 0.01261257816119185}}}
# #metrics {"StartTime": 1644210278.1990607, "EndTime": 1644210278.1990838, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 13}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.012488340938866289, "count": 1, "min": 0.012488340938866289, "max": 0.012488340938866289}}}
# #metrics {"StartTime": 1644210278.1991608, "EndTime": 1644210278.199186, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 14}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.012396600667237486, "count": 1, "min": 0.012396600667237486, "max": 0.012396600667237486}}}
# #metrics {"StartTime": 1644210278.1992586, "EndTime": 1644210278.1992824, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 15}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.012499406192096035, "count": 1, "min": 0.012499406192096035, "max": 0.012499406192096035}}}
# #metrics {"StartTime": 1644210278.1993566, "EndTime": 1644210278.1993802, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 16}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.1228250465488913, "count": 1, "min": 0.1228250465488913, "max": 0.1228250465488913}}}
# #metrics {"StartTime": 1644210278.1994524, "EndTime": 1644210278.199477, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 17}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.12008383270723735, "count": 1, "min": 0.12008383270723735, "max": 0.12008383270723735}}}
# #metrics {"StartTime": 1644210278.199557, "EndTime": 1644210278.1995842, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 18}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.12283358952507901, "count": 1, "min": 0.12283358952507901, "max": 0.12283358952507901}}}
# #metrics {"StartTime": 1644210278.199653, "EndTime": 1644210278.1996684, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 19}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.12025850340109974, "count": 1, "min": 0.12025850340109974, "max": 0.12025850340109974}}}
# #metrics {"StartTime": 1644210278.1997066, "EndTime": 1644210278.199723, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 20}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.019943902858238126, "count": 1, "min": 0.019943902858238126, "max": 0.019943902858238126}}}
# #metrics {"StartTime": 1644210278.1997843, "EndTime": 1644210278.199807, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 21}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.01993385848758658, "count": 1, "min": 0.01993385848758658, "max": 0.01993385848758658}}}
# #metrics {"StartTime": 1644210278.1998715, "EndTime": 1644210278.1999063, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 22}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.019987651391170133, "count": 1, "min": 0.019987651391170133, "max": 0.019987651391170133}}}
# #metrics {"StartTime": 1644210278.1999717, "EndTime": 1644210278.1999946, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 23}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.01984426697302404, "count": 1, "min": 0.01984426697302404, "max": 0.01984426697302404}}}
# #metrics {"StartTime": 1644210278.2000635, "EndTime": 1644210278.2000859, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 24}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.12367208990739219, "count": 1, "min": 0.12367208990739219, "max": 0.12367208990739219}}}
# #metrics {"StartTime": 1644210278.2001805, "EndTime": 1644210278.2002027, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 25}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.12108522349985401, "count": 1, "min": 0.12108522349985401, "max": 0.12108522349985401}}}
# #metrics {"StartTime": 1644210278.2002654, "EndTime": 1644210278.2002845, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 26}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.12374423226399638, "count": 1, "min": 0.12374423226399638, "max": 0.12374423226399638}}}
# #metrics {"StartTime": 1644210278.2003415, "EndTime": 1644210278.2003584, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 27}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.12116944918800239, "count": 1, "min": 0.12116944918800239, "max": 0.12116944918800239}}}
# #metrics {"StartTime": 1644210278.2004206, "EndTime": 1644210278.2004383, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 28}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.02103997616806821, "count": 1, "min": 0.02103997616806821, "max": 0.02103997616806821}}}
# #metrics {"StartTime": 1644210278.200498, "EndTime": 1644210278.2005205, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 29}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.020920196363487135, "count": 1, "min": 0.020920196363487135, "max": 0.020920196363487135}}}
# #metrics {"StartTime": 1644210278.2005603, "EndTime": 1644210278.2005706, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 30}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.021012824348543756, "count": 1, "min": 0.021012824348543756, "max": 0.021012824348543756}}}
# #metrics {"StartTime": 1644210278.2006035, "EndTime": 1644210278.20062, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 31}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.021031404245476327, "count": 1, "min": 0.021031404245476327, "max": 0.021031404245476327}}}
# [02/07/2022 05:04:38 INFO 139740920325952] #quality_metric: host=algo-1, epoch=0, train binary_classification_cross_entropy_objective <loss>=0.12023840661743777
# [02/07/2022 05:04:38 INFO 139740920325952] #early_stopping_criteria_metric: host=algo-1, epoch=0, criteria=binary_classification_cross_entropy_objective, value=0.012175582823441855
# [02/07/2022 05:04:38 INFO 139740920325952] Epoch 0: Loss improved. Updating best model
# [02/07/2022 05:04:38 INFO 139740920325952] Saving model for epoch: 0
# [02/07/2022 05:04:38 INFO 139740920325952] Saved checkpoint to "/tmp/tmprcr3n3x3/mx-mod-0000.params"
# [02/07/2022 05:04:38 INFO 139740920325952] #progress_metric: host=algo-1, completed 6.666666666666667 % of epochs
# #metrics {"StartTime": 1644210268.5614502, "EndTime": 1644210278.2195976, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 211364.0, "count": 1, "min": 211364, "max": 211364}, "Total Batches Seen": {"sum": 212.0, "count": 1, "min": 212, "max": 212}, "Max Records Seen Between Resets": {"sum": 199364.0, "count": 1, "min": 199364, "max": 199364}, "Max Batches Seen Between Resets": {"sum": 200.0, "count": 1, "min": 200, "max": 200}, "Reset Count": {"sum": 3.0, "count": 1, "min": 3, "max": 3}, "Number of Records Since Last Reset": {"sum": 199364.0, "count": 1, "min": 199364, "max": 199364}, "Number of Batches Since Last Reset": {"sum": 200.0, "count": 1, "min": 200, "max": 200}}}
# [02/07/2022 05:04:38 INFO 139740920325952] #throughput_metric: host=algo-1, train throughput=20641.65208255395 records/second
# [2022-02-07 05:04:49.283] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 5, "duration": 11061, "num_examples": 200, "num_bytes": 33493152}
# #metrics {"StartTime": 1644210289.2836401, "EndTime": 1644210289.2837622, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 0}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.016883339575187645, "count": 1, "min": 0.016883339575187645, "max": 0.016883339575187645}}}
# #metrics {"StartTime": 1644210289.2839048, "EndTime": 1644210289.2839386, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 1}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.014893327607581363, "count": 1, "min": 0.014893327607581363, "max": 0.014893327607581363}}}
# #metrics {"StartTime": 1644210289.284038, "EndTime": 1644210289.2840655, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 2}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.01687481061178236, "count": 1, "min": 0.01687481061178236, "max": 0.01687481061178236}}}
# #metrics {"StartTime": 1644210289.2841754, "EndTime": 1644210289.2842045, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 3}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.014889016120278056, "count": 1, "min": 0.014889016120278056, "max": 0.014889016120278056}}}
# #metrics {"StartTime": 1644210289.284285, "EndTime": 1644210289.2843122, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 4}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.0054091289906046496, "count": 1, "min": 0.0054091289906046496, "max": 0.0054091289906046496}}}
# #metrics {"StartTime": 1644210289.2843857, "EndTime": 1644210289.284409, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 5}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.0055940955086569094, "count": 1, "min": 0.0055940955086569094, "max": 0.0055940955086569094}}}
# #metrics {"StartTime": 1644210289.284483, "EndTime": 1644210289.2845068, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 6}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.00551705657522283, "count": 1, "min": 0.00551705657522283, "max": 0.00551705657522283}}}
# #metrics {"StartTime": 1644210289.2846043, "EndTime": 1644210289.2846313, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 7}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.005566651671825342, "count": 1, "min": 0.005566651671825342, "max": 0.005566651671825342}}}
# #metrics {"StartTime": 1644210289.284708, "EndTime": 1644210289.2847335, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 8}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.0170403941312627, "count": 1, "min": 0.0170403941312627, "max": 0.0170403941312627}}}
# #metrics {"StartTime": 1644210289.284809, "EndTime": 1644210289.2848341, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 9}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.015086053342675444, "count": 1, "min": 0.015086053342675444, "max": 0.015086053342675444}}}
# #metrics {"StartTime": 1644210289.2849014, "EndTime": 1644210289.284925, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 10}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.017052275235928484, "count": 1, "min": 0.017052275235928484, "max": 0.017052275235928484}}}
# #metrics {"StartTime": 1644210289.2850192, "EndTime": 1644210289.2850454, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 11}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.015078012080647837, "count": 1, "min": 0.015078012080647837, "max": 0.015078012080647837}}}
# #metrics {"StartTime": 1644210289.285139, "EndTime": 1644210289.2851648, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 12}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.005623061710715893, "count": 1, "min": 0.005623061710715893, "max": 0.005623061710715893}}}
# #metrics {"StartTime": 1644210289.285243, "EndTime": 1644210289.2852669, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 13}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.005685889098512468, "count": 1, "min": 0.005685889098512468, "max": 0.005685889098512468}}}
# #metrics {"StartTime": 1644210289.2853498, "EndTime": 1644210289.2853773, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 14}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.005619973746376421, "count": 1, "min": 0.005619973746376421, "max": 0.005619973746376421}}}
# #metrics {"StartTime": 1644210289.2854626, "EndTime": 1644210289.2854884, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 15}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.005672148302122576, "count": 1, "min": 0.005672148302122576, "max": 0.005672148302122576}}}
# #metrics {"StartTime": 1644210289.2855713, "EndTime": 1644210289.2855968, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 16}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.02126987413665158, "count": 1, "min": 0.02126987413665158, "max": 0.02126987413665158}}}
# #metrics {"StartTime": 1644210289.285672, "EndTime": 1644210289.2856972, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 17}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.019476390440859387, "count": 1, "min": 0.019476390440859387, "max": 0.019476390440859387}}}
# #metrics {"StartTime": 1644210289.2857864, "EndTime": 1644210289.285812, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 18}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.02127108111932649, "count": 1, "min": 0.02127108111932649, "max": 0.02127108111932649}}}
# #metrics {"StartTime": 1644210289.285895, "EndTime": 1644210289.2859209, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 19}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.01948852028679009, "count": 1, "min": 0.01948852028679009, "max": 0.01948852028679009}}}
# #metrics {"StartTime": 1644210289.2860038, "EndTime": 1644210289.2860305, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 20}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.012074755899271174, "count": 1, "min": 0.012074755899271174, "max": 0.012074755899271174}}}
# #metrics {"StartTime": 1644210289.286118, "EndTime": 1644210289.2861433, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 21}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.012111119604589951, "count": 1, "min": 0.012111119604589951, "max": 0.012111119604589951}}}
# #metrics {"StartTime": 1644210289.2862244, "EndTime": 1644210289.2862504, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 22}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.01207915733866955, "count": 1, "min": 0.01207915733866955, "max": 0.01207915733866955}}}
# #metrics {"StartTime": 1644210289.2863324, "EndTime": 1644210289.2863574, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 23}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.01210820182843424, "count": 1, "min": 0.01210820182843424, "max": 0.01210820182843424}}}
# #metrics {"StartTime": 1644210289.2864318, "EndTime": 1644210289.286456, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 24}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.022298133768627992, "count": 1, "min": 0.022298133768627992, "max": 0.022298133768627992}}}
# #metrics {"StartTime": 1644210289.2865317, "EndTime": 1644210289.286555, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 25}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.020528922866936306, "count": 1, "min": 0.020528922866936306, "max": 0.020528922866936306}}}
# #metrics {"StartTime": 1644210289.2866292, "EndTime": 1644210289.2866538, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 26}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.022301760285343957, "count": 1, "min": 0.022301760285343957, "max": 0.022301760285343957}}}
# #metrics {"StartTime": 1644210289.2867284, "EndTime": 1644210289.286754, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 27}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.020534939981585173, "count": 1, "min": 0.020534939981585173, "max": 0.020534939981585173}}}
# #metrics {"StartTime": 1644210289.286844, "EndTime": 1644210289.2868698, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 28}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.01314413232719479, "count": 1, "min": 0.01314413232719479, "max": 0.01314413232719479}}}
# #metrics {"StartTime": 1644210289.286951, "EndTime": 1644210289.2869766, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 29}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.013147845992490874, "count": 1, "min": 0.013147845992490874, "max": 0.013147845992490874}}}
# #metrics {"StartTime": 1644210289.2870505, "EndTime": 1644210289.2870746, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 30}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.013144269559251603, "count": 1, "min": 0.013144269559251603, "max": 0.013144269559251603}}}
# #metrics {"StartTime": 1644210289.287157, "EndTime": 1644210289.2871819, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 31}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.013148174486567627, "count": 1, "min": 0.013148174486567627, "max": 0.013148174486567627}}}
# [02/07/2022 05:04:49 INFO 139740920325952] #quality_metric: host=algo-1, epoch=1, train binary_classification_cross_entropy_objective <loss>=0.016883339575187645
# [02/07/2022 05:04:49 INFO 139740920325952] #early_stopping_criteria_metric: host=algo-1, epoch=1, criteria=binary_classification_cross_entropy_objective, value=0.0054091289906046496
# [02/07/2022 05:04:49 INFO 139740920325952] Epoch 1: Loss improved. Updating best model
# [02/07/2022 05:04:49 INFO 139740920325952] Saving model for epoch: 1
# [02/07/2022 05:04:49 INFO 139740920325952] Saved checkpoint to "/tmp/tmp385jom07/mx-mod-0000.params"
# [02/07/2022 05:04:49 INFO 139740920325952] #progress_metric: host=algo-1, completed 13.333333333333334 % of epochs
# #metrics {"StartTime": 1644210278.2218676, "EndTime": 1644210289.2984374, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 410728.0, "count": 1, "min": 410728, "max": 410728}, "Total Batches Seen": {"sum": 412.0, "count": 1, "min": 412, "max": 412}, "Max Records Seen Between Resets": {"sum": 199364.0, "count": 1, "min": 199364, "max": 199364}, "Max Batches Seen Between Resets": {"sum": 200.0, "count": 1, "min": 200, "max": 200}, "Reset Count": {"sum": 4.0, "count": 1, "min": 4, "max": 4}, "Number of Records Since Last Reset": {"sum": 199364.0, "count": 1, "min": 199364, "max": 199364}, "Number of Batches Since Last Reset": {"sum": 200.0, "count": 1, "min": 200, "max": 200}}}
# [02/07/2022 05:04:49 INFO 139740920325952] #throughput_metric: host=algo-1, train throughput=17998.40803965829 records/second
# [2022-02-07 05:04:59.128] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 7, "duration": 9829, "num_examples": 200, "num_bytes": 33493152}
# #metrics {"StartTime": 1644210299.1288285, "EndTime": 1644210299.1289508, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 0}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.010249469512671083, "count": 1, "min": 0.010249469512671083, "max": 0.010249469512671083}}}
# #metrics {"StartTime": 1644210299.1291027, "EndTime": 1644210299.1291354, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 1}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.008671593309047832, "count": 1, "min": 0.008671593309047832, "max": 0.008671593309047832}}}
# #metrics {"StartTime": 1644210299.1292245, "EndTime": 1644210299.129252, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 2}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.010244108916527063, "count": 1, "min": 0.010244108916527063, "max": 0.010244108916527063}}}
# #metrics {"StartTime": 1644210299.1293364, "EndTime": 1644210299.1293652, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 3}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.00867205645930228, "count": 1, "min": 0.00867205645930228, "max": 0.00867205645930228}}}
# #metrics {"StartTime": 1644210299.1294491, "EndTime": 1644210299.1294758, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 4}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.004918119081076066, "count": 1, "min": 0.004918119081076066, "max": 0.004918119081076066}}}
# #metrics {"StartTime": 1644210299.1295555, "EndTime": 1644210299.1295822, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 5}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.005651303291320801, "count": 1, "min": 0.005651303291320801, "max": 0.005651303291320801}}}
# #metrics {"StartTime": 1644210299.1296618, "EndTime": 1644210299.1296875, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 6}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.0049273479259643125, "count": 1, "min": 0.0049273479259643125, "max": 0.0049273479259643125}}}
# #metrics {"StartTime": 1644210299.1297686, "EndTime": 1644210299.1297953, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 7}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.005490868361226878, "count": 1, "min": 0.005490868361226878, "max": 0.005490868361226878}}}
# #metrics {"StartTime": 1644210299.1298745, "EndTime": 1644210299.1298985, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 8}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.010515944255656334, "count": 1, "min": 0.010515944255656334, "max": 0.010515944255656334}}}
# #metrics {"StartTime": 1644210299.1299758, "EndTime": 1644210299.1300027, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 9}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.009003221483086821, "count": 1, "min": 0.009003221483086821, "max": 0.009003221483086821}}}
# #metrics {"StartTime": 1644210299.1300778, "EndTime": 1644210299.130104, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 10}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.010521823832737141, "count": 1, "min": 0.010521823832737141, "max": 0.010521823832737141}}}
# #metrics {"StartTime": 1644210299.130198, "EndTime": 1644210299.1302247, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 11}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.008999888767549142, "count": 1, "min": 0.008999888767549142, "max": 0.008999888767549142}}}
# #metrics {"StartTime": 1644210299.1302986, "EndTime": 1644210299.1303232, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 12}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.005593623910117988, "count": 1, "min": 0.005593623910117988, "max": 0.005593623910117988}}}
# #metrics {"StartTime": 1644210299.130397, "EndTime": 1644210299.1304224, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 13}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.005721277174338624, "count": 1, "min": 0.005721277174338624, "max": 0.005721277174338624}}}
# #metrics {"StartTime": 1644210299.1304917, "EndTime": 1644210299.1305184, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 14}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.005546630558656089, "count": 1, "min": 0.005546630558656089, "max": 0.005546630558656089}}}
# #metrics {"StartTime": 1644210299.1305912, "EndTime": 1644210299.1306174, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 15}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.005712993024581641, "count": 1, "min": 0.005712993024581641, "max": 0.005712993024581641}}}
# #metrics {"StartTime": 1644210299.1306996, "EndTime": 1644210299.1307268, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 16}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.015533093172102119, "count": 1, "min": 0.015533093172102119, "max": 0.015533093172102119}}}
# #metrics {"StartTime": 1644210299.130819, "EndTime": 1644210299.1308465, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 17}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.0142904183541111, "count": 1, "min": 0.0142904183541111, "max": 0.0142904183541111}}}
# #metrics {"StartTime": 1644210299.1309397, "EndTime": 1644210299.1309657, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 18}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.01553408638556399, "count": 1, "min": 0.01553408638556399, "max": 0.01553408638556399}}}
# #metrics {"StartTime": 1644210299.1310468, "EndTime": 1644210299.1310706, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 19}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.014295967495022108, "count": 1, "min": 0.014295967495022108, "max": 0.014295967495022108}}}
# #metrics {"StartTime": 1644210299.1311526, "EndTime": 1644210299.1311781, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 20}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.012072144002171617, "count": 1, "min": 0.012072144002171617, "max": 0.012072144002171617}}}
# #metrics {"StartTime": 1644210299.1312604, "EndTime": 1644210299.131287, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 21}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.0121305170963757, "count": 1, "min": 0.0121305170963757, "max": 0.0121305170963757}}}
# #metrics {"StartTime": 1644210299.1313808, "EndTime": 1644210299.1314082, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 22}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.012072037987373583, "count": 1, "min": 0.012072037987373583, "max": 0.012072037987373583}}}
# #metrics {"StartTime": 1644210299.131482, "EndTime": 1644210299.1315055, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 23}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.012126008991021007, "count": 1, "min": 0.012126008991021007, "max": 0.012126008991021007}}}
# #metrics {"StartTime": 1644210299.1315742, "EndTime": 1644210299.1315992, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 24}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.016575735899671238, "count": 1, "min": 0.016575735899671238, "max": 0.016575735899671238}}}
# #metrics {"StartTime": 1644210299.1316693, "EndTime": 1644210299.1316907, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 25}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.01536184029123891, "count": 1, "min": 0.01536184029123891, "max": 0.01536184029123891}}}
# #metrics {"StartTime": 1644210299.1317735, "EndTime": 1644210299.1317973, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 26}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.01657752835451059, "count": 1, "min": 0.01657752835451059, "max": 0.01657752835451059}}}
# #metrics {"StartTime": 1644210299.131869, "EndTime": 1644210299.1318908, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 27}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.01536392712712887, "count": 1, "min": 0.01536392712712887, "max": 0.01536392712712887}}}
# #metrics {"StartTime": 1644210299.1319497, "EndTime": 1644210299.1319664, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 28}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.013144806580327862, "count": 1, "min": 0.013144806580327862, "max": 0.013144806580327862}}}
# #metrics {"StartTime": 1644210299.1320293, "EndTime": 1644210299.1320508, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 29}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.013156182020153832, "count": 1, "min": 0.013156182020153832, "max": 0.013156182020153832}}}
# #metrics {"StartTime": 1644210299.1321213, "EndTime": 1644210299.1321845, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 30}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.013145586877012972, "count": 1, "min": 0.013145586877012972, "max": 0.013145586877012972}}}
# #metrics {"StartTime": 1644210299.132263, "EndTime": 1644210299.1322858, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 31}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.01315547815998595, "count": 1, "min": 0.01315547815998595, "max": 0.01315547815998595}}}
# [02/07/2022 05:04:59 INFO 139740920325952] #quality_metric: host=algo-1, epoch=2, train binary_classification_cross_entropy_objective <loss>=0.010249469512671083
# [02/07/2022 05:04:59 INFO 139740920325952] #early_stopping_criteria_metric: host=algo-1, epoch=2, criteria=binary_classification_cross_entropy_objective, value=0.004918119081076066
# [02/07/2022 05:04:59 INFO 139740920325952] Epoch 2: Loss improved. Updating best model
# [02/07/2022 05:04:59 INFO 139740920325952] Saving model for epoch: 2
# [02/07/2022 05:04:59 INFO 139740920325952] Saved checkpoint to "/tmp/tmpnrox_3ol/mx-mod-0000.params"
# [02/07/2022 05:04:59 INFO 139740920325952] #progress_metric: host=algo-1, completed 20.0 % of epochs
# #metrics {"StartTime": 1644210289.2989073, "EndTime": 1644210299.14357, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 610092.0, "count": 1, "min": 610092, "max": 610092}, "Total Batches Seen": {"sum": 612.0, "count": 1, "min": 612, "max": 612}, "Max Records Seen Between Resets": {"sum": 199364.0, "count": 1, "min": 199364, "max": 199364}, "Max Batches Seen Between Resets": {"sum": 200.0, "count": 1, "min": 200, "max": 200}, "Reset Count": {"sum": 5.0, "count": 1, "min": 5, "max": 5}, "Number of Records Since Last Reset": {"sum": 199364.0, "count": 1, "min": 199364, "max": 199364}, "Number of Batches Since Last Reset": {"sum": 200.0, "count": 1, "min": 200, "max": 200}}}
# [02/07/2022 05:04:59 INFO 139740920325952] #throughput_metric: host=algo-1, train throughput=20250.589702242236 records/second
# [2022-02-07 05:05:11.526] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 9, "duration": 12379, "num_examples": 200, "num_bytes": 33493152}
# #metrics {"StartTime": 1644210311.5260844, "EndTime": 1644210311.5262299, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 0}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.00796071047279703, "count": 1, "min": 0.00796071047279703, "max": 0.00796071047279703}}}
# #metrics {"StartTime": 1644210311.5263796, "EndTime": 1644210311.5264206, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 1}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.0066089136300973555, "count": 1, "min": 0.0066089136300973555, "max": 0.0066089136300973555}}}
# #metrics {"StartTime": 1644210311.5265396, "EndTime": 1644210311.5265758, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 2}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.007957086086273194, "count": 1, "min": 0.007957086086273194, "max": 0.007957086086273194}}}
# #metrics {"StartTime": 1644210311.526682, "EndTime": 1644210311.5267146, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 3}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.006610484449108642, "count": 1, "min": 0.006610484449108642, "max": 0.006610484449108642}}}
# ...
# #metrics {"StartTime": 1644210423.282929, "EndTime": 1644210423.28296, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 4}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.0040303359740044, "count": 1, "min": 0.0040303359740044, "max": 0.0040303359740044}}}
# #metrics {"StartTime": 1644210423.2830384, "EndTime": 1644210423.2830648, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 5}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.005875211362862707, "count": 1, "min": 0.005875211362862707, "max": 0.005875211362862707}}}
# #metrics {"StartTime": 1644210423.2831419, "EndTime": 1644210423.2831662, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 6}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.00404278004139512, "count": 1, "min": 0.00404278004139512, "max": 0.00404278004139512}}}
# #metrics {"StartTime": 1644210423.2832289, "EndTime": 1644210423.2832534, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 7}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.005471848284853763, "count": 1, "min": 0.005471848284853763, "max": 0.005471848284853763}}}
# #metrics {"StartTime": 1644210423.2833297, "EndTime": 1644210423.2833538, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 8}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.0055071240819279275, "count": 1, "min": 0.0055071240819279275, "max": 0.0055071240819279275}}}
# #metrics {"StartTime": 1644210423.2834258, "EndTime": 1644210423.2834504, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 9}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.005093599353004341, "count": 1, "min": 0.005093599353004341, "max": 0.005093599353004341}}}
# #metrics {"StartTime": 1644210423.2835383, "EndTime": 1644210423.2835665, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 10}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.005507833725243956, "count": 1, "min": 0.005507833725243956, "max": 0.005507833725243956}}}
# #metrics {"StartTime": 1644210423.2836452, "EndTime": 1644210423.2836719, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 11}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.005093542199638022, "count": 1, "min": 0.005093542199638022, "max": 0.005093542199638022}}}
# #metrics {"StartTime": 1644210423.2837496, "EndTime": 1644210423.2837775, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 12}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.0050990720678813495, "count": 1, "min": 0.0050990720678813495, "max": 0.0050990720678813495}}}
# #metrics {"StartTime": 1644210423.283863, "EndTime": 1644210423.2838883, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 13}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.005519994659040441, "count": 1, "min": 0.005519994659040441, "max": 0.005519994659040441}}}
# #metrics {"StartTime": 1644210423.2839675, "EndTime": 1644210423.2839935, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 14}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.005098994569862308, "count": 1, "min": 0.005098994569862308, "max": 0.005098994569862308}}}
# #metrics {"StartTime": 1644210423.2840712, "EndTime": 1644210423.2840965, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 15}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.005520632858851448, "count": 1, "min": 0.005520632858851448, "max": 0.005520632858851448}}}
# #metrics {"StartTime": 1644210423.2842257, "EndTime": 1644210423.284273, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 16}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.012167769629751617, "count": 1, "min": 0.012167769629751617, "max": 0.012167769629751617}}}
# #metrics {"StartTime": 1644210423.2843523, "EndTime": 1644210423.2843778, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 17}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.012054018840118868, "count": 1, "min": 0.012054018840118868, "max": 0.012054018840118868}}}
# #metrics {"StartTime": 1644210423.2844694, "EndTime": 1644210423.2844985, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 18}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.012167777455631811, "count": 1, "min": 0.012167777455631811, "max": 0.012167777455631811}}}
# #metrics {"StartTime": 1644210423.2845793, "EndTime": 1644210423.2846038, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 19}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.012054238608135051, "count": 1, "min": 0.012054238608135051, "max": 0.012054238608135051}}}
# #metrics {"StartTime": 1644210423.284692, "EndTime": 1644210423.2847178, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 20}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.012039981996593762, "count": 1, "min": 0.012039981996593762, "max": 0.012039981996593762}}}
# #metrics {"StartTime": 1644210423.284793, "EndTime": 1644210423.2848148, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 21}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.012189195263625389, "count": 1, "min": 0.012189195263625389, "max": 0.012189195263625389}}}
# #metrics {"StartTime": 1644210423.284898, "EndTime": 1644210423.2849216, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 22}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.012040088680521328, "count": 1, "min": 0.012040088680521328, "max": 0.012040088680521328}}}
# #metrics {"StartTime": 1644210423.2850106, "EndTime": 1644210423.2850378, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 23}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.012187875629968979, "count": 1, "min": 0.012187875629968979, "max": 0.012187875629968979}}}
# #metrics {"StartTime": 1644210423.2851214, "EndTime": 1644210423.2851472, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 24}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.013193741987698042, "count": 1, "min": 0.013193741987698042, "max": 0.013193741987698042}}}
# #metrics {"StartTime": 1644210423.285238, "EndTime": 1644210423.2852635, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 25}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.013127850090438997, "count": 1, "min": 0.013127850090438997, "max": 0.013127850090438997}}}
# #metrics {"StartTime": 1644210423.2853448, "EndTime": 1644210423.2853713, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 26}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.013193773884270059, "count": 1, "min": 0.013193773884270059, "max": 0.013193773884270059}}}
# #metrics {"StartTime": 1644210423.2854533, "EndTime": 1644210423.285479, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 27}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.013127679164685196, "count": 1, "min": 0.013127679164685196, "max": 0.013127679164685196}}}
# #metrics {"StartTime": 1644210423.2855499, "EndTime": 1644210423.2855735, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 28}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.013136238493512024, "count": 1, "min": 0.013136238493512024, "max": 0.013136238493512024}}}
# #metrics {"StartTime": 1644210423.2856617, "EndTime": 1644210423.2856905, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 29}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.013258359701190162, "count": 1, "min": 0.013258359701190162, "max": 0.013258359701190162}}}
# #metrics {"StartTime": 1644210423.285774, "EndTime": 1644210423.2858014, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 30}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.013136125135062328, "count": 1, "min": 0.013136125135062328, "max": 0.013136125135062328}}}
# #metrics {"StartTime": 1644210423.2858694, "EndTime": 1644210423.2858918, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 31}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.013257740079757557, "count": 1, "min": 0.013257740079757557, "max": 0.013257740079757557}}}
# [02/07/2022 05:07:03 INFO 139740920325952] #quality_metric: host=algo-1, epoch=14, train binary_classification_cross_entropy_objective <loss>=0.004796242649830766
# [02/07/2022 05:07:03 INFO 139740920325952] #early_stopping_criteria_metric: host=algo-1, epoch=14, criteria=binary_classification_cross_entropy_objective, value=0.0040303359740044
# [02/07/2022 05:07:03 INFO 139740920325952] Epoch 14: Loss improved. Updating best model
# [02/07/2022 05:07:03 INFO 139740920325952] Saving model for epoch: 14
# [02/07/2022 05:07:03 INFO 139740920325952] Saved checkpoint to "/tmp/tmp6dgyuqko/mx-mod-0000.params"
# [02/07/2022 05:07:03 INFO 139740920325952] #progress_metric: host=algo-1, completed 100.0 % of epochs
# #metrics {"StartTime": 1644210412.6330993, "EndTime": 1644210423.2997358, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 3002460.0, "count": 1, "min": 3002460, "max": 3002460}, "Total Batches Seen": {"sum": 3012.0, "count": 1, "min": 3012, "max": 3012}, "Max Records Seen Between Resets": {"sum": 199364.0, "count": 1, "min": 199364, "max": 199364}, "Max Batches Seen Between Resets": {"sum": 200.0, "count": 1, "min": 200, "max": 200}, "Reset Count": {"sum": 17.0, "count": 1, "min": 17, "max": 17}, "Number of Records Since Last Reset": {"sum": 199364.0, "count": 1, "min": 199364, "max": 199364}, "Number of Batches Since Last Reset": {"sum": 200.0, "count": 1, "min": 200, "max": 200}}}
# [02/07/2022 05:07:03 INFO 139740920325952] #throughput_metric: host=algo-1, train throughput=18690.21736563699 records/second
# [02/07/2022 05:07:03 WARNING 139740920325952] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [02/07/2022 05:07:03 WARNING 139740920325952] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [2022-02-07 05:07:03.309] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 33, "duration": 9, "num_examples": 1, "num_bytes": 168000}
# [2022-02-07 05:07:04.133] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 36, "duration": 819, "num_examples": 200, "num_bytes": 33493152}
# [2022-02-07 05:07:05.838] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 38, "duration": 1577, "num_examples": 200, "num_bytes": 33493152}
# [02/07/2022 05:07:06 INFO 139740920325952] #train_score (algo-1) : ('binary_classification_cross_entropy_objective', 0.003960911865313041)
# [02/07/2022 05:07:06 INFO 139740920325952] #train_score (algo-1) : ('binary_classification_accuracy', 0.9992827190465681)
# [02/07/2022 05:07:06 INFO 139740920325952] #train_score (algo-1) : ('binary_f_1.000', 0.7971631205673759)
# [02/07/2022 05:07:06 INFO 139740920325952] #train_score (algo-1) : ('precision', 0.8074712643678161)
# [02/07/2022 05:07:06 INFO 139740920325952] #train_score (algo-1) : ('recall', 0.7871148459383753)
# [02/07/2022 05:07:06 INFO 139740920325952] #train_score (algo-1) : ('roc_auc_score', 0.9790894705377465)
# [02/07/2022 05:07:06 INFO 139740920325952] #train_score (algo-1) : ('binary_balanced_accuracy', 0.5)
# [02/07/2022 05:07:06 INFO 139740920325952] #train_score (algo-1) : ('binary_log_loss', 0.6930574032138126)
# [02/07/2022 05:07:06 INFO 139740920325952] #quality_metric: host=algo-1, train binary_classification_cross_entropy_objective <loss>=0.003960911865313041
# [02/07/2022 05:07:06 INFO 139740920325952] #quality_metric: host=algo-1, train binary_classification_accuracy <score>=0.9992827190465681
# [02/07/2022 05:07:06 INFO 139740920325952] #quality_metric: host=algo-1, train binary_f_1.000 <score>=0.7971631205673759
# [02/07/2022 05:07:06 INFO 139740920325952] #quality_metric: host=algo-1, train precision <score>=0.8074712643678161
# [02/07/2022 05:07:06 INFO 139740920325952] #quality_metric: host=algo-1, train recall <score>=0.7871148459383753
# [02/07/2022 05:07:06 INFO 139740920325952] #quality_metric: host=algo-1, train roc_auc_score <score>=0.9790894705377465
# [02/07/2022 05:07:06 INFO 139740920325952] #quality_metric: host=algo-1, train binary_balanced_accuracy <score>=0.5
# [02/07/2022 05:07:06 INFO 139740920325952] #quality_metric: host=algo-1, train binary_log_loss <score>=0.6930574032138126
# [02/07/2022 05:07:06 INFO 139740920325952] Best model found for hyperparameters: {"optimizer": "adam", "learning_rate": 0.1, "wd": 0.0001, "l1": 0.0, "lr_scheduler_step": 10, "lr_scheduler_factor": 0.99, "lr_scheduler_minimum_lr": 1e-05}
# [02/07/2022 05:07:06 INFO 139740920325952] Saved checkpoint to "/tmp/tmpr9xi1eta/mx-mod-0000.params"
# [02/07/2022 05:07:06 INFO 139740920325952] Test data is not provided.
# #metrics {"StartTime": 1644210268.1769364, "EndTime": 1644210426.30553, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training"}, "Metrics": {"initialize.time": {"sum": 380.36274909973145, "count": 1, "min": 380.36274909973145, "max": 380.36274909973145}, "epochs": {"sum": 15.0, "count": 1, "min": 15, "max": 15}, "check_early_stopping.time": {"sum": 22.070646286010742, "count": 15, "min": 1.2900829315185547, "max": 1.8546581268310547}, "update.time": {"sum": 154647.82118797302, "count": 15, "min": 9473.078727722168, "max": 12396.445989608765}, "finalize.time": {"sum": 2997.3480701446533, "count": 1, "min": 2997.3480701446533, "max": 2997.3480701446533}, "setuptime": {"sum": 29.759645462036133, "count": 1, "min": 29.759645462036133, "max": 29.759645462036133}, "totaltime": {"sum": 158383.06760787964, "count": 1, "min": 158383.06760787964, "max": 158383.06760787964}}}
# Training seconds: 220
# Billable seconds: 220
# CPU times: user 924 ms, sys: 24.7 ms, total: 949 ms
# Wall time: 6min 14s

# %% [markdown]
# ### EXERCISE: Deploy the trained model
#
# Deploy your model to create a predictor. We'll use this to make predictions on our test data and evaluate the model.

# %%
# %%time 
# deploy and create a predictor
linear_predictor = lin_SM.deploy(initial_instance_count=1,
                                 instance_type='ml.t2.medium')
# Out:
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# --------!CPU times: user 158 ms, sys: 4.68 ms, total: 163 ms
# Wall time: 4min 1s

# %% [markdown]
# ---
# # Evaluating Your Model
#
# Once your model is deployed, you can see how it performs when applied to the test data.
#
# According to the deployed [predictor documentation](https://sagemaker.readthedocs.io/en/stable/linear_learner.html#sagemaker.LinearLearnerPredictor), this predictor expects an `ndarray` of input features and returns a list of Records.
# > "The prediction is stored in the "predicted_label" key of the `Record.label` field."
#
# Let's first test our model on just one test point, to see the resulting list.

# %%
# test one prediction
test_x_np = test_features.values.astype('float32')
result = linear_predictor.predict(test_x_np[0])

print(result)
# Out:
# [label {
#   key: "predicted_label"
#   value {
#     float32_tensor {
#       values: 0.0
#     }
#   }
# }
# label {
#   key: "score"
#   value {
#     float32_tensor {
#       values: 0.0002751190622802824
#     }
#   }
# }
# ]

# %% [markdown]
# ### Helper function for evaluation
#
#
# The provided function below, takes in a deployed predictor, some test features and labels, and returns a dictionary of metrics; calculating false negatives and positives as well as recall, precision, and accuracy.

# %%
# code to evaluate the endpoint on test data
# returns a variety of model metrics
def evaluate(predictor, test_features, test_labels, verbose=True):
    """
    Evaluate a model on a test set given the prediction endpoint.  
    Return binary classification metrics.
    :param predictor: A prediction endpoint
    :param test_features: Test features
    :param test_labels: Class labels for test data
    :param verbose: If True, prints a table of all performance metrics
    :return: A dictionary of performance metrics.
    """
    
    # We have a lot of test data, so we'll split it into batches of 100
    # split the test data set into batches and evaluate using prediction endpoint    
    prediction_batches = [predictor.predict(batch) for batch in np.array_split(test_features, 100)]
    
    # LinearLearner produces a `predicted_label` for each data point in a batch
    # get the 'predicted_label' for every point in a batch
    test_preds = np.concatenate([np.array([x.label['predicted_label'].float32_tensor.values[0] for x in batch]) 
                                 for batch in prediction_batches])
    
    # calculate true positives, false positives, true negatives, false negatives
    tp = np.logical_and(test_labels, test_preds).sum()
    fp = np.logical_and(1-test_labels, test_preds).sum()
    tn = np.logical_and(1-test_labels, 1-test_preds).sum()
    fn = np.logical_and(test_labels, 1-test_preds).sum()
    
    # calculate binary classification metrics
    recall = tp / (tp + fn)
    precision = tp / (tp + fp)
    accuracy = (tp + tn) / (tp + fp + tn + fn)
    
    # printing a table of metrics
    if verbose:
        print(pd.crosstab(test_labels, test_preds, rownames=['actual (row)'], colnames=['prediction (col)']))
        print("\n{:<11} {:.3f}".format('Recall:', recall))
        print("{:<11} {:.3f}".format('Precision:', precision))
        print("{:<11} {:.3f}".format('Accuracy:', accuracy))
        print()
        
    return {'TP': tp, 'FP': fp, 'FN': fn, 'TN': tn, 
            'Precision': precision, 'Recall': recall, 'Accuracy': accuracy}

# %% [markdown]
# ### Test Results
#
# The cell below runs the `evaluate` function.
#
# The code assumes that you have a defined `predictor` and `test_features` and `test_labels` from previously-run cells.

# %%
print('Metrics for simple, LinearLearner.\n')

# get metrics for linear predictor
metrics = evaluate(linear_predictor, 
                   test_features.values.astype('float32'), 
                   test_labels, 
                   verbose=True) # verbose means we'll print out the metrics
# Out:
# Metrics for simple, LinearLearner.
#
# prediction (col)    0.0  1.0
# actual (row)
# 0                 85282   26
# 1                    36   99
#
# Recall:     0.733
# Precision:  0.792
# Accuracy:   0.999

# %% [markdown]
# ## Delete the Endpoint
#
# I've added a convenience function to delete prediction endpoints after we're done with them. And if you're done evaluating the model, you should delete your model endpoint!

# %%
# Deletes a precictor.endpoint
def delete_endpoint(predictor):
        try:
            boto3.client('sagemaker').delete_endpoint(EndpointName=predictor.endpoint)
            print('Deleted {}'.format(predictor.endpoint))
        except:
            print('Already deleted: {}'.format(predictor.endpoint))

# %%
# delete the predictor endpoint 
delete_endpoint(linear_predictor)
# Out:
# The endpoint attribute has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The endpoint attribute has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# Deleted linear-learner-2022-02-07-05-07-27-788

# %% [markdown]
# ---
#
# # Model Improvements
#
# The default LinearLearner got a high accuracy, but still classified fraudulent and valid data points incorrectly. Specifically classifying more than 30 points as false negatives (incorrectly labeled, fraudulent transactions), and a little over 30 points as false positives (incorrectly labeled, valid transactions). Let's think about what, during training, could cause this behavior and what we could improve.
#
# **1. Model optimization**
# * If we imagine that we are designing this model for use in a bank application, we know that users do *not* want any valid transactions to be categorized as fraudulent. That is, we want to have as few **false positives** (0s classified as 1s) as possible.
# * On the other hand, if our bank manager asks for an application that will catch almost *all* cases of fraud, even if it means a higher number of false positives, then we'd want as few **false negatives** as possible.
# * To train according to specific product demands and goals, we do not want to optimize for accuracy only. Instead, we want to optimize for a metric that can help us decrease the number of false positives or negatives.
#
# <img src='notebook_ims/precision_recall.png' width=40% />
#
# In this notebook, we'll look at different cases for tuning a model and make an optimization decision, accordingly.
#
# **2. Imbalanced training data**
# * At the start of this notebook, we saw that only about 0.17% of the training data was labeled as fraudulent. So, even if a model labels **all** of our data as valid, it will still have a high accuracy.
# * This may result in some overfitting towards valid data, which accounts for some **false negatives**; cases in which fraudulent data (1) is incorrectly characterized as valid (0).
#
# So, let's address these issues in order; first, tuning our model and optimizing for a specific metric during training, and second, accounting for class imbalance in the training set.

# %% [markdown]
# ## Improvement: Model Tuning
#
# Optimizing according to a specific metric is called **model tuning**, and SageMaker provides a number of ways to automatically tune a model.
#
#
# ### Create a LinearLearner and tune for higher precision
#
# **Scenario:**
# * A bank has asked you to build a model that detects cases of fraud with an accuracy of about 85%.
#
# In this case, we want to build a model that has as many true positives and as few false negatives, as possible. This corresponds to a model with a high **recall**: true positives / (true positives + false negatives).
#
# To aim for a specific metric, LinearLearner offers the hyperparameter `binary_classifier_model_selection_criteria`, which is the model evaluation criteria for the training dataset. A reference to this parameter is in [LinearLearner's documentation](https://sagemaker.readthedocs.io/en/stable/linear_learner.html#sagemaker.LinearLearner). We'll also have to further specify the exact value we want to aim for; read more about the details of the parameters, [here](https://docs.aws.amazon.com/sagemaker/latest/dg/ll_hyperparameters.html).
#
# I will assume that performance on a training set will be within about 5% of the performance on a test set. So, for a recall of about 85%, I'll aim for a bit higher, 90%.

# %%
# instantiate a LinearLearner
# tune the model for a higher recall
linear_recall = LinearLearner(role=role,
                              train_instance_count=1, 
                              train_instance_type='ml.c4.xlarge',
                              predictor_type='binary_classifier',
                              output_path=output_path,
                              sagemaker_session=sagemaker_session,
                              epochs=15,
                              binary_classifier_model_selection_criteria='precision_at_target_recall', # target recall
                              target_recall=0.9) # 90% recall
# Out:
# train_instance_count has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# train_instance_type has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.

# %% [markdown]
# ### Train the tuned estimator
#
# Fit the new, tuned estimator on the formatted training data.

# %%
# %%time 
# train the estimator on formatted training data
linear_recall.fit(formatted_train_data)
# Out:
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# 2022-02-07 05:11:39 Starting - Starting the training job...
# 2022-02-07 05:12:02 Starting - Launching requested ML instancesProfilerReport-1644210699: InProgress
# ...
# 2022-02-07 05:12:30 Starting - Preparing the instances for training............
# 2022-02-07 05:14:34 Downloading - Downloading input data
# 2022-02-07 05:14:34 Training - Downloading the training image...
# 2022-02-07 05:15:03 Training - Training image download completed. Training in progress.Docker entrypoint called with argument(s): train
# Running default environment configuration script
# [02/07/2022 05:14:59 INFO 139876352214848] Reading default configuration from /opt/amazon/lib/python3.7/site-packages/algorithm/resources/default-input.json: {'mini_batch_size': '1000', 'epochs': '15', 'feature_dim': 'auto', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'accuracy', 'f_beta': '1.0', 'target_recall': '0.8', 'target_precision': '0.8', 'num_models': 'auto', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'auto', 'loss': 'auto', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '1', 'accuracy_top_k': '3', 'wd': 'auto', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': 'auto', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': 'auto', 'lr_scheduler_factor': 'auto', 'lr_scheduler_minimum_lr': 'auto', 'positive_example_weight_mult': '1.0', 'balance_multiclass_weights': 'false', 'normalize_data': 'true', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false'}
# [02/07/2022 05:14:59 INFO 139876352214848] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {'feature_dim': '30', 'predictor_type': 'binary_classifier', 'epochs': '15', 'target_recall': '0.9', 'binary_classifier_model_selection_criteria': 'precision_at_target_recall', 'mini_batch_size': '1000'}
# [02/07/2022 05:14:59 INFO 139876352214848] Final configuration: {'mini_batch_size': '1000', 'epochs': '15', 'feature_dim': '30', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'precision_at_target_recall', 'f_beta': '1.0', 'target_recall': '0.9', 'target_precision': '0.8', 'num_models': 'auto', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'auto', 'loss': 'auto', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '1', 'accuracy_top_k': '3', 'wd': 'auto', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': 'auto', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': 'auto', 'lr_scheduler_factor': 'auto', 'lr_scheduler_minimum_lr': 'auto', 'positive_example_weight_mult': '1.0', 'balance_multiclass_weights': 'false', 'normalize_data': 'true', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false', 'predictor_type': 'binary_classifier'}
# [02/07/2022 05:14:59 WARNING 139876352214848] Loggers have already been setup.
# Process 1 is a worker.
# [02/07/2022 05:14:59 INFO 139876352214848] Using default worker.
# [02/07/2022 05:14:59 INFO 139876352214848] Checkpoint loading and saving are disabled.
# [2022-02-07 05:14:59.281] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration": 27, "num_examples": 1, "num_bytes": 168000}
# [02/07/2022 05:14:59 INFO 139876352214848] Create Store: local
# [2022-02-07 05:14:59.365] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 1, "duration": 83, "num_examples": 11, "num_bytes": 1848000}
# [02/07/2022 05:14:59 INFO 139876352214848] Scaler algorithm parameters
#  <algorithm.scaler.ScalerAlgorithmStable object at 0x7f3728660950>
# [02/07/2022 05:14:59 INFO 139876352214848] Scaling model computed with parameters:
#  {'stdev_label': None, 'stdev_weight':
# [4.7823008e+04 1.8987731e+00 1.5821997e+00 1.5291911e+00 1.4364978e+00
#  1.3388461e+00 1.2955806e+00 1.1771069e+00 1.2127448e+00 1.0843055e+00
#  1.0475702e+00 1.0230465e+00 1.0090139e+00 1.0057642e+00 9.5122164e-01
#  9.2613727e-01 8.7072927e-01 8.6057234e-01 8.3151484e-01 8.2762748e-01
#  7.1313608e-01 7.3347980e-01 7.2524083e-01 5.6213826e-01 6.0201687e-01
#  5.1174247e-01 4.8000538e-01 3.7595215e-01 2.7081874e-01 2.3656270e+02]
# <NDArray 30 @cpu(0)>, 'mean_label': None, 'mean_weight':
# [ 9.4275984e+04 -1.7378727e-02  1.5538026e-02  2.5005125e-02
#   3.3166975e-02  1.8197566e-02  1.7799012e-03  6.9396999e-03
#   9.8540336e-03 -3.0757964e-02 -1.2736557e-02  4.0434714e-04
#  -1.4243029e-02  1.6704608e-02  2.2619881e-02 -9.6982103e-03
#  -4.7834702e-03 -1.6767335e-04 -9.0120723e-03 -3.0407687e-03
#   4.6031545e-03 -4.0078526e-03 -1.2586080e-04  1.2784966e-03
#   3.7617318e-03 -3.1254767e-03 -8.2200055e-04  3.4045519e-03
#  -1.0332187e-03  8.7559837e+01]
# <NDArray 30 @cpu(0)>}
# [02/07/2022 05:14:59 INFO 139876352214848] nvidia-smi: took 0.031 seconds to run.
# [02/07/2022 05:14:59 INFO 139876352214848] nvidia-smi identified 0 GPUs.
# [02/07/2022 05:14:59 INFO 139876352214848] Number of GPUs being used: 0
# #metrics {"StartTime": 1644210899.4853935, "EndTime": 1644210899.4854298, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "Meta": "init_train_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 12000.0, "count": 1, "min": 12000, "max": 12000}, "Total Batches Seen": {"sum": 12.0, "count": 1, "min": 12, "max": 12}, "Max Records Seen Between Resets": {"sum": 11000.0, "count": 1, "min": 11000, "max": 11000}, "Max Batches Seen Between Resets": {"sum": 11.0, "count": 1, "min": 11, "max": 11}, "Reset Count": {"sum": 2.0, "count": 1, "min": 2, "max": 2}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [2022-02-07 05:15:07.139] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 3, "duration": 7654, "num_examples": 200, "num_bytes": 33493152}
# #metrics {"StartTime": 1644210907.1400633, "EndTime": 1644210907.1401892, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 0}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.12023840661743777, "count": 1, "min": 0.12023840661743777, "max": 0.12023840661743777}}}
# #metrics {"StartTime": 1644210907.1402903, "EndTime": 1644210907.140311, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 1}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.1175625283514435, "count": 1, "min": 0.1175625283514435, "max": 0.1175625283514435}}}
# #metrics {"StartTime": 1644210907.1403716, "EndTime": 1644210907.140389, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 2}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.12012009677216036, "count": 1, "min": 0.12012009677216036, "max": 0.12012009677216036}}}
# #metrics {"StartTime": 1644210907.1404436, "EndTime": 1644210907.14046, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 3}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.11766779350395777, "count": 1, "min": 0.11766779350395777, "max": 0.11766779350395777}}}
# #metrics {"StartTime": 1644210907.1405118, "EndTime": 1644210907.1405282, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 4}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.012220082102483841, "count": 1, "min": 0.012220082102483841, "max": 0.012220082102483841}}}
# #metrics {"StartTime": 1644210907.1405811, "EndTime": 1644210907.1405976, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 5}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.012175582823441855, "count": 1, "min": 0.012175582823441855, "max": 0.012175582823441855}}}
# #metrics {"StartTime": 1644210907.1406503, "EndTime": 1644210907.1406665, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 6}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.012201707582415348, "count": 1, "min": 0.012201707582415348, "max": 0.012201707582415348}}}
# #metrics {"StartTime": 1644210907.1407173, "EndTime": 1644210907.1407337, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 7}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.012345536659747811, "count": 1, "min": 0.012345536659747811, "max": 0.012345536659747811}}}
# #metrics {"StartTime": 1644210907.140783, "EndTime": 1644210907.1408093, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 8}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.12014251477035445, "count": 1, "min": 0.12014251477035445, "max": 0.12014251477035445}}}
# #metrics {"StartTime": 1644210907.1408582, "EndTime": 1644210907.140874, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 9}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.11776210052643589, "count": 1, "min": 0.11776210052643589, "max": 0.11776210052643589}}}
# #metrics {"StartTime": 1644210907.140923, "EndTime": 1644210907.1409397, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 10}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.12038165889912514, "count": 1, "min": 0.12038165889912514, "max": 0.12038165889912514}}}
# #metrics {"StartTime": 1644210907.1409898, "EndTime": 1644210907.1410048, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 11}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.11770791634602762, "count": 1, "min": 0.11770791634602762, "max": 0.11770791634602762}}}
# #metrics {"StartTime": 1644210907.1410537, "EndTime": 1644210907.1410694, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 12}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.01261257816119185, "count": 1, "min": 0.01261257816119185, "max": 0.01261257816119185}}}
# #metrics {"StartTime": 1644210907.1411185, "EndTime": 1644210907.1411333, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 13}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.012488340938866289, "count": 1, "min": 0.012488340938866289, "max": 0.012488340938866289}}}
# #metrics {"StartTime": 1644210907.1411898, "EndTime": 1644210907.1412077, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 14}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.012396600667237486, "count": 1, "min": 0.012396600667237486, "max": 0.012396600667237486}}}
# #metrics {"StartTime": 1644210907.1412601, "EndTime": 1644210907.1412754, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 15}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.012499406192096035, "count": 1, "min": 0.012499406192096035, "max": 0.012499406192096035}}}
# #metrics {"StartTime": 1644210907.1413283, "EndTime": 1644210907.141344, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 16}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.1228250465488913, "count": 1, "min": 0.1228250465488913, "max": 0.1228250465488913}}}
# #metrics {"StartTime": 1644210907.1413925, "EndTime": 1644210907.141408, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 17}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.12008383270723735, "count": 1, "min": 0.12008383270723735, "max": 0.12008383270723735}}}
# #metrics {"StartTime": 1644210907.1414561, "EndTime": 1644210907.1414714, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 18}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.12283358952507901, "count": 1, "min": 0.12283358952507901, "max": 0.12283358952507901}}}
# #metrics {"StartTime": 1644210907.1415236, "EndTime": 1644210907.141539, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 19}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.12025850340109974, "count": 1, "min": 0.12025850340109974, "max": 0.12025850340109974}}}
# #metrics {"StartTime": 1644210907.1415877, "EndTime": 1644210907.1416032, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 20}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.019943902858238126, "count": 1, "min": 0.019943902858238126, "max": 0.019943902858238126}}}
# #metrics {"StartTime": 1644210907.14166, "EndTime": 1644210907.141677, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 21}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.01993385848758658, "count": 1, "min": 0.01993385848758658, "max": 0.01993385848758658}}}
# #metrics {"StartTime": 1644210907.141731, "EndTime": 1644210907.1417482, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 22}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.019987651391170133, "count": 1, "min": 0.019987651391170133, "max": 0.019987651391170133}}}
# #metrics {"StartTime": 1644210907.1417906, "EndTime": 1644210907.1418064, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 23}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.01984426697302404, "count": 1, "min": 0.01984426697302404, "max": 0.01984426697302404}}}
# #metrics {"StartTime": 1644210907.1418593, "EndTime": 1644210907.1418753, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 24}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.12367208990739219, "count": 1, "min": 0.12367208990739219, "max": 0.12367208990739219}}}
# #metrics {"StartTime": 1644210907.1419172, "EndTime": 1644210907.1419322, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 25}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.12108522349985401, "count": 1, "min": 0.12108522349985401, "max": 0.12108522349985401}}}
# #metrics {"StartTime": 1644210907.1419704, "EndTime": 1644210907.1419852, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 26}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.12374423226399638, "count": 1, "min": 0.12374423226399638, "max": 0.12374423226399638}}}
# #metrics {"StartTime": 1644210907.1420274, "EndTime": 1644210907.1420429, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 27}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.12116944918800239, "count": 1, "min": 0.12116944918800239, "max": 0.12116944918800239}}}
# #metrics {"StartTime": 1644210907.1420875, "EndTime": 1644210907.1421027, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 28}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.02103997616806821, "count": 1, "min": 0.02103997616806821, "max": 0.02103997616806821}}}
# #metrics {"StartTime": 1644210907.1421533, "EndTime": 1644210907.1421685, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 29}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.020920196363487135, "count": 1, "min": 0.020920196363487135, "max": 0.020920196363487135}}}
# #metrics {"StartTime": 1644210907.142209, "EndTime": 1644210907.1422238, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 30}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.021012824348543756, "count": 1, "min": 0.021012824348543756, "max": 0.021012824348543756}}}
# #metrics {"StartTime": 1644210907.1422873, "EndTime": 1644210907.142304, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 31}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.021031404245476327, "count": 1, "min": 0.021031404245476327, "max": 0.021031404245476327}}}
# [02/07/2022 05:15:07 INFO 139876352214848] #quality_metric: host=algo-1, epoch=0, train binary_classification_cross_entropy_objective <loss>=0.12023840661743777
# [02/07/2022 05:15:07 INFO 139876352214848] #early_stopping_criteria_metric: host=algo-1, epoch=0, criteria=binary_classification_cross_entropy_objective, value=0.012175582823441855
# [02/07/2022 05:15:07 INFO 139876352214848] Epoch 0: Loss improved. Updating best model
# [02/07/2022 05:15:07 INFO 139876352214848] Saving model for epoch: 0
# [02/07/2022 05:15:07 INFO 139876352214848] Saved checkpoint to "/tmp/tmpc1kjm9t6/mx-mod-0000.params"
# [02/07/2022 05:15:07 INFO 139876352214848] #progress_metric: host=algo-1, completed 6.666666666666667 % of epochs
# #metrics {"StartTime": 1644210899.4857247, "EndTime": 1644210907.1561868, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 211364.0, "count": 1, "min": 211364, "max": 211364}, "Total Batches Seen": {"sum": 212.0, "count": 1, "min": 212, "max": 212}, "Max Records Seen Between Resets": {"sum": 199364.0, "count": 1, "min": 199364, "max": 199364}, "Max Batches Seen Between Resets": {"sum": 200.0, "count": 1, "min": 200, "max": 200}, "Reset Count": {"sum": 3.0, "count": 1, "min": 3, "max": 3}, "Number of Records Since Last Reset": {"sum": 199364.0, "count": 1, "min": 199364, "max": 199364}, "Number of Batches Since Last Reset": {"sum": 200.0, "count": 1, "min": 200, "max": 200}}}
# [02/07/2022 05:15:07 INFO 139876352214848] #throughput_metric: host=algo-1, train throughput=25990.65617632761 records/second
# [2022-02-07 05:15:14.482] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 5, "duration": 7324, "num_examples": 200, "num_bytes": 33493152}
# #metrics {"StartTime": 1644210914.482495, "EndTime": 1644210914.4826028, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 0}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.016883339575187645, "count": 1, "min": 0.016883339575187645, "max": 0.016883339575187645}}}
# #metrics {"StartTime": 1644210914.4827073, "EndTime": 1644210914.482727, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 1}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.014893327607581363, "count": 1, "min": 0.014893327607581363, "max": 0.014893327607581363}}}
# #metrics {"StartTime": 1644210914.4827836, "EndTime": 1644210914.4827993, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 2}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.01687481061178236, "count": 1, "min": 0.01687481061178236, "max": 0.01687481061178236}}}
# #metrics {"StartTime": 1644210914.4828568, "EndTime": 1644210914.4828732, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 3}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.014889016120278056, "count": 1, "min": 0.014889016120278056, "max": 0.014889016120278056}}}
# #metrics {"StartTime": 1644210914.4829242, "EndTime": 1644210914.4829402, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 4}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.0054091289906046496, "count": 1, "min": 0.0054091289906046496, "max": 0.0054091289906046496}}}
# #metrics {"StartTime": 1644210914.4829926, "EndTime": 1644210914.4830134, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 5}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.0055940955086569094, "count": 1, "min": 0.0055940955086569094, "max": 0.0055940955086569094}}}
# #metrics {"StartTime": 1644210914.4830644, "EndTime": 1644210914.4830801, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 6}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.00551705657522283, "count": 1, "min": 0.00551705657522283, "max": 0.00551705657522283}}}
# #metrics {"StartTime": 1644210914.4831383, "EndTime": 1644210914.483155, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 7}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.005566651671825342, "count": 1, "min": 0.005566651671825342, "max": 0.005566651671825342}}}
# #metrics {"StartTime": 1644210914.4831991, "EndTime": 1644210914.4832144, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 8}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.0170403941312627, "count": 1, "min": 0.0170403941312627, "max": 0.0170403941312627}}}
# #metrics {"StartTime": 1644210914.4832656, "EndTime": 1644210914.4832811, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 9}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.015086053342675444, "count": 1, "min": 0.015086053342675444, "max": 0.015086053342675444}}}
# #metrics {"StartTime": 1644210914.4833274, "EndTime": 1644210914.483342, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 10}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.017052275235928484, "count": 1, "min": 0.017052275235928484, "max": 0.017052275235928484}}}
# #metrics {"StartTime": 1644210914.4833987, "EndTime": 1644210914.4834414, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 11}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.015078012080647837, "count": 1, "min": 0.015078012080647837, "max": 0.015078012080647837}}}
# #metrics {"StartTime": 1644210914.4835007, "EndTime": 1644210914.4835184, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 12}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.005623061710715893, "count": 1, "min": 0.005623061710715893, "max": 0.005623061710715893}}}
# #metrics {"StartTime": 1644210914.4835665, "EndTime": 1644210914.4835823, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 13}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.005685889098512468, "count": 1, "min": 0.005685889098512468, "max": 0.005685889098512468}}}
# #metrics {"StartTime": 1644210914.483632, "EndTime": 1644210914.4836488, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 14}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.005619973746376421, "count": 1, "min": 0.005619973746376421, "max": 0.005619973746376421}}}
# #metrics {"StartTime": 1644210914.4837008, "EndTime": 1644210914.483716, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 15}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.005672148302122576, "count": 1, "min": 0.005672148302122576, "max": 0.005672148302122576}}}
# #metrics {"StartTime": 1644210914.4837713, "EndTime": 1644210914.483787, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 16}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.02126987413665158, "count": 1, "min": 0.02126987413665158, "max": 0.02126987413665158}}}
# #metrics {"StartTime": 1644210914.483835, "EndTime": 1644210914.4838457, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 17}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.019476390440859387, "count": 1, "min": 0.019476390440859387, "max": 0.019476390440859387}}}
# #metrics {"StartTime": 1644210914.4838793, "EndTime": 1644210914.4838884, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 18}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.02127108111932649, "count": 1, "min": 0.02127108111932649, "max": 0.02127108111932649}}}
# #metrics {"StartTime": 1644210914.4839191, "EndTime": 1644210914.483927, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 19}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.01948852028679009, "count": 1, "min": 0.01948852028679009, "max": 0.01948852028679009}}}
# #metrics {"StartTime": 1644210914.4839563, "EndTime": 1644210914.483964, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 20}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.012074755899271174, "count": 1, "min": 0.012074755899271174, "max": 0.012074755899271174}}}
# #metrics {"StartTime": 1644210914.4840078, "EndTime": 1644210914.4840188, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 21}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.012111119604589951, "count": 1, "min": 0.012111119604589951, "max": 0.012111119604589951}}}
# #metrics {"StartTime": 1644210914.4840631, "EndTime": 1644210914.4840734, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 22}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.01207915733866955, "count": 1, "min": 0.01207915733866955, "max": 0.01207915733866955}}}
# #metrics {"StartTime": 1644210914.484106, "EndTime": 1644210914.4841142, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 23}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.01210820182843424, "count": 1, "min": 0.01210820182843424, "max": 0.01210820182843424}}}
# #metrics {"StartTime": 1644210914.484143, "EndTime": 1644210914.484153, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 24}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.022298133768627992, "count": 1, "min": 0.022298133768627992, "max": 0.022298133768627992}}}
# #metrics {"StartTime": 1644210914.4842093, "EndTime": 1644210914.4842193, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 25}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.020528922866936306, "count": 1, "min": 0.020528922866936306, "max": 0.020528922866936306}}}
# #metrics {"StartTime": 1644210914.4842455, "EndTime": 1644210914.4842525, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 26}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.022301760285343957, "count": 1, "min": 0.022301760285343957, "max": 0.022301760285343957}}}
# #metrics {"StartTime": 1644210914.4842806, "EndTime": 1644210914.4842885, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 27}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.020534939981585173, "count": 1, "min": 0.020534939981585173, "max": 0.020534939981585173}}}
# #metrics {"StartTime": 1644210914.4843173, "EndTime": 1644210914.484325, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 28}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.01314413232719479, "count": 1, "min": 0.01314413232719479, "max": 0.01314413232719479}}}
# #metrics {"StartTime": 1644210914.48437, "EndTime": 1644210914.484382, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 29}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.013147845992490874, "count": 1, "min": 0.013147845992490874, "max": 0.013147845992490874}}}
# #metrics {"StartTime": 1644210914.4844146, "EndTime": 1644210914.4844227, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 30}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.013144269559251603, "count": 1, "min": 0.013144269559251603, "max": 0.013144269559251603}}}
# #metrics {"StartTime": 1644210914.4844465, "EndTime": 1644210914.4844534, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 31}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.013148174486567627, "count": 1, "min": 0.013148174486567627, "max": 0.013148174486567627}}}
# [02/07/2022 05:15:14 INFO 139876352214848] #quality_metric: host=algo-1, epoch=1, train binary_classification_cross_entropy_objective <loss>=0.016883339575187645
# [02/07/2022 05:15:14 INFO 139876352214848] #early_stopping_criteria_metric: host=algo-1, epoch=1, criteria=binary_classification_cross_entropy_objective, value=0.0054091289906046496
# [02/07/2022 05:15:14 INFO 139876352214848] Epoch 1: Loss improved. Updating best model
# [02/07/2022 05:15:14 INFO 139876352214848] Saving model for epoch: 1
# [02/07/2022 05:15:14 INFO 139876352214848] Saved checkpoint to "/tmp/tmp8d4d0mbc/mx-mod-0000.params"
# [02/07/2022 05:15:14 INFO 139876352214848] #progress_metric: host=algo-1, completed 13.333333333333334 % of epochs
# #metrics {"StartTime": 1644210907.1577451, "EndTime": 1644210914.4936817, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 410728.0, "count": 1, "min": 410728, "max": 410728}, "Total Batches Seen": {"sum": 412.0, "count": 1, "min": 412, "max": 412}, "Max Records Seen Between Resets": {"sum": 199364.0, "count": 1, "min": 199364, "max": 199364}, "Max Batches Seen Between Resets": {"sum": 200.0, "count": 1, "min": 200, "max": 200}, "Reset Count": {"sum": 4.0, "count": 1, "min": 4, "max": 4}, "Number of Records Since Last Reset": {"sum": 199364.0, "count": 1, "min": 199364, "max": 199364}, "Number of Batches Since Last Reset": {"sum": 200.0, "count": 1, "min": 200, "max": 200}}}
# [02/07/2022 05:15:14 INFO 139876352214848] #throughput_metric: host=algo-1, train throughput=27175.719576800224 records/second
# [2022-02-07 05:15:21.608] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 7, "duration": 7112, "num_examples": 200, "num_bytes": 33493152}
# #metrics {"StartTime": 1644210921.608087, "EndTime": 1644210921.6081886, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 0}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.010249469512671083, "count": 1, "min": 0.010249469512671083, "max": 0.010249469512671083}}}
# #metrics {"StartTime": 1644210921.6082842, "EndTime": 1644210921.6083028, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 1}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.008671593309047832, "count": 1, "min": 0.008671593309047832, "max": 0.008671593309047832}}}
# #metrics {"StartTime": 1644210921.6083534, "EndTime": 1644210921.6083717, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 2}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.010244108916527063, "count": 1, "min": 0.010244108916527063, "max": 0.010244108916527063}}}
# #metrics {"StartTime": 1644210921.6084104, "EndTime": 1644210921.6084201, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 3}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.00867205645930228, "count": 1, "min": 0.00867205645930228, "max": 0.00867205645930228}}}
# #metrics {"StartTime": 1644210921.6084545, "EndTime": 1644210921.6084638, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 4}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.004918119081076066, "count": 1, "min": 0.004918119081076066, "max": 0.004918119081076066}}}
# #metrics {"StartTime": 1644210921.608497, "EndTime": 1644210921.6085076, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 5}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.005651303291320801, "count": 1, "min": 0.005651303291320801, "max": 0.005651303291320801}}}
# #metrics {"StartTime": 1644210921.608552, "EndTime": 1644210921.6085644, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 6}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.0049273479259643125, "count": 1, "min": 0.0049273479259643125, "max": 0.0049273479259643125}}}
# #metrics {"StartTime": 1644210921.6086054, "EndTime": 1644210921.6086166, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 7}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.005490868361226878, "count": 1, "min": 0.005490868361226878, "max": 0.005490868361226878}}}
# #metrics {"StartTime": 1644210921.6086814, "EndTime": 1644210921.608695, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 8}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.010515944255656334, "count": 1, "min": 0.010515944255656334, "max": 0.010515944255656334}}}
# #metrics {"StartTime": 1644210921.6087432, "EndTime": 1644210921.6087575, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 9}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.009003221483086821, "count": 1, "min": 0.009003221483086821, "max": 0.009003221483086821}}}
# #metrics {"StartTime": 1644210921.6088, "EndTime": 1644210921.6088457, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 10}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.010521823832737141, "count": 1, "min": 0.010521823832737141, "max": 0.010521823832737141}}}
# #metrics {"StartTime": 1644210921.608889, "EndTime": 1644210921.6088996, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 11}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.008999888767549142, "count": 1, "min": 0.008999888767549142, "max": 0.008999888767549142}}}
# #metrics {"StartTime": 1644210921.6089337, "EndTime": 1644210921.608943, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 12}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.005593623910117988, "count": 1, "min": 0.005593623910117988, "max": 0.005593623910117988}}}
# #metrics {"StartTime": 1644210921.608976, "EndTime": 1644210921.609011, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 13}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.005721277174338624, "count": 1, "min": 0.005721277174338624, "max": 0.005721277174338624}}}
# #metrics {"StartTime": 1644210921.6090512, "EndTime": 1644210921.609061, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 14}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.005546630558656089, "count": 1, "min": 0.005546630558656089, "max": 0.005546630558656089}}}
# #metrics {"StartTime": 1644210921.6090941, "EndTime": 1644210921.6091032, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 15}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.005712993024581641, "count": 1, "min": 0.005712993024581641, "max": 0.005712993024581641}}}
# #metrics {"StartTime": 1644210921.6091356, "EndTime": 1644210921.6091447, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 16}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.015533093172102119, "count": 1, "min": 0.015533093172102119, "max": 0.015533093172102119}}}
# #metrics {"StartTime": 1644210921.6091795, "EndTime": 1644210921.6091886, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 17}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.0142904183541111, "count": 1, "min": 0.0142904183541111, "max": 0.0142904183541111}}}
# #metrics {"StartTime": 1644210921.6092215, "EndTime": 1644210921.6092358, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 18}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.01553408638556399, "count": 1, "min": 0.01553408638556399, "max": 0.01553408638556399}}}
# #metrics {"StartTime": 1644210921.6092677, "EndTime": 1644210921.609277, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 19}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.014295967495022108, "count": 1, "min": 0.014295967495022108, "max": 0.014295967495022108}}}
# #metrics {"StartTime": 1644210921.609309, "EndTime": 1644210921.6093178, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 20}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.012072144002171617, "count": 1, "min": 0.012072144002171617, "max": 0.012072144002171617}}}
# #metrics {"StartTime": 1644210921.6093502, "EndTime": 1644210921.609359, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 21}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.0121305170963757, "count": 1, "min": 0.0121305170963757, "max": 0.0121305170963757}}}
# #metrics {"StartTime": 1644210921.6093917, "EndTime": 1644210921.6094005, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 22}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.012072037987373583, "count": 1, "min": 0.012072037987373583, "max": 0.012072037987373583}}}
# #metrics {"StartTime": 1644210921.609433, "EndTime": 1644210921.6094418, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 23}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.012126008991021007, "count": 1, "min": 0.012126008991021007, "max": 0.012126008991021007}}}
# #metrics {"StartTime": 1644210921.6095278, "EndTime": 1644210921.6095436, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 24}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.016575735899671238, "count": 1, "min": 0.016575735899671238, "max": 0.016575735899671238}}}
# #metrics {"StartTime": 1644210921.6095972, "EndTime": 1644210921.6096127, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 25}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.01536184029123891, "count": 1, "min": 0.01536184029123891, "max": 0.01536184029123891}}}
# #metrics {"StartTime": 1644210921.609661, "EndTime": 1644210921.6096754, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 26}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.01657752835451059, "count": 1, "min": 0.01657752835451059, "max": 0.01657752835451059}}}
# #metrics {"StartTime": 1644210921.6097257, "EndTime": 1644210921.6097407, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 27}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.01536392712712887, "count": 1, "min": 0.01536392712712887, "max": 0.01536392712712887}}}
# #metrics {"StartTime": 1644210921.6097784, "EndTime": 1644210921.6097875, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 28}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.013144806580327862, "count": 1, "min": 0.013144806580327862, "max": 0.013144806580327862}}}
# #metrics {"StartTime": 1644210921.6098125, "EndTime": 1644210921.6098197, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 29}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.013156182020153832, "count": 1, "min": 0.013156182020153832, "max": 0.013156182020153832}}}
# #metrics {"StartTime": 1644210921.609849, "EndTime": 1644210921.6098626, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 30}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.013145586877012972, "count": 1, "min": 0.013145586877012972, "max": 0.013145586877012972}}}
# #metrics {"StartTime": 1644210921.6099112, "EndTime": 1644210921.609927, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 31}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.01315547815998595, "count": 1, "min": 0.01315547815998595, "max": 0.01315547815998595}}}
# [02/07/2022 05:15:21 INFO 139876352214848] #quality_metric: host=algo-1, epoch=2, train binary_classification_cross_entropy_objective <loss>=0.010249469512671083
# [02/07/2022 05:15:21 INFO 139876352214848] #early_stopping_criteria_metric: host=algo-1, epoch=2, criteria=binary_classification_cross_entropy_objective, value=0.004918119081076066
# [02/07/2022 05:15:21 INFO 139876352214848] Epoch 2: Loss improved. Updating best model
# [02/07/2022 05:15:21 INFO 139876352214848] Saving model for epoch: 2
# [02/07/2022 05:15:21 INFO 139876352214848] Saved checkpoint to "/tmp/tmp2xp31p7x/mx-mod-0000.params"
# [02/07/2022 05:15:21 INFO 139876352214848] #progress_metric: host=algo-1, completed 20.0 % of epochs
# #metrics {"StartTime": 1644210914.495175, "EndTime": 1644210921.6192403, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 610092.0, "count": 1, "min": 610092, "max": 610092}, "Total Batches Seen": {"sum": 612.0, "count": 1, "min": 612, "max": 612}, "Max Records Seen Between Resets": {"sum": 199364.0, "count": 1, "min": 199364, "max": 199364}, "Max Batches Seen Between Resets": {"sum": 200.0, "count": 1, "min": 200, "max": 200}, "Reset Count": {"sum": 5.0, "count": 1, "min": 5, "max": 5}, "Number of Records Since Last Reset": {"sum": 199364.0, "count": 1, "min": 199364, "max": 199364}, "Number of Batches Since Last Reset": {"sum": 200.0, "count": 1, "min": 200, "max": 200}}}
# [02/07/2022 05:15:21 INFO 139876352214848] #throughput_metric: host=algo-1, train throughput=27984.01928389646 records/second
# [2022-02-07 05:15:28.581] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 9, "duration": 6960, "num_examples": 200, "num_bytes": 33493152}
# #metrics {"StartTime": 1644210928.5817175, "EndTime": 1644210928.5818145, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 0}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.00796071047279703, "count": 1, "min": 0.00796071047279703, "max": 0.00796071047279703}}}
# #metrics {"StartTime": 1644210928.581889, "EndTime": 1644210928.5819073, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 1}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.0066089136300973555, "count": 1, "min": 0.0066089136300973555, "max": 0.0066089136300973555}}}
# #metrics {"StartTime": 1644210928.5819547, "EndTime": 1644210928.5819697, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 2}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.007957086086273194, "count": 1, "min": 0.007957086086273194, "max": 0.007957086086273194}}}
# #metrics {"StartTime": 1644210928.582026, "EndTime": 1644210928.5820417, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 3}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.006610484449108642, "count": 1, "min": 0.006610484449108642, "max": 0.006610484449108642}}}
# ...
# #metrics {"StartTime": 1644211004.1061366, "EndTime": 1644211004.106151, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 4}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.0040303359740044, "count": 1, "min": 0.0040303359740044, "max": 0.0040303359740044}}}
# #metrics {"StartTime": 1644211004.1061819, "EndTime": 1644211004.1061904, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 5}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.005875211362862707, "count": 1, "min": 0.005875211362862707, "max": 0.005875211362862707}}}
# #metrics {"StartTime": 1644211004.106237, "EndTime": 1644211004.1062522, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 6}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.00404278004139512, "count": 1, "min": 0.00404278004139512, "max": 0.00404278004139512}}}
# #metrics {"StartTime": 1644211004.1063023, "EndTime": 1644211004.1063178, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 7}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.005471848284853763, "count": 1, "min": 0.005471848284853763, "max": 0.005471848284853763}}}
# #metrics {"StartTime": 1644211004.1063757, "EndTime": 1644211004.1063921, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 8}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.0055071240819279275, "count": 1, "min": 0.0055071240819279275, "max": 0.0055071240819279275}}}
# #metrics {"StartTime": 1644211004.1064446, "EndTime": 1644211004.1064615, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 9}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.005093599353004341, "count": 1, "min": 0.005093599353004341, "max": 0.005093599353004341}}}
# #metrics {"StartTime": 1644211004.1065147, "EndTime": 1644211004.1065316, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 10}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.005507833725243956, "count": 1, "min": 0.005507833725243956, "max": 0.005507833725243956}}}
# #metrics {"StartTime": 1644211004.1065834, "EndTime": 1644211004.1065996, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 11}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.005093542199638022, "count": 1, "min": 0.005093542199638022, "max": 0.005093542199638022}}}
# #metrics {"StartTime": 1644211004.1066482, "EndTime": 1644211004.1066618, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 12}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.0050990720678813495, "count": 1, "min": 0.0050990720678813495, "max": 0.0050990720678813495}}}
# #metrics {"StartTime": 1644211004.1067095, "EndTime": 1644211004.1067257, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 13}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.005519994659040441, "count": 1, "min": 0.005519994659040441, "max": 0.005519994659040441}}}
# #metrics {"StartTime": 1644211004.1067758, "EndTime": 1644211004.1067924, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 14}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.005098994569862308, "count": 1, "min": 0.005098994569862308, "max": 0.005098994569862308}}}
# #metrics {"StartTime": 1644211004.106842, "EndTime": 1644211004.1068578, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 15}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.005520632858851448, "count": 1, "min": 0.005520632858851448, "max": 0.005520632858851448}}}
# #metrics {"StartTime": 1644211004.106914, "EndTime": 1644211004.106929, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 16}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.012167769629751617, "count": 1, "min": 0.012167769629751617, "max": 0.012167769629751617}}}
# #metrics {"StartTime": 1644211004.1069772, "EndTime": 1644211004.1069934, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 17}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.012054018840118868, "count": 1, "min": 0.012054018840118868, "max": 0.012054018840118868}}}
# #metrics {"StartTime": 1644211004.1070428, "EndTime": 1644211004.1070588, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 18}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.012167777455631811, "count": 1, "min": 0.012167777455631811, "max": 0.012167777455631811}}}
# #metrics {"StartTime": 1644211004.1071026, "EndTime": 1644211004.1071167, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 19}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.012054238608135051, "count": 1, "min": 0.012054238608135051, "max": 0.012054238608135051}}}
# #metrics {"StartTime": 1644211004.1071522, "EndTime": 1644211004.1071613, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 20}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.012039981996593762, "count": 1, "min": 0.012039981996593762, "max": 0.012039981996593762}}}
# #metrics {"StartTime": 1644211004.1071932, "EndTime": 1644211004.107202, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 21}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.012189195263625389, "count": 1, "min": 0.012189195263625389, "max": 0.012189195263625389}}}
# #metrics {"StartTime": 1644211004.1072304, "EndTime": 1644211004.1072433, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 22}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.012040088680521328, "count": 1, "min": 0.012040088680521328, "max": 0.012040088680521328}}}
# #metrics {"StartTime": 1644211004.1072927, "EndTime": 1644211004.1073031, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 23}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.012187875629968979, "count": 1, "min": 0.012187875629968979, "max": 0.012187875629968979}}}
# #metrics {"StartTime": 1644211004.107335, "EndTime": 1644211004.1073434, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 24}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.013193741987698042, "count": 1, "min": 0.013193741987698042, "max": 0.013193741987698042}}}
# #metrics {"StartTime": 1644211004.1073694, "EndTime": 1644211004.1073763, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 25}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.013127850090438997, "count": 1, "min": 0.013127850090438997, "max": 0.013127850090438997}}}
# #metrics {"StartTime": 1644211004.107401, "EndTime": 1644211004.1074078, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 26}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.013193773884270059, "count": 1, "min": 0.013193773884270059, "max": 0.013193773884270059}}}
# #metrics {"StartTime": 1644211004.1074777, "EndTime": 1644211004.1074882, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 27}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.013127679164685196, "count": 1, "min": 0.013127679164685196, "max": 0.013127679164685196}}}
# #metrics {"StartTime": 1644211004.1075158, "EndTime": 1644211004.1075234, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 28}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.013136238493512024, "count": 1, "min": 0.013136238493512024, "max": 0.013136238493512024}}}
# #metrics {"StartTime": 1644211004.1075487, "EndTime": 1644211004.1075556, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 29}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.013258359701190162, "count": 1, "min": 0.013258359701190162, "max": 0.013258359701190162}}}
# #metrics {"StartTime": 1644211004.1075835, "EndTime": 1644211004.1075919, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 30}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.013136125135062328, "count": 1, "min": 0.013136125135062328, "max": 0.013136125135062328}}}
# #metrics {"StartTime": 1644211004.1076355, "EndTime": 1644211004.1076453, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 31}, "Metrics": {"train_binary_classification_cross_entropy_objective": {"sum": 0.013257740079757557, "count": 1, "min": 0.013257740079757557, "max": 0.013257740079757557}}}
# [02/07/2022 05:16:44 INFO 139876352214848] #quality_metric: host=algo-1, epoch=14, train binary_classification_cross_entropy_objective <loss>=0.004796242649830766
# [02/07/2022 05:16:44 INFO 139876352214848] #early_stopping_criteria_metric: host=algo-1, epoch=14, criteria=binary_classification_cross_entropy_objective, value=0.0040303359740044
# [02/07/2022 05:16:44 INFO 139876352214848] Epoch 14: Loss improved. Updating best model
# [02/07/2022 05:16:44 INFO 139876352214848] Saving model for epoch: 14
# [02/07/2022 05:16:44 INFO 139876352214848] Saved checkpoint to "/tmp/tmp3q5_k_06/mx-mod-0000.params"
# [02/07/2022 05:16:44 INFO 139876352214848] #progress_metric: host=algo-1, completed 100.0 % of epochs
# #metrics {"StartTime": 1644210997.345617, "EndTime": 1644211004.1169357, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 3002460.0, "count": 1, "min": 3002460, "max": 3002460}, "Total Batches Seen": {"sum": 3012.0, "count": 1, "min": 3012, "max": 3012}, "Max Records Seen Between Resets": {"sum": 199364.0, "count": 1, "min": 199364, "max": 199364}, "Max Batches Seen Between Resets": {"sum": 200.0, "count": 1, "min": 200, "max": 200}, "Reset Count": {"sum": 17.0, "count": 1, "min": 17, "max": 17}, "Number of Records Since Last Reset": {"sum": 199364.0, "count": 1, "min": 199364, "max": 199364}, "Number of Batches Since Last Reset": {"sum": 200.0, "count": 1, "min": 200, "max": 200}}}
# [02/07/2022 05:16:44 INFO 139876352214848] #throughput_metric: host=algo-1, train throughput=29441.729396836818 records/second
# [02/07/2022 05:16:44 WARNING 139876352214848] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [02/07/2022 05:16:44 WARNING 139876352214848] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [2022-02-07 05:16:44.121] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 33, "duration": 3, "num_examples": 1, "num_bytes": 168000}
# [2022-02-07 05:16:44.663] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 36, "duration": 539, "num_examples": 200, "num_bytes": 33493152}
# [2022-02-07 05:16:45.698] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 38, "duration": 934, "num_examples": 200, "num_bytes": 33493152}
# [02/07/2022 05:16:45 INFO 139876352214848] #train_score (algo-1) : ('binary_classification_cross_entropy_objective', 0.003960911865313041)
# [02/07/2022 05:16:45 INFO 139876352214848] #train_score (algo-1) : ('binary_classification_accuracy', 0.9879416544611865)
# [02/07/2022 05:16:45 INFO 139876352214848] #train_score (algo-1) : ('binary_f_1.000', 0.21180327868852458)
# [02/07/2022 05:16:45 INFO 139876352214848] #train_score (algo-1) : ('precision', 0.11994058670627553)
# [02/07/2022 05:16:45 INFO 139876352214848] #train_score (algo-1) : ('recall', 0.9047619047619048)
# [02/07/2022 05:16:45 INFO 139876352214848] #train_score (algo-1) : ('roc_auc_score', 0.9790894705377465)
# [02/07/2022 05:16:45 INFO 139876352214848] #train_score (algo-1) : ('binary_balanced_accuracy', 0.5)
# [02/07/2022 05:16:45 INFO 139876352214848] #train_score (algo-1) : ('binary_log_loss', 0.6930574032138126)
# [02/07/2022 05:16:45 INFO 139876352214848] #quality_metric: host=algo-1, train binary_classification_cross_entropy_objective <loss>=0.003960911865313041
# [02/07/2022 05:16:45 INFO 139876352214848] #quality_metric: host=algo-1, train binary_classification_accuracy <score>=0.9879416544611865
# [02/07/2022 05:16:45 INFO 139876352214848] #quality_metric: host=algo-1, train binary_f_1.000 <score>=0.21180327868852458
# [02/07/2022 05:16:45 INFO 139876352214848] #quality_metric: host=algo-1, train precision <score>=0.11994058670627553
# [02/07/2022 05:16:45 INFO 139876352214848] #quality_metric: host=algo-1, train recall <score>=0.9047619047619048
# [02/07/2022 05:16:45 INFO 139876352214848] #quality_metric: host=algo-1, train roc_auc_score <score>=0.9790894705377465
# [02/07/2022 05:16:45 INFO 139876352214848] #quality_metric: host=algo-1, train binary_balanced_accuracy <score>=0.5
# [02/07/2022 05:16:46 INFO 139876352214848] #quality_metric: host=algo-1, train binary_log_loss <score>=0.6930574032138126
# [02/07/2022 05:16:46 INFO 139876352214848] Best model found for hyperparameters: {"optimizer": "adam", "learning_rate": 0.1, "wd": 0.0001, "l1": 0.0, "lr_scheduler_step": 10, "lr_scheduler_factor": 0.99, "lr_scheduler_minimum_lr": 1e-05}
# [02/07/2022 05:16:46 INFO 139876352214848] Saved checkpoint to "/tmp/tmp5084o363/mx-mod-0000.params"
# [02/07/2022 05:16:46 INFO 139876352214848] Test data is not provided.
# #metrics {"StartTime": 1644210899.2527823, "EndTime": 1644211006.0062258, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training"}, "Metrics": {"initialize.time": {"sum": 229.4747829437256, "count": 1, "min": 229.4747829437256, "max": 229.4747829437256}, "epochs": {"sum": 15.0, "count": 1, "min": 15, "max": 15}, "check_early_stopping.time": {"sum": 17.22431182861328, "count": 15, "min": 0.9896755218505859, "max": 1.3229846954345703}, "update.time": {"sum": 104564.89062309265, "count": 15, "min": 6569.63586807251, "max": 7663.825035095215}, "finalize.time": {"sum": 1882.7850818634033, "count": 1, "min": 1882.7850818634033, "max": 1882.7850818634033}, "setuptime": {"sum": 28.310537338256836, "count": 1, "min": 28.310537338256836, "max": 28.310537338256836}, "totaltime": {"sum": 106997.64704704285, "count": 1, "min": 106997.64704704285, "max": 106997.64704704285}}}
#
# 2022-02-07 05:17:03 Uploading - Uploading generated training model
# 2022-02-07 05:17:03 Completed - Training job completed
# Training seconds: 147
# Billable seconds: 147
# CPU times: user 813 ms, sys: 61.6 ms, total: 875 ms
# Wall time: 5min 43s

# %% [markdown]
# ### Deploy and evaluate the tuned estimator
#
# Deploy the tuned predictor and evaluate it.
#
# We hypothesized that a tuned model, optimized for a higher recall, would have fewer false negatives (fraudulent transactions incorrectly labeled as valid); did the number of false negatives get reduced after tuning the model?

# %%
# %%time 
# deploy and create a predictor
recall_predictor = linear_recall.deploy(initial_instance_count=1, instance_type='ml.t2.medium')
# Out:
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# --------!CPU times: user 151 ms, sys: 8.34 ms, total: 159 ms
# Wall time: 4min 1s

# %%
print('Metrics for tuned (recall), LinearLearner.\n')

# get metrics for tuned predictor
metrics = evaluate(recall_predictor, 
                   test_features.values.astype('float32'), 
                   test_labels, 
                   verbose=True)
# Out:
# Metrics for tuned (recall), LinearLearner.
#
# prediction (col)    0.0  1.0
# actual (row)
# 0                 84317  991
# 1                    20  115
#
# Recall:     0.852
# Precision:  0.104
# Accuracy:   0.988

# %% [markdown]
# **My notes:** The **false negatives** (1s predicted to be 0s) fell from 36 with the `linear_predictor` to 20 with the `recall_predictor`. As predicted, our recall-optimized model resulted in fewer false negatives.

# %% [markdown]
# ## Delete the endpoint
#
# As always, when you're done evaluating a model, you should delete the endpoint. Below, I'm using the `delete_endpoint` helper function I defined earlier. The model fell short of our target recall of 0.9, however.

# %%
# delete the predictor endpoint 
delete_endpoint(recall_predictor)
# Out:
# The endpoint attribute has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The endpoint attribute has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# Deleted linear-learner-2022-02-07-05-17-22-891

# %% [markdown]
# ---
# ## Improvement: Managing Class Imbalance
#
# We have a model that is tuned to get a higher recall, which aims to reduce the number of false negatives. Earlier, we discussed how class imbalance may actually bias our model towards predicting that all transactions are valid, resulting in higher false negatives and true negatives. It stands to reason that this model could be further improved if we account for this imbalance.
#
# To account for class imbalance during training of a binary classifier, LinearLearner offers the hyperparameter, `positive_example_weight_mult`, which is the weight assigned to positive (1, fraudulent) examples when training a binary classifier. The weight of negative examples (0, valid) is fixed at 1.
#
# ### EXERCISE: Create a LinearLearner with a `positive_example_weight_mult` parameter
#
# In **addition** to tuning a model for higher recall (you may use `linear_recall` as a starting point), you should *add* a parameter that helps account for class imbalance. From the [hyperparameter documentation](https://docs.aws.amazon.com/sagemaker/latest/dg/ll_hyperparameters.html) on `positive_example_weight_mult`, it reads:
# > "If you want the algorithm to choose a weight so that errors in classifying negative vs. positive examples have equal impact on training loss, specify `balanced`."
#
# You could also put in a specific float value, in which case you'd want to weight positive examples more heavily than negative examples, since there are fewer of them.

# %%
# instantiate a LinearLearner

# include params for tuning for higher recall
# *and* account for class imbalance in training data
linear_balanced = LinearLearner(role=role,
                              train_instance_count=1, 
                              train_instance_type='ml.c4.xlarge',
                              predictor_type='binary_classifier',
                              output_path=output_path,
                              sagemaker_session=sagemaker_session,
                              epochs=15,
                              binary_classifier_model_selection_criteria='precision_at_target_recall', # target recall
                              positive_example_weight_mult='balanced',
                              target_recall=0.9) # 90% recall
# Out:
# train_instance_count has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# train_instance_type has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.

# %% [markdown]
# ### EXERCISE: Train the balanced estimator
#
# Fit the new, balanced estimator on the formatted training data.

# %%
# %%time 
# train the estimator on formatted training data
linear_balanced.fit(formatted_train_data)
# Out:
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# 2022-02-07 05:21:34 Starting - Starting the training job...
# 2022-02-07 05:21:57 Starting - Launching requested ML instancesProfilerReport-1644211294: InProgress
# ...
# 2022-02-07 05:22:22 Starting - Preparing the instances for training............
# 2022-02-07 05:24:27 Downloading - Downloading input data...
# 2022-02-07 05:24:58 Training - Training image download completed. Training in progress.Docker entrypoint called with argument(s): train
# Running default environment configuration script
# [02/07/2022 05:24:58 INFO 139639256651584] Reading default configuration from /opt/amazon/lib/python3.7/site-packages/algorithm/resources/default-input.json: {'mini_batch_size': '1000', 'epochs': '15', 'feature_dim': 'auto', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'accuracy', 'f_beta': '1.0', 'target_recall': '0.8', 'target_precision': '0.8', 'num_models': 'auto', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'auto', 'loss': 'auto', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '1', 'accuracy_top_k': '3', 'wd': 'auto', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': 'auto', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': 'auto', 'lr_scheduler_factor': 'auto', 'lr_scheduler_minimum_lr': 'auto', 'positive_example_weight_mult': '1.0', 'balance_multiclass_weights': 'false', 'normalize_data': 'true', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false'}
# [02/07/2022 05:24:58 INFO 139639256651584] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {'positive_example_weight_mult': 'balanced', 'feature_dim': '30', 'predictor_type': 'binary_classifier', 'epochs': '15', 'target_recall': '0.9', 'binary_classifier_model_selection_criteria': 'precision_at_target_recall', 'mini_batch_size': '1000'}
# [02/07/2022 05:24:58 INFO 139639256651584] Final configuration: {'mini_batch_size': '1000', 'epochs': '15', 'feature_dim': '30', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'precision_at_target_recall', 'f_beta': '1.0', 'target_recall': '0.9', 'target_precision': '0.8', 'num_models': 'auto', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'auto', 'loss': 'auto', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '1', 'accuracy_top_k': '3', 'wd': 'auto', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': 'auto', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': 'auto', 'lr_scheduler_factor': 'auto', 'lr_scheduler_minimum_lr': 'auto', 'positive_example_weight_mult': 'balanced', 'balance_multiclass_weights': 'false', 'normalize_data': 'true', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false', 'predictor_type': 'binary_classifier'}
# [02/07/2022 05:24:58 WARNING 139639256651584] Loggers have already been setup.
# Process 1 is a worker.
# [02/07/2022 05:24:58 INFO 139639256651584] Using default worker.
# [02/07/2022 05:24:59 INFO 139639256651584] Checkpoint loading and saving are disabled.
# [2022-02-07 05:24:59.093] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration": 27, "num_examples": 1, "num_bytes": 168000}
# [02/07/2022 05:24:59 INFO 139639256651584] Create Store: local
# [2022-02-07 05:24:59.196] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 1, "duration": 102, "num_examples": 11, "num_bytes": 1848000}
# [02/07/2022 05:24:59 INFO 139639256651584] Scaler algorithm parameters
#  <algorithm.scaler.ScalerAlgorithmStable object at 0x7efff40a68d0>
# [02/07/2022 05:24:59 INFO 139639256651584] Scaling model computed with parameters:
#  {'stdev_label': None, 'stdev_weight':
# [4.7823008e+04 1.8987731e+00 1.5821997e+00 1.5291911e+00 1.4364978e+00
#  1.3388461e+00 1.2955806e+00 1.1771069e+00 1.2127448e+00 1.0843055e+00
#  1.0475702e+00 1.0230465e+00 1.0090139e+00 1.0057642e+00 9.5122164e-01
#  9.2613727e-01 8.7072927e-01 8.6057234e-01 8.3151484e-01 8.2762748e-01
#  7.1313608e-01 7.3347980e-01 7.2524083e-01 5.6213826e-01 6.0201687e-01
#  5.1174247e-01 4.8000538e-01 3.7595215e-01 2.7081874e-01 2.3656270e+02]
# <NDArray 30 @cpu(0)>, 'mean_label': None, 'mean_weight':
# [ 9.4275984e+04 -1.7378727e-02  1.5538026e-02  2.5005125e-02
#   3.3166975e-02  1.8197566e-02  1.7799012e-03  6.9396999e-03
#   9.8540336e-03 -3.0757964e-02 -1.2736557e-02  4.0434714e-04
#  -1.4243029e-02  1.6704608e-02  2.2619881e-02 -9.6982103e-03
#  -4.7834702e-03 -1.6767335e-04 -9.0120723e-03 -3.0407687e-03
#   4.6031545e-03 -4.0078526e-03 -1.2586080e-04  1.2784966e-03
#   3.7617318e-03 -3.1254767e-03 -8.2200055e-04  3.4045519e-03
#  -1.0332187e-03  8.7559837e+01]
# <NDArray 30 @cpu(0)>}
# [02/07/2022 05:24:59 INFO 139639256651584] nvidia-smi: took 0.055 seconds to run.
# [02/07/2022 05:24:59 INFO 139639256651584] nvidia-smi identified 0 GPUs.
# [02/07/2022 05:24:59 INFO 139639256651584] Number of GPUs being used: 0
# #metrics {"StartTime": 1644211499.4086504, "EndTime": 1644211499.4087021, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "Meta": "init_train_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 12000.0, "count": 1, "min": 12000, "max": 12000}, "Total Batches Seen": {"sum": 12.0, "count": 1, "min": 12, "max": 12}, "Max Records Seen Between Resets": {"sum": 11000.0, "count": 1, "min": 11000, "max": 11000}, "Max Batches Seen Between Resets": {"sum": 11.0, "count": 1, "min": 11, "max": 11}, "Reset Count": {"sum": 2.0, "count": 1, "min": 2, "max": 2}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [2022-02-07 05:25:06.541] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 3, "duration": 7131, "num_examples": 200, "num_bytes": 33493152}
# #metrics {"StartTime": 1644211506.5413647, "EndTime": 1644211506.541452, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 0}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5791407177028943, "count": 1, "min": 0.5791407177028943, "max": 0.5791407177028943}}}
# #metrics {"StartTime": 1644211506.5415244, "EndTime": 1644211506.5415418, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 1}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.4759549259971734, "count": 1, "min": 0.4759549259971734, "max": 0.4759549259971734}}}
# #metrics {"StartTime": 1644211506.541592, "EndTime": 1644211506.5416071, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 2}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.4948354150206599, "count": 1, "min": 0.4948354150206599, "max": 0.4948354150206599}}}
# #metrics {"StartTime": 1644211506.5416553, "EndTime": 1644211506.541672, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 3}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5374999441789023, "count": 1, "min": 0.5374999441789023, "max": 0.5374999441789023}}}
# #metrics {"StartTime": 1644211506.5417225, "EndTime": 1644211506.5417385, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 4}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6132990110579447, "count": 1, "min": 0.6132990110579447, "max": 0.6132990110579447}}}
# #metrics {"StartTime": 1644211506.5417907, "EndTime": 1644211506.541806, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 5}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.650242357378629, "count": 1, "min": 0.650242357378629, "max": 0.650242357378629}}}
# #metrics {"StartTime": 1644211506.5418594, "EndTime": 1644211506.541876, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 6}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6198758794314897, "count": 1, "min": 0.6198758794314897, "max": 0.6198758794314897}}}
# #metrics {"StartTime": 1644211506.5419297, "EndTime": 1644211506.5419462, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 7}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.642763320194417, "count": 1, "min": 0.642763320194417, "max": 0.642763320194417}}}
# #metrics {"StartTime": 1644211506.5420065, "EndTime": 1644211506.5420213, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 8}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.4923872120919539, "count": 1, "min": 0.4923872120919539, "max": 0.4923872120919539}}}
# #metrics {"StartTime": 1644211506.5420697, "EndTime": 1644211506.5420854, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 9}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5910773196579823, "count": 1, "min": 0.5910773196579823, "max": 0.5910773196579823}}}
# #metrics {"StartTime": 1644211506.5421345, "EndTime": 1644211506.5421503, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 10}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5660034152850434, "count": 1, "min": 0.5660034152850434, "max": 0.5660034152850434}}}
# #metrics {"StartTime": 1644211506.5421968, "EndTime": 1644211506.5422127, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 11}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.570866738247512, "count": 1, "min": 0.570866738247512, "max": 0.570866738247512}}}
# #metrics {"StartTime": 1644211506.5422964, "EndTime": 1644211506.542313, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 12}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.603102036327573, "count": 1, "min": 0.603102036327573, "max": 0.603102036327573}}}
# #metrics {"StartTime": 1644211506.5423644, "EndTime": 1644211506.5423803, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 13}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6313092581015736, "count": 1, "min": 0.6313092581015736, "max": 0.6313092581015736}}}
# #metrics {"StartTime": 1644211506.5424235, "EndTime": 1644211506.542434, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 14}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6069122777967597, "count": 1, "min": 0.6069122777967597, "max": 0.6069122777967597}}}
# #metrics {"StartTime": 1644211506.5424805, "EndTime": 1644211506.542496, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 15}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6302709089116235, "count": 1, "min": 0.6302709089116235, "max": 0.6302709089116235}}}
# #metrics {"StartTime": 1644211506.5425456, "EndTime": 1644211506.5425613, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 16}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6274360078591198, "count": 1, "min": 0.6274360078591198, "max": 0.6274360078591198}}}
# #metrics {"StartTime": 1644211506.5426092, "EndTime": 1644211506.5426242, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 17}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.512769868476906, "count": 1, "min": 0.512769868476906, "max": 0.512769868476906}}}
# #metrics {"StartTime": 1644211506.5426722, "EndTime": 1644211506.542688, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 18}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5364223231790054, "count": 1, "min": 0.5364223231790054, "max": 0.5364223231790054}}}
# #metrics {"StartTime": 1644211506.5427456, "EndTime": 1644211506.542762, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 19}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5448161246141596, "count": 1, "min": 0.5448161246141596, "max": 0.5448161246141596}}}
# #metrics {"StartTime": 1644211506.5428207, "EndTime": 1644211506.54288, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 20}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.540332931163922, "count": 1, "min": 0.540332931163922, "max": 0.540332931163922}}}
# #metrics {"StartTime": 1644211506.5429473, "EndTime": 1644211506.5429645, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 21}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.541313360655128, "count": 1, "min": 0.541313360655128, "max": 0.541313360655128}}}
# #metrics {"StartTime": 1644211506.543014, "EndTime": 1644211506.5430305, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 22}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.536809625117623, "count": 1, "min": 0.536809625117623, "max": 0.536809625117623}}}
# #metrics {"StartTime": 1644211506.5430887, "EndTime": 1644211506.5431, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 23}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5356268091920632, "count": 1, "min": 0.5356268091920632, "max": 0.5356268091920632}}}
# #metrics {"StartTime": 1644211506.5431473, "EndTime": 1644211506.5431628, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 24}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.081357410986819, "count": 1, "min": 1.081357410986819, "max": 1.081357410986819}}}
# #metrics {"StartTime": 1644211506.5439959, "EndTime": 1644211506.5440161, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 25}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.0807654687315975, "count": 1, "min": 1.0807654687315975, "max": 1.0807654687315975}}}
# #metrics {"StartTime": 1644211506.5440633, "EndTime": 1644211506.544073, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 26}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.107846775994229, "count": 1, "min": 1.107846775994229, "max": 1.107846775994229}}}
# #metrics {"StartTime": 1644211506.5441012, "EndTime": 1644211506.5441086, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 27}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.0852037635688208, "count": 1, "min": 1.0852037635688208, "max": 1.0852037635688208}}}
# #metrics {"StartTime": 1644211506.5441694, "EndTime": 1644211506.5441835, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 28}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.2230319136423082, "count": 1, "min": 1.2230319136423082, "max": 1.2230319136423082}}}
# #metrics {"StartTime": 1644211506.5442247, "EndTime": 1644211506.5442371, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 29}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.240264271721768, "count": 1, "min": 1.240264271721768, "max": 1.240264271721768}}}
# #metrics {"StartTime": 1644211506.544265, "EndTime": 1644211506.5442724, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 30}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.2185808203615736, "count": 1, "min": 1.2185808203615736, "max": 1.2185808203615736}}}
# #metrics {"StartTime": 1644211506.5442972, "EndTime": 1644211506.5443096, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 31}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.2268015014801792, "count": 1, "min": 1.2268015014801792, "max": 1.2268015014801792}}}
# [02/07/2022 05:25:06 INFO 139639256651584] #quality_metric: host=algo-1, epoch=0, train binary_classification_weighted_cross_entropy_objective <loss>=0.5791407177028943
# [02/07/2022 05:25:06 INFO 139639256651584] #early_stopping_criteria_metric: host=algo-1, epoch=0, criteria=binary_classification_weighted_cross_entropy_objective, value=0.4759549259971734
# [02/07/2022 05:25:06 INFO 139639256651584] Epoch 0: Loss improved. Updating best model
# [02/07/2022 05:25:06 INFO 139639256651584] Saving model for epoch: 0
# [02/07/2022 05:25:06 INFO 139639256651584] Saved checkpoint to "/tmp/tmpmqrvwbzs/mx-mod-0000.params"
# [02/07/2022 05:25:06 INFO 139639256651584] #progress_metric: host=algo-1, completed 6.666666666666667 % of epochs
# #metrics {"StartTime": 1644211499.4090555, "EndTime": 1644211506.5624373, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 211364.0, "count": 1, "min": 211364, "max": 211364}, "Total Batches Seen": {"sum": 212.0, "count": 1, "min": 212, "max": 212}, "Max Records Seen Between Resets": {"sum": 199364.0, "count": 1, "min": 199364, "max": 199364}, "Max Batches Seen Between Resets": {"sum": 200.0, "count": 1, "min": 200, "max": 200}, "Reset Count": {"sum": 3.0, "count": 1, "min": 3, "max": 3}, "Number of Records Since Last Reset": {"sum": 199364.0, "count": 1, "min": 199364, "max": 199364}, "Number of Batches Since Last Reset": {"sum": 200.0, "count": 1, "min": 200, "max": 200}}}
# [02/07/2022 05:25:06 INFO 139639256651584] #throughput_metric: host=algo-1, train throughput=27869.43794587046 records/second
# [2022-02-07 05:25:13.859] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 5, "duration": 7296, "num_examples": 200, "num_bytes": 33493152}
# #metrics {"StartTime": 1644211513.8600004, "EndTime": 1644211513.8600993, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 0}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.3762333395109704, "count": 1, "min": 0.3762333395109704, "max": 0.3762333395109704}}}
# #metrics {"StartTime": 1644211513.860177, "EndTime": 1644211513.8601913, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 1}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.3452077499849712, "count": 1, "min": 0.3452077499849712, "max": 0.3452077499849712}}}
# #metrics {"StartTime": 1644211513.8602302, "EndTime": 1644211513.8602405, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 2}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.3545212267391646, "count": 1, "min": 0.3545212267391646, "max": 0.3545212267391646}}}
# #metrics {"StartTime": 1644211513.860421, "EndTime": 1644211513.8604367, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 3}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.358282039009746, "count": 1, "min": 0.358282039009746, "max": 0.358282039009746}}}
# #metrics {"StartTime": 1644211513.8604796, "EndTime": 1644211513.86049, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 4}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.503855560801137, "count": 1, "min": 0.503855560801137, "max": 0.503855560801137}}}
# #metrics {"StartTime": 1644211513.860524, "EndTime": 1644211513.8605337, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 5}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5762882809279553, "count": 1, "min": 0.5762882809279553, "max": 0.5762882809279553}}}
# #metrics {"StartTime": 1644211513.8605666, "EndTime": 1644211513.860576, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 6}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5095617222809912, "count": 1, "min": 0.5095617222809912, "max": 0.5095617222809912}}}
# #metrics {"StartTime": 1644211513.8606088, "EndTime": 1644211513.8606179, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 7}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5621733702846508, "count": 1, "min": 0.5621733702846508, "max": 0.5621733702846508}}}
# #metrics {"StartTime": 1644211513.8606505, "EndTime": 1644211513.8606596, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 8}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.35608179332023887, "count": 1, "min": 0.35608179332023887, "max": 0.35608179332023887}}}
# #metrics {"StartTime": 1644211513.8607035, "EndTime": 1644211513.8607125, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 9}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.37639001955578677, "count": 1, "min": 0.37639001955578677, "max": 0.37639001955578677}}}
# #metrics {"StartTime": 1644211513.8607445, "EndTime": 1644211513.8607533, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 10}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.3734735677901225, "count": 1, "min": 0.3734735677901225, "max": 0.3734735677901225}}}
# #metrics {"StartTime": 1644211513.860785, "EndTime": 1644211513.8607938, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 11}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.3714105723778806, "count": 1, "min": 0.3714105723778806, "max": 0.3714105723778806}}}
# #metrics {"StartTime": 1644211513.8608253, "EndTime": 1644211513.8608344, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 12}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.4968251642581806, "count": 1, "min": 0.4968251642581806, "max": 0.4968251642581806}}}
# #metrics {"StartTime": 1644211513.8608656, "EndTime": 1644211513.8608744, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 13}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5793348179342759, "count": 1, "min": 0.5793348179342759, "max": 0.5793348179342759}}}
# #metrics {"StartTime": 1644211513.860906, "EndTime": 1644211513.8609147, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 14}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5010429530119777, "count": 1, "min": 0.5010429530119777, "max": 0.5010429530119777}}}
# #metrics {"StartTime": 1644211513.8609462, "EndTime": 1644211513.8609552, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 15}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5806286224671944, "count": 1, "min": 0.5806286224671944, "max": 0.5806286224671944}}}
# #metrics {"StartTime": 1644211513.8609865, "EndTime": 1644211513.8609953, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 16}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.45959482746986885, "count": 1, "min": 0.45959482746986885, "max": 0.45959482746986885}}}
# #metrics {"StartTime": 1644211513.8610752, "EndTime": 1644211513.8610885, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 17}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.45221469054869073, "count": 1, "min": 0.45221469054869073, "max": 0.45221469054869073}}}
# #metrics {"StartTime": 1644211513.8611267, "EndTime": 1644211513.8611364, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 18}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.4510753076447913, "count": 1, "min": 0.4510753076447913, "max": 0.4510753076447913}}}
# #metrics {"StartTime": 1644211513.861169, "EndTime": 1644211513.8611782, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 19}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.45293791068379, "count": 1, "min": 0.45293791068379, "max": 0.45293791068379}}}
# #metrics {"StartTime": 1644211513.8612094, "EndTime": 1644211513.861218, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 20}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.513988640119083, "count": 1, "min": 0.513988640119083, "max": 0.513988640119083}}}
# #metrics {"StartTime": 1644211513.8612492, "EndTime": 1644211513.8612585, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 21}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5301194904844965, "count": 1, "min": 0.5301194904844965, "max": 0.5301194904844965}}}
# #metrics {"StartTime": 1644211513.8612924, "EndTime": 1644211513.861306, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 22}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5141575448309357, "count": 1, "min": 0.5141575448309357, "max": 0.5141575448309357}}}
# #metrics {"StartTime": 1644211513.861335, "EndTime": 1644211513.8613427, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 23}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5306000879949062, "count": 1, "min": 0.5306000879949062, "max": 0.5306000879949062}}}
# #metrics {"StartTime": 1644211513.8613653, "EndTime": 1644211513.861372, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 24}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.0809531622651833, "count": 1, "min": 1.0809531622651833, "max": 1.0809531622651833}}}
# #metrics {"StartTime": 1644211513.861394, "EndTime": 1644211513.8614004, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 25}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.0806157694294225, "count": 1, "min": 1.0806157694294225, "max": 1.0806157694294225}}}
# #metrics {"StartTime": 1644211513.8614218, "EndTime": 1644211513.8614283, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 26}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.0811927944164181, "count": 1, "min": 1.0811927944164181, "max": 1.0811927944164181}}}
# #metrics {"StartTime": 1644211513.8614497, "EndTime": 1644211513.8614562, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 27}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.0806420212942152, "count": 1, "min": 1.0806420212942152, "max": 1.0806420212942152}}}
# #metrics {"StartTime": 1644211513.8614774, "EndTime": 1644211513.8614838, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 28}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.1822309901558574, "count": 1, "min": 1.1822309901558574, "max": 1.1822309901558574}}}
# #metrics {"StartTime": 1644211513.8615053, "EndTime": 1644211513.8615117, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 29}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.2228483647485475, "count": 1, "min": 1.2228483647485475, "max": 1.2228483647485475}}}
# #metrics {"StartTime": 1644211513.8615355, "EndTime": 1644211513.8615425, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 30}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.1816888533549093, "count": 1, "min": 1.1816888533549093, "max": 1.1816888533549093}}}
# #metrics {"StartTime": 1644211513.8615642, "EndTime": 1644211513.8615706, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 31}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.2195927194566583, "count": 1, "min": 1.2195927194566583, "max": 1.2195927194566583}}}
# [02/07/2022 05:25:13 INFO 139639256651584] #quality_metric: host=algo-1, epoch=1, train binary_classification_weighted_cross_entropy_objective <loss>=0.3762333395109704
# [02/07/2022 05:25:13 INFO 139639256651584] #early_stopping_criteria_metric: host=algo-1, epoch=1, criteria=binary_classification_weighted_cross_entropy_objective, value=0.3452077499849712
# [02/07/2022 05:25:13 INFO 139639256651584] Epoch 1: Loss improved. Updating best model
# [02/07/2022 05:25:13 INFO 139639256651584] Saving model for epoch: 1
# [02/07/2022 05:25:13 INFO 139639256651584] Saved checkpoint to "/tmp/tmpkm_rm60w/mx-mod-0000.params"
# [02/07/2022 05:25:13 INFO 139639256651584] #progress_metric: host=algo-1, completed 13.333333333333334 % of epochs
# #metrics {"StartTime": 1644211506.5637271, "EndTime": 1644211513.876421, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 410728.0, "count": 1, "min": 410728, "max": 410728}, "Total Batches Seen": {"sum": 412.0, "count": 1, "min": 412, "max": 412}, "Max Records Seen Between Resets": {"sum": 199364.0, "count": 1, "min": 199364, "max": 199364}, "Max Batches Seen Between Resets": {"sum": 200.0, "count": 1, "min": 200, "max": 200}, "Reset Count": {"sum": 4.0, "count": 1, "min": 4, "max": 4}, "Number of Records Since Last Reset": {"sum": 199364.0, "count": 1, "min": 199364, "max": 199364}, "Number of Batches Since Last Reset": {"sum": 200.0, "count": 1, "min": 200, "max": 200}}}
# [02/07/2022 05:25:13 INFO 139639256651584] #throughput_metric: host=algo-1, train throughput=27262.18902793957 records/second
# [2022-02-07 05:25:20.854] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 7, "duration": 6976, "num_examples": 200, "num_bytes": 33493152}
# #metrics {"StartTime": 1644211520.8549592, "EndTime": 1644211520.8550372, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 0}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.3391149269755761, "count": 1, "min": 0.3391149269755761, "max": 0.3391149269755761}}}
# #metrics {"StartTime": 1644211520.8551004, "EndTime": 1644211520.8551137, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 1}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.3195404147047493, "count": 1, "min": 0.3195404147047493, "max": 0.3195404147047493}}}
# #metrics {"StartTime": 1644211520.855163, "EndTime": 1644211520.8551788, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 2}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.32698557615040535, "count": 1, "min": 0.32698557615040535, "max": 0.32698557615040535}}}
# #metrics {"StartTime": 1644211520.8552265, "EndTime": 1644211520.8552408, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 3}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.3274032881846979, "count": 1, "min": 0.3274032881846979, "max": 0.3274032881846979}}}
# #metrics {"StartTime": 1644211520.85529, "EndTime": 1644211520.8553054, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 4}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.4777964639903313, "count": 1, "min": 0.4777964639903313, "max": 0.4777964639903313}}}
# #metrics {"StartTime": 1644211520.855352, "EndTime": 1644211520.855367, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 5}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.590638911990065, "count": 1, "min": 0.590638911990065, "max": 0.590638911990065}}}
# #metrics {"StartTime": 1644211520.855416, "EndTime": 1644211520.855433, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 6}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.48253254189802774, "count": 1, "min": 0.48253254189802774, "max": 0.48253254189802774}}}
# #metrics {"StartTime": 1644211520.855484, "EndTime": 1644211520.8554997, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 7}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6031271160259918, "count": 1, "min": 0.6031271160259918, "max": 0.6031271160259918}}}
# #metrics {"StartTime": 1644211520.8555503, "EndTime": 1644211520.855564, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 8}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.3290663219432735, "count": 1, "min": 0.3290663219432735, "max": 0.3290663219432735}}}
# #metrics {"StartTime": 1644211520.8556073, "EndTime": 1644211520.855623, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 9}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.33843334504707373, "count": 1, "min": 0.33843334504707373, "max": 0.33843334504707373}}}
# #metrics {"StartTime": 1644211520.855683, "EndTime": 1644211520.8556983, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 10}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.33953402284401746, "count": 1, "min": 0.33953402284401746, "max": 0.33953402284401746}}}
# #metrics {"StartTime": 1644211520.8557546, "EndTime": 1644211520.8557708, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 11}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.3347382457100566, "count": 1, "min": 0.3347382457100566, "max": 0.3347382457100566}}}
# #metrics {"StartTime": 1644211520.855821, "EndTime": 1644211520.8558369, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 12}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.43369665937567475, "count": 1, "min": 0.43369665937567475, "max": 0.43369665937567475}}}
# #metrics {"StartTime": 1644211520.8558888, "EndTime": 1644211520.8559046, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 13}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5582932119513276, "count": 1, "min": 0.5582932119513276, "max": 0.5582932119513276}}}
# #metrics {"StartTime": 1644211520.8559556, "EndTime": 1644211520.855971, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 14}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.40992417111229057, "count": 1, "min": 0.40992417111229057, "max": 0.40992417111229057}}}
# #metrics {"StartTime": 1644211520.8560207, "EndTime": 1644211520.8560367, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 15}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5464452117843245, "count": 1, "min": 0.5464452117843245, "max": 0.5464452117843245}}}
# #metrics {"StartTime": 1644211520.8560863, "EndTime": 1644211520.856103, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 16}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.44801290402819766, "count": 1, "min": 0.44801290402819766, "max": 0.44801290402819766}}}
# #metrics {"StartTime": 1644211520.856152, "EndTime": 1644211520.8561687, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 17}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.4507313074466571, "count": 1, "min": 0.4507313074466571, "max": 0.4507313074466571}}}
# #metrics {"StartTime": 1644211520.856228, "EndTime": 1644211520.8562443, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 18}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.4471608550872036, "count": 1, "min": 0.4471608550872036, "max": 0.4471608550872036}}}
# #metrics {"StartTime": 1644211520.8563018, "EndTime": 1644211520.8563166, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 19}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.4506483911868915, "count": 1, "min": 0.4506483911868915, "max": 0.4506483911868915}}}
# #metrics {"StartTime": 1644211520.856364, "EndTime": 1644211520.8563783, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 20}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5034817837087353, "count": 1, "min": 0.5034817837087353, "max": 0.5034817837087353}}}
# #metrics {"StartTime": 1644211520.8564286, "EndTime": 1644211520.856443, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 21}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5302559648638394, "count": 1, "min": 0.5302559648638394, "max": 0.5302559648638394}}}
# #metrics {"StartTime": 1644211520.856471, "EndTime": 1644211520.8564787, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 22}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5034230974091957, "count": 1, "min": 0.5034230974091957, "max": 0.5034230974091957}}}
# #metrics {"StartTime": 1644211520.8565018, "EndTime": 1644211520.8565087, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 23}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.531876334511455, "count": 1, "min": 0.531876334511455, "max": 0.531876334511455}}}
# #metrics {"StartTime": 1644211520.856555, "EndTime": 1644211520.8565714, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 24}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.080485231179089, "count": 1, "min": 1.080485231179089, "max": 1.080485231179089}}}
# #metrics {"StartTime": 1644211520.8566275, "EndTime": 1644211520.856644, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 25}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.0806065483668341, "count": 1, "min": 1.0806065483668341, "max": 1.0806065483668341}}}
# #metrics {"StartTime": 1644211520.856697, "EndTime": 1644211520.856714, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 26}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.080347275623724, "count": 1, "min": 1.080347275623724, "max": 1.080347275623724}}}
# #metrics {"StartTime": 1644211520.8567712, "EndTime": 1644211520.856788, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 27}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.0807068119528305, "count": 1, "min": 1.0807068119528305, "max": 1.0807068119528305}}}
# #metrics {"StartTime": 1644211520.8568482, "EndTime": 1644211520.856864, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 28}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.1454150128388525, "count": 1, "min": 1.1454150128388525, "max": 1.1454150128388525}}}
# #metrics {"StartTime": 1644211520.8569162, "EndTime": 1644211520.8569317, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 29}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.2139291877171503, "count": 1, "min": 1.2139291877171503, "max": 1.2139291877171503}}}
# #metrics {"StartTime": 1644211520.8569827, "EndTime": 1644211520.856998, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 30}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.1451639179632291, "count": 1, "min": 1.1451639179632291, "max": 1.1451639179632291}}}
# #metrics {"StartTime": 1644211520.8570483, "EndTime": 1644211520.8570635, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 31}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.2131926508764526, "count": 1, "min": 1.2131926508764526, "max": 1.2131926508764526}}}
# [02/07/2022 05:25:20 INFO 139639256651584] #quality_metric: host=algo-1, epoch=2, train binary_classification_weighted_cross_entropy_objective <loss>=0.3391149269755761
# [02/07/2022 05:25:20 INFO 139639256651584] #early_stopping_criteria_metric: host=algo-1, epoch=2, criteria=binary_classification_weighted_cross_entropy_objective, value=0.3195404147047493
# [02/07/2022 05:25:20 INFO 139639256651584] Epoch 2: Loss improved. Updating best model
# [02/07/2022 05:25:20 INFO 139639256651584] Saving model for epoch: 2
# [02/07/2022 05:25:20 INFO 139639256651584] Saved checkpoint to "/tmp/tmpxc13t9yz/mx-mod-0000.params"
# [02/07/2022 05:25:20 INFO 139639256651584] #progress_metric: host=algo-1, completed 20.0 % of epochs
# #metrics {"StartTime": 1644211513.8783507, "EndTime": 1644211520.8663182, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 610092.0, "count": 1, "min": 610092, "max": 610092}, "Total Batches Seen": {"sum": 612.0, "count": 1, "min": 612, "max": 612}, "Max Records Seen Between Resets": {"sum": 199364.0, "count": 1, "min": 199364, "max": 199364}, "Max Batches Seen Between Resets": {"sum": 200.0, "count": 1, "min": 200, "max": 200}, "Reset Count": {"sum": 5.0, "count": 1, "min": 5, "max": 5}, "Number of Records Since Last Reset": {"sum": 199364.0, "count": 1, "min": 199364, "max": 199364}, "Number of Batches Since Last Reset": {"sum": 200.0, "count": 1, "min": 200, "max": 200}}}
# [02/07/2022 05:25:20 INFO 139639256651584] #throughput_metric: host=algo-1, train throughput=28529.06382377234 records/second
# [2022-02-07 05:25:28.002] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 9, "duration": 7135, "num_examples": 200, "num_bytes": 33493152}
# #metrics {"StartTime": 1644211528.002285, "EndTime": 1644211528.0023673, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 0}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.32226599174767884, "count": 1, "min": 0.32226599174767884, "max": 0.32226599174767884}}}
# #metrics {"StartTime": 1644211528.0024405, "EndTime": 1644211528.0024593, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 1}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.3074733453491824, "count": 1, "min": 0.3074733453491824, "max": 0.3074733453491824}}}
# ...
# #metrics {"StartTime": 1644211603.4613166, "EndTime": 1644211603.461327, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 5}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5330752930856829, "count": 1, "min": 0.5330752930856829, "max": 0.5330752930856829}}}
# #metrics {"StartTime": 1644211603.4613755, "EndTime": 1644211603.4613907, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 6}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.28378996158005604, "count": 1, "min": 0.28378996158005604, "max": 0.28378996158005604}}}
# #metrics {"StartTime": 1644211603.4614427, "EndTime": 1644211603.4614594, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 7}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.47326236121019527, "count": 1, "min": 0.47326236121019527, "max": 0.47326236121019527}}}
# #metrics {"StartTime": 1644211603.4615114, "EndTime": 1644211603.4615278, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 8}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.29130650279749576, "count": 1, "min": 0.29130650279749576, "max": 0.29130650279749576}}}
# #metrics {"StartTime": 1644211603.4615812, "EndTime": 1644211603.4615977, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 9}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.29114658903955815, "count": 1, "min": 0.29114658903955815, "max": 0.29114658903955815}}}
# #metrics {"StartTime": 1644211603.4616492, "EndTime": 1644211603.4616752, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 10}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.29353761303005504, "count": 1, "min": 0.29353761303005504, "max": 0.29353761303005504}}}
# #metrics {"StartTime": 1644211603.4617264, "EndTime": 1644211603.461742, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 11}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.2908794963204082, "count": 1, "min": 0.2908794963204082, "max": 0.2908794963204082}}}
# #metrics {"StartTime": 1644211603.461794, "EndTime": 1644211603.4618106, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 12}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.2914942595515419, "count": 1, "min": 0.2914942595515419, "max": 0.2914942595515419}}}
# #metrics {"StartTime": 1644211603.4618607, "EndTime": 1644211603.461876, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 13}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.4870187229367357, "count": 1, "min": 0.4870187229367357, "max": 0.4870187229367357}}}
# #metrics {"StartTime": 1644211603.4619267, "EndTime": 1644211603.4619422, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 14}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.2914134636116986, "count": 1, "min": 0.2914134636116986, "max": 0.2914134636116986}}}
# #metrics {"StartTime": 1644211603.4619932, "EndTime": 1644211603.4620094, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 15}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.49398941992754913, "count": 1, "min": 0.49398941992754913, "max": 0.49398941992754913}}}
# #metrics {"StartTime": 1644211603.4620593, "EndTime": 1644211603.4620755, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 16}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.4376009713177705, "count": 1, "min": 0.4376009713177705, "max": 0.4376009713177705}}}
# #metrics {"StartTime": 1644211603.4621274, "EndTime": 1644211603.4621437, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 17}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.4484181482516342, "count": 1, "min": 0.4484181482516342, "max": 0.4484181482516342}}}
# #metrics {"StartTime": 1644211603.4621983, "EndTime": 1644211603.4622142, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 18}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.43762711445410646, "count": 1, "min": 0.43762711445410646, "max": 0.43762711445410646}}}
# #metrics {"StartTime": 1644211603.4622915, "EndTime": 1644211603.4623096, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 19}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.44841468803367424, "count": 1, "min": 0.44841468803367424, "max": 0.44841468803367424}}}
# #metrics {"StartTime": 1644211603.4623635, "EndTime": 1644211603.46238, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 20}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.45202172866897966, "count": 1, "min": 0.45202172866897966, "max": 0.45202172866897966}}}
# #metrics {"StartTime": 1644211603.4624388, "EndTime": 1644211603.4624555, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 21}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5203195825893077, "count": 1, "min": 0.5203195825893077, "max": 0.5203195825893077}}}
# #metrics {"StartTime": 1644211603.4625075, "EndTime": 1644211603.4625223, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 22}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.4520227471739803, "count": 1, "min": 0.4520227471739803, "max": 0.4520227471739803}}}
# #metrics {"StartTime": 1644211603.4625716, "EndTime": 1644211603.4625862, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 23}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5202868180394772, "count": 1, "min": 0.5202868180394772, "max": 0.5202868180394772}}}
# #metrics {"StartTime": 1644211603.462626, "EndTime": 1644211603.4626405, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 24}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.0734474260339786, "count": 1, "min": 1.0734474260339786, "max": 1.0734474260339786}}}
# #metrics {"StartTime": 1644211603.4626925, "EndTime": 1644211603.4627085, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 25}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.0808105422743601, "count": 1, "min": 1.0808105422743601, "max": 1.0808105422743601}}}
# #metrics {"StartTime": 1644211603.4627647, "EndTime": 1644211603.4627812, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 26}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.073446477075318, "count": 1, "min": 1.073446477075318, "max": 1.073446477075318}}}
# #metrics {"StartTime": 1644211603.4628294, "EndTime": 1644211603.4628448, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 27}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.0808158106204853, "count": 1, "min": 1.0808158106204853, "max": 1.0808158106204853}}}
# #metrics {"StartTime": 1644211603.4628937, "EndTime": 1644211603.4629085, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 28}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.081110000226965, "count": 1, "min": 1.081110000226965, "max": 1.081110000226965}}}
# #metrics {"StartTime": 1644211603.4629574, "EndTime": 1644211603.4629736, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 29}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.178819695554187, "count": 1, "min": 1.178819695554187, "max": 1.178819695554187}}}
# #metrics {"StartTime": 1644211603.4630318, "EndTime": 1644211603.463049, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 30}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.0811094335814817, "count": 1, "min": 1.0811094335814817, "max": 1.0811094335814817}}}
# #metrics {"StartTime": 1644211603.4631073, "EndTime": 1644211603.463124, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 31}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.1788132949905779, "count": 1, "min": 1.1788132949905779, "max": 1.1788132949905779}}}
# [02/07/2022 05:26:43 INFO 139639256651584] #quality_metric: host=algo-1, epoch=14, train binary_classification_weighted_cross_entropy_objective <loss>=0.29068308453583835
# [02/07/2022 05:26:43 INFO 139639256651584] #early_stopping_criteria_metric: host=algo-1, epoch=14, criteria=binary_classification_weighted_cross_entropy_objective, value=0.28373790798474796
# [02/07/2022 05:26:43 INFO 139639256651584] Epoch 14: Loss improved. Updating best model
# [02/07/2022 05:26:43 INFO 139639256651584] Saving model for epoch: 14
# [02/07/2022 05:26:43 INFO 139639256651584] Saved checkpoint to "/tmp/tmp0knngoik/mx-mod-0000.params"
# [02/07/2022 05:26:43 INFO 139639256651584] #progress_metric: host=algo-1, completed 100.0 % of epochs
# #metrics {"StartTime": 1644211596.4051728, "EndTime": 1644211603.4717963, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 3002460.0, "count": 1, "min": 3002460, "max": 3002460}, "Total Batches Seen": {"sum": 3012.0, "count": 1, "min": 3012, "max": 3012}, "Max Records Seen Between Resets": {"sum": 199364.0, "count": 1, "min": 199364, "max": 199364}, "Max Batches Seen Between Resets": {"sum": 200.0, "count": 1, "min": 200, "max": 200}, "Reset Count": {"sum": 17.0, "count": 1, "min": 17, "max": 17}, "Number of Records Since Last Reset": {"sum": 199364.0, "count": 1, "min": 199364, "max": 199364}, "Number of Batches Since Last Reset": {"sum": 200.0, "count": 1, "min": 200, "max": 200}}}
# [02/07/2022 05:26:43 INFO 139639256651584] #throughput_metric: host=algo-1, train throughput=28211.53201958926 records/second
# [02/07/2022 05:26:43 WARNING 139639256651584] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [02/07/2022 05:26:43 WARNING 139639256651584] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [2022-02-07 05:26:43.477] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 33, "duration": 3, "num_examples": 1, "num_bytes": 168000}
# [2022-02-07 05:26:43.993] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 36, "duration": 512, "num_examples": 200, "num_bytes": 33493152}
# [2022-02-07 05:26:44.820] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 38, "duration": 756, "num_examples": 200, "num_bytes": 33493152}
# [02/07/2022 05:26:45 INFO 139639256651584] #train_score (algo-1) : ('binary_classification_weighted_cross_entropy_objective', 0.2687483957430368)
# [02/07/2022 05:26:45 INFO 139639256651584] #train_score (algo-1) : ('binary_classification_accuracy', 0.9913173892979675)
# [02/07/2022 05:26:45 INFO 139639256651584] #train_score (algo-1) : ('binary_f_1.000', 0.27177114009255365)
# [02/07/2022 05:26:45 INFO 139639256651584] #train_score (algo-1) : ('precision', 0.1599009900990099)
# [02/07/2022 05:26:45 INFO 139639256651584] #train_score (algo-1) : ('recall', 0.9047619047619048)
# [02/07/2022 05:26:45 INFO 139639256651584] #train_score (algo-1) : ('roc_auc_score', 0.9883347149127631)
# [02/07/2022 05:26:45 INFO 139639256651584] #train_score (algo-1) : ('binary_balanced_accuracy', 0.5)
# [02/07/2022 05:26:45 INFO 139639256651584] #train_score (algo-1) : ('binary_log_loss', 0.7326821872687728)
# [02/07/2022 05:26:45 INFO 139639256651584] #quality_metric: host=algo-1, train binary_classification_weighted_cross_entropy_objective <loss>=0.2687483957430368
# [02/07/2022 05:26:45 INFO 139639256651584] #quality_metric: host=algo-1, train binary_classification_accuracy <score>=0.9913173892979675
# [02/07/2022 05:26:45 INFO 139639256651584] #quality_metric: host=algo-1, train binary_f_1.000 <score>=0.27177114009255365
# [02/07/2022 05:26:45 INFO 139639256651584] #quality_metric: host=algo-1, train precision <score>=0.1599009900990099
# [02/07/2022 05:26:45 INFO 139639256651584] #quality_metric: host=algo-1, train recall <score>=0.9047619047619048
# [02/07/2022 05:26:45 INFO 139639256651584] #quality_metric: host=algo-1, train roc_auc_score <score>=0.9883347149127631
# [02/07/2022 05:26:45 INFO 139639256651584] #quality_metric: host=algo-1, train binary_balanced_accuracy <score>=0.5
# [02/07/2022 05:26:45 INFO 139639256651584] #quality_metric: host=algo-1, train binary_log_loss <score>=0.7326821872687728
# [02/07/2022 05:26:45 INFO 139639256651584] Best model found for hyperparameters: {"optimizer": "adam", "learning_rate": 0.1, "wd": 0.0001, "l1": 0.0, "lr_scheduler_step": 10, "lr_scheduler_factor": 0.99, "lr_scheduler_minimum_lr": 1e-05}
# [02/07/2022 05:26:45 INFO 139639256651584] Saved checkpoint to "/tmp/tmp401_ryps/mx-mod-0000.params"
# [02/07/2022 05:26:45 INFO 139639256651584] Test data is not provided.
# #metrics {"StartTime": 1644211499.065494, "EndTime": 1644211605.1106842, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training"}, "Metrics": {"initialize.time": {"sum": 340.09575843811035, "count": 1, "min": 340.09575843811035, "max": 340.09575843811035}, "epochs": {"sum": 15.0, "count": 1, "min": 15, "max": 15}, "check_early_stopping.time": {"sum": 14.379739761352539, "count": 15, "min": 0.8418560028076172, "max": 1.150369644165039}, "update.time": {"sum": 103999.32527542114, "count": 15, "min": 6377.494096755981, "max": 7304.291486740112}, "finalize.time": {"sum": 1629.5740604400635, "count": 1, "min": 1629.5740604400635, "max": 1629.5740604400635}, "setuptime": {"sum": 26.889562606811523, "count": 1, "min": 26.889562606811523, "max": 26.889562606811523}, "totaltime": {"sum": 106319.5252418518, "count": 1, "min": 106319.5252418518, "max": 106319.5252418518}}}
#
# 2022-02-07 05:26:59 Uploading - Uploading generated training model
# 2022-02-07 05:26:59 Completed - Training job completed
# Training seconds: 146
# Billable seconds: 146
# CPU times: user 893 ms, sys: 55.6 ms, total: 948 ms
# Wall time: 5min 44s

# %% [markdown]
# ### EXERCISE: Deploy and evaluate the balanced estimator
#
# Deploy the balanced predictor and evaluate it. Do the results match with your expectations?

# %%
# %%time 
# deploy and create a predictor
balanced_predictor = linear_balanced.deploy(initial_instance_count=1, instance_type='ml.t2.medium')
# Out:
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# --------!CPU times: user 153 ms, sys: 7.48 ms, total: 161 ms
# Wall time: 4min 2s

# %%
print('Metrics for balanced, LinearLearner.\n')

# get metrics for balanced predictor
metrics = evaluate(balanced_predictor, 
                   test_features.values.astype('float32'), 
                   test_labels, 
                   verbose=True)
# Out:
# Metrics for balanced, LinearLearner.
#
# prediction (col)    0.0  1.0
# actual (row)
# 0                 84629  679
# 1                    18  117
#
# Recall:     0.867
# Precision:  0.147
# Accuracy:   0.992

# %% [markdown]
# **My notes:** Although still below our target recall of 0.9, our balanced recall-optimized model has improved recall (0.852 up to 0.867), precision (0.104 up to 0.147) and accuracy (0.988 up to 0.992) from the unbalanced, recall-optimized model. False negatives have fallen slightly from 20 to 18.

# %% [markdown]
# ## Delete the endpoint
#
# When you're done evaluating a model, you should delete the endpoint.

# %%
# delete the predictor endpoint 
delete_endpoint(balanced_predictor)
# Out:
# The endpoint attribute has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The endpoint attribute has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# Deleted linear-learner-2022-02-07-05-27-18-359

# %% [markdown]
# A note on metric variability:
#
# The above model is tuned for the best possible precision with recall fixed at about 90%. The recall is fixed at 90% during training, but may vary when we apply our trained model to a test set of data.

# %% [markdown]
# ---
# ## Model Design
#
# Now that you've seen how to tune and balance a LinearLearner. Create, train and deploy your own model. This exercise is meant to be more open-ended, so that you get practice with the steps involved in designing a model and deploying it.
#
# ### EXERCISE: Train and deploy a LinearLearner with appropriate hyperparameters, according to the given scenario
#
# **Scenario:**
# * A bank has asked you to build a model that optimizes for a good user experience; users should only ever have up to about 15% of their valid transactions flagged as fraudulent.
#
# This requires that you make a design decision: Given the above scenario, what metric (and value) should you aim for during training?
#
# You may assume that performance on a training set will be within about 5-10% of the performance on a test set. For example, if you get 80% on a training set, you can assume that you'll get between about 70-90% accuracy on a test set.
#
# Your final model should account for class imbalance and be appropriately tuned.

# %% [markdown]
# ---
# **My notes:** Since the client is requesting no more than 15% of a customer's transactions be flagged as fraudulent, this means that they want as few 0s classified as 1s, or **false postitives**, as possible. So we can try a *'recall-at-target-precision'* `binary_classifier_model_selection_criteria`. Againwe can aim for about 5% higher (90%) is anticipation that the model will perform with 5% on test data.

# %%
# %%time
# instantiate and train a LinearLearner of my own.


# include params for tuning for higher precision
# *and* account for class imbalance in training data

my_learner=LinearLearner(role=role,
                         train_instance_count=1, 
                         train_instance_type='ml.c4.xlarge',
                         predictor_type='binary_classifier',
                         output_path=output_path,
                         sagemaker_session=sagemaker_session,
                         epochs=15,
                         binary_classifier_model_selection_criteria='recall_at_target_precision', # target precision
                         target_precision=0.89,
                         positive_example_weight_mult='balanced')

my_learner.fit(formatted_train_data)
# Out:
# train_instance_count has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# train_instance_type has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# 2022-02-08 04:07:46 Starting - Starting the training job...
# 2022-02-08 04:07:48 Starting - Launching requested ML instancesProfilerReport-1644293266: InProgress
# ...
# 2022-02-08 04:08:46 Starting - Preparing the instances for training............
# 2022-02-08 04:10:46 Downloading - Downloading input data...
# 2022-02-08 04:11:15 Training - Downloading the training image...
# 2022-02-08 04:11:47 Training - Training image download completed. Training in progress.Docker entrypoint called with argument(s): train
# Running default environment configuration script
# [02/08/2022 04:11:41 INFO 139697446053696] Reading default configuration from /opt/amazon/lib/python3.7/site-packages/algorithm/resources/default-input.json: {'mini_batch_size': '1000', 'epochs': '15', 'feature_dim': 'auto', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'accuracy', 'f_beta': '1.0', 'target_recall': '0.8', 'target_precision': '0.8', 'num_models': 'auto', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'auto', 'loss': 'auto', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '1', 'accuracy_top_k': '3', 'wd': 'auto', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': 'auto', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': 'auto', 'lr_scheduler_factor': 'auto', 'lr_scheduler_minimum_lr': 'auto', 'positive_example_weight_mult': '1.0', 'balance_multiclass_weights': 'false', 'normalize_data': 'true', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false'}
# [02/08/2022 04:11:41 INFO 139697446053696] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {'positive_example_weight_mult': 'balanced', 'feature_dim': '30', 'predictor_type': 'binary_classifier', 'target_precision': '0.89', 'epochs': '15', 'binary_classifier_model_selection_criteria': 'recall_at_target_precision', 'mini_batch_size': '1000'}
# [02/08/2022 04:11:41 INFO 139697446053696] Final configuration: {'mini_batch_size': '1000', 'epochs': '15', 'feature_dim': '30', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'recall_at_target_precision', 'f_beta': '1.0', 'target_recall': '0.8', 'target_precision': '0.89', 'num_models': 'auto', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'auto', 'loss': 'auto', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '1', 'accuracy_top_k': '3', 'wd': 'auto', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': 'auto', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': 'auto', 'lr_scheduler_factor': 'auto', 'lr_scheduler_minimum_lr': 'auto', 'positive_example_weight_mult': 'balanced', 'balance_multiclass_weights': 'false', 'normalize_data': 'true', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false', 'predictor_type': 'binary_classifier'}
# [02/08/2022 04:11:41 WARNING 139697446053696] Loggers have already been setup.
# Process 1 is a worker.
# [02/08/2022 04:11:41 INFO 139697446053696] Using default worker.
# [02/08/2022 04:11:41 INFO 139697446053696] Checkpoint loading and saving are disabled.
# [2022-02-08 04:11:41.719] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration": 28, "num_examples": 1, "num_bytes": 168000}
# [02/08/2022 04:11:41 INFO 139697446053696] Create Store: local
# [2022-02-08 04:11:41.820] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 1, "duration": 99, "num_examples": 11, "num_bytes": 1848000}
# [02/08/2022 04:11:41 INFO 139697446053696] Scaler algorithm parameters
#  <algorithm.scaler.ScalerAlgorithmStable object at 0x7f0d785535d0>
# [02/08/2022 04:11:41 INFO 139697446053696] Scaling model computed with parameters:
#  {'stdev_label': None, 'stdev_weight':
# [4.7823008e+04 1.8987731e+00 1.5821997e+00 1.5291911e+00 1.4364978e+00
#  1.3388461e+00 1.2955806e+00 1.1771069e+00 1.2127448e+00 1.0843055e+00
#  1.0475702e+00 1.0230465e+00 1.0090139e+00 1.0057642e+00 9.5122164e-01
#  9.2613727e-01 8.7072927e-01 8.6057234e-01 8.3151484e-01 8.2762748e-01
#  7.1313608e-01 7.3347980e-01 7.2524083e-01 5.6213826e-01 6.0201687e-01
#  5.1174247e-01 4.8000538e-01 3.7595215e-01 2.7081874e-01 2.3656270e+02]
# <NDArray 30 @cpu(0)>, 'mean_label': None, 'mean_weight':
# [ 9.4275984e+04 -1.7378727e-02  1.5538026e-02  2.5005125e-02
#   3.3166975e-02  1.8197566e-02  1.7799012e-03  6.9396999e-03
#   9.8540336e-03 -3.0757964e-02 -1.2736557e-02  4.0434714e-04
#  -1.4243029e-02  1.6704608e-02  2.2619881e-02 -9.6982103e-03
#  -4.7834702e-03 -1.6767335e-04 -9.0120723e-03 -3.0407687e-03
#   4.6031545e-03 -4.0078526e-03 -1.2586080e-04  1.2784966e-03
#   3.7617318e-03 -3.1254767e-03 -8.2200055e-04  3.4045519e-03
#  -1.0332187e-03  8.7559837e+01]
# <NDArray 30 @cpu(0)>}
# [02/08/2022 04:11:41 INFO 139697446053696] nvidia-smi: took 0.030 seconds to run.
# [02/08/2022 04:11:41 INFO 139697446053696] nvidia-smi identified 0 GPUs.
# [02/08/2022 04:11:41 INFO 139697446053696] Number of GPUs being used: 0
# #metrics {"StartTime": 1644293502.020448, "EndTime": 1644293502.0204804, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "Meta": "init_train_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 12000.0, "count": 1, "min": 12000, "max": 12000}, "Total Batches Seen": {"sum": 12.0, "count": 1, "min": 12, "max": 12}, "Max Records Seen Between Resets": {"sum": 11000.0, "count": 1, "min": 11000, "max": 11000}, "Max Batches Seen Between Resets": {"sum": 11.0, "count": 1, "min": 11, "max": 11}, "Reset Count": {"sum": 2.0, "count": 1, "min": 2, "max": 2}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [2022-02-08 04:11:49.119] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 3, "duration": 7098, "num_examples": 200, "num_bytes": 33493152}
# #metrics {"StartTime": 1644293509.1191099, "EndTime": 1644293509.1192253, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 0}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5791407177028943, "count": 1, "min": 0.5791407177028943, "max": 0.5791407177028943}}}
# #metrics {"StartTime": 1644293509.1193192, "EndTime": 1644293509.1193395, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 1}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.4759549259971734, "count": 1, "min": 0.4759549259971734, "max": 0.4759549259971734}}}
# #metrics {"StartTime": 1644293509.11939, "EndTime": 1644293509.1194062, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 2}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.4948354150206599, "count": 1, "min": 0.4948354150206599, "max": 0.4948354150206599}}}
# #metrics {"StartTime": 1644293509.1194663, "EndTime": 1644293509.1194837, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 3}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5374999441789023, "count": 1, "min": 0.5374999441789023, "max": 0.5374999441789023}}}
# #metrics {"StartTime": 1644293509.1195395, "EndTime": 1644293509.1195552, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 4}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6132990110579447, "count": 1, "min": 0.6132990110579447, "max": 0.6132990110579447}}}
# #metrics {"StartTime": 1644293509.1196058, "EndTime": 1644293509.1196208, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 5}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.650242357378629, "count": 1, "min": 0.650242357378629, "max": 0.650242357378629}}}
# #metrics {"StartTime": 1644293509.1196747, "EndTime": 1644293509.1196916, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 6}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6198758794314897, "count": 1, "min": 0.6198758794314897, "max": 0.6198758794314897}}}
# #metrics {"StartTime": 1644293509.119745, "EndTime": 1644293509.119762, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 7}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.642763320194417, "count": 1, "min": 0.642763320194417, "max": 0.642763320194417}}}
# #metrics {"StartTime": 1644293509.1198163, "EndTime": 1644293509.1198323, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 8}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.4923872120919539, "count": 1, "min": 0.4923872120919539, "max": 0.4923872120919539}}}
# #metrics {"StartTime": 1644293509.1199164, "EndTime": 1644293509.119935, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 9}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5910773196579823, "count": 1, "min": 0.5910773196579823, "max": 0.5910773196579823}}}
# #metrics {"StartTime": 1644293509.119998, "EndTime": 1644293509.120016, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 10}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5660034152850434, "count": 1, "min": 0.5660034152850434, "max": 0.5660034152850434}}}
# #metrics {"StartTime": 1644293509.1200643, "EndTime": 1644293509.1200788, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 11}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.570866738247512, "count": 1, "min": 0.570866738247512, "max": 0.570866738247512}}}
# #metrics {"StartTime": 1644293509.1201262, "EndTime": 1644293509.12014, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 12}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.603102036327573, "count": 1, "min": 0.603102036327573, "max": 0.603102036327573}}}
# #metrics {"StartTime": 1644293509.1201959, "EndTime": 1644293509.1202123, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 13}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6313092581015736, "count": 1, "min": 0.6313092581015736, "max": 0.6313092581015736}}}
# #metrics {"StartTime": 1644293509.1202736, "EndTime": 1644293509.1202903, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 14}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6069122777967597, "count": 1, "min": 0.6069122777967597, "max": 0.6069122777967597}}}
# #metrics {"StartTime": 1644293509.1203516, "EndTime": 1644293509.1203692, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 15}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6302709089116235, "count": 1, "min": 0.6302709089116235, "max": 0.6302709089116235}}}
# #metrics {"StartTime": 1644293509.1204295, "EndTime": 1644293509.1204474, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 16}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6274360078591198, "count": 1, "min": 0.6274360078591198, "max": 0.6274360078591198}}}
# #metrics {"StartTime": 1644293509.1205077, "EndTime": 1644293509.1205251, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 17}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.512769868476906, "count": 1, "min": 0.512769868476906, "max": 0.512769868476906}}}
# #metrics {"StartTime": 1644293509.1205776, "EndTime": 1644293509.1205935, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 18}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5364223231790054, "count": 1, "min": 0.5364223231790054, "max": 0.5364223231790054}}}
# #metrics {"StartTime": 1644293509.1206462, "EndTime": 1644293509.120662, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 19}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5448161246141596, "count": 1, "min": 0.5448161246141596, "max": 0.5448161246141596}}}
# #metrics {"StartTime": 1644293509.120724, "EndTime": 1644293509.1207418, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 20}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.540332931163922, "count": 1, "min": 0.540332931163922, "max": 0.540332931163922}}}
# #metrics {"StartTime": 1644293509.1208026, "EndTime": 1644293509.1208196, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 21}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.541313360655128, "count": 1, "min": 0.541313360655128, "max": 0.541313360655128}}}
# #metrics {"StartTime": 1644293509.1208754, "EndTime": 1644293509.1208906, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 22}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.536809625117623, "count": 1, "min": 0.536809625117623, "max": 0.536809625117623}}}
# #metrics {"StartTime": 1644293509.1209464, "EndTime": 1644293509.120961, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 23}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5356268091920632, "count": 1, "min": 0.5356268091920632, "max": 0.5356268091920632}}}
# #metrics {"StartTime": 1644293509.121011, "EndTime": 1644293509.1210284, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 24}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.081357410986819, "count": 1, "min": 1.081357410986819, "max": 1.081357410986819}}}
# #metrics {"StartTime": 1644293509.1210823, "EndTime": 1644293509.121099, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 25}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.0807654687315975, "count": 1, "min": 1.0807654687315975, "max": 1.0807654687315975}}}
# #metrics {"StartTime": 1644293509.1211607, "EndTime": 1644293509.1211789, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 26}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.107846775994229, "count": 1, "min": 1.107846775994229, "max": 1.107846775994229}}}
# #metrics {"StartTime": 1644293509.12124, "EndTime": 1644293509.1212556, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 27}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.0852037635688208, "count": 1, "min": 1.0852037635688208, "max": 1.0852037635688208}}}
# #metrics {"StartTime": 1644293509.1213138, "EndTime": 1644293509.1213293, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 28}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.2230319136423082, "count": 1, "min": 1.2230319136423082, "max": 1.2230319136423082}}}
# #metrics {"StartTime": 1644293509.121388, "EndTime": 1644293509.1214054, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 29}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.240264271721768, "count": 1, "min": 1.240264271721768, "max": 1.240264271721768}}}
# #metrics {"StartTime": 1644293509.1214669, "EndTime": 1644293509.1214843, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 30}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.2185808203615736, "count": 1, "min": 1.2185808203615736, "max": 1.2185808203615736}}}
# #metrics {"StartTime": 1644293509.1215465, "EndTime": 1644293509.1215577, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 31}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.2268015014801792, "count": 1, "min": 1.2268015014801792, "max": 1.2268015014801792}}}
# [02/08/2022 04:11:49 INFO 139697446053696] #quality_metric: host=algo-1, epoch=0, train binary_classification_weighted_cross_entropy_objective <loss>=0.5791407177028943
# [02/08/2022 04:11:49 INFO 139697446053696] #early_stopping_criteria_metric: host=algo-1, epoch=0, criteria=binary_classification_weighted_cross_entropy_objective, value=0.4759549259971734
# [02/08/2022 04:11:49 INFO 139697446053696] Epoch 0: Loss improved. Updating best model
# [02/08/2022 04:11:49 INFO 139697446053696] Saving model for epoch: 0
# [02/08/2022 04:11:49 INFO 139697446053696] Saved checkpoint to "/tmp/tmp6ha62uxu/mx-mod-0000.params"
# [02/08/2022 04:11:49 INFO 139697446053696] #progress_metric: host=algo-1, completed 6.666666666666667 % of epochs
# #metrics {"StartTime": 1644293502.020751, "EndTime": 1644293509.136421, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 211364.0, "count": 1, "min": 211364, "max": 211364}, "Total Batches Seen": {"sum": 212.0, "count": 1, "min": 212, "max": 212}, "Max Records Seen Between Resets": {"sum": 199364.0, "count": 1, "min": 199364, "max": 199364}, "Max Batches Seen Between Resets": {"sum": 200.0, "count": 1, "min": 200, "max": 200}, "Reset Count": {"sum": 3.0, "count": 1, "min": 3, "max": 3}, "Number of Records Since Last Reset": {"sum": 199364.0, "count": 1, "min": 199364, "max": 199364}, "Number of Batches Since Last Reset": {"sum": 200.0, "count": 1, "min": 200, "max": 200}}}
# [02/08/2022 04:11:49 INFO 139697446053696] #throughput_metric: host=algo-1, train throughput=28017.17828997532 records/second
# [2022-02-08 04:11:56.934] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 5, "duration": 7796, "num_examples": 200, "num_bytes": 33493152}
# #metrics {"StartTime": 1644293516.934588, "EndTime": 1644293516.9346697, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 0}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.3762333395109704, "count": 1, "min": 0.3762333395109704, "max": 0.3762333395109704}}}
# #metrics {"StartTime": 1644293516.9347444, "EndTime": 1644293516.9347618, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 1}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.3452077499849712, "count": 1, "min": 0.3452077499849712, "max": 0.3452077499849712}}}
# #metrics {"StartTime": 1644293516.9348083, "EndTime": 1644293516.9348238, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 2}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.3545212267391646, "count": 1, "min": 0.3545212267391646, "max": 0.3545212267391646}}}
# #metrics {"StartTime": 1644293516.934869, "EndTime": 1644293516.9348829, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 3}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.358282039009746, "count": 1, "min": 0.358282039009746, "max": 0.358282039009746}}}
# #metrics {"StartTime": 1644293516.9349296, "EndTime": 1644293516.934945, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 4}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.503855560801137, "count": 1, "min": 0.503855560801137, "max": 0.503855560801137}}}
# #metrics {"StartTime": 1644293516.9349942, "EndTime": 1644293516.9350092, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 5}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5762882809279553, "count": 1, "min": 0.5762882809279553, "max": 0.5762882809279553}}}
# #metrics {"StartTime": 1644293516.935057, "EndTime": 1644293516.935072, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 6}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5095617222809912, "count": 1, "min": 0.5095617222809912, "max": 0.5095617222809912}}}
# #metrics {"StartTime": 1644293516.935119, "EndTime": 1644293516.9351346, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 7}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5621733702846508, "count": 1, "min": 0.5621733702846508, "max": 0.5621733702846508}}}
# #metrics {"StartTime": 1644293516.9351826, "EndTime": 1644293516.935198, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 8}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.35608179332023887, "count": 1, "min": 0.35608179332023887, "max": 0.35608179332023887}}}
# #metrics {"StartTime": 1644293516.935238, "EndTime": 1644293516.935262, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 9}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.37639001955578677, "count": 1, "min": 0.37639001955578677, "max": 0.37639001955578677}}}
# #metrics {"StartTime": 1644293516.9353101, "EndTime": 1644293516.9353251, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 10}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.3734735677901225, "count": 1, "min": 0.3734735677901225, "max": 0.3734735677901225}}}
# #metrics {"StartTime": 1644293516.9353745, "EndTime": 1644293516.9353905, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 11}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.3714105723778806, "count": 1, "min": 0.3714105723778806, "max": 0.3714105723778806}}}
# #metrics {"StartTime": 1644293516.9354398, "EndTime": 1644293516.9354527, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 12}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.4968251642581806, "count": 1, "min": 0.4968251642581806, "max": 0.4968251642581806}}}
# #metrics {"StartTime": 1644293516.9354959, "EndTime": 1644293516.9355114, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 13}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5793348179342759, "count": 1, "min": 0.5793348179342759, "max": 0.5793348179342759}}}
# #metrics {"StartTime": 1644293516.9355588, "EndTime": 1644293516.9355743, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 14}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5010429530119777, "count": 1, "min": 0.5010429530119777, "max": 0.5010429530119777}}}
# #metrics {"StartTime": 1644293516.935621, "EndTime": 1644293516.9356346, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 15}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5806286224671944, "count": 1, "min": 0.5806286224671944, "max": 0.5806286224671944}}}
# #metrics {"StartTime": 1644293516.935681, "EndTime": 1644293516.9356966, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 16}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.45959482746986885, "count": 1, "min": 0.45959482746986885, "max": 0.45959482746986885}}}
# #metrics {"StartTime": 1644293516.9357483, "EndTime": 1644293516.9357646, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 17}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.45221469054869073, "count": 1, "min": 0.45221469054869073, "max": 0.45221469054869073}}}
# #metrics {"StartTime": 1644293516.9358163, "EndTime": 1644293516.9358323, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 18}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.4510753076447913, "count": 1, "min": 0.4510753076447913, "max": 0.4510753076447913}}}
# #metrics {"StartTime": 1644293516.9359107, "EndTime": 1644293516.935929, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 19}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.45293791068379, "count": 1, "min": 0.45293791068379, "max": 0.45293791068379}}}
# #metrics {"StartTime": 1644293516.9359815, "EndTime": 1644293516.9359994, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 20}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.513988640119083, "count": 1, "min": 0.513988640119083, "max": 0.513988640119083}}}
# #metrics {"StartTime": 1644293516.9360406, "EndTime": 1644293516.9360557, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 21}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5301194904844965, "count": 1, "min": 0.5301194904844965, "max": 0.5301194904844965}}}
# #metrics {"StartTime": 1644293516.9361033, "EndTime": 1644293516.9361188, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 22}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5141575448309357, "count": 1, "min": 0.5141575448309357, "max": 0.5141575448309357}}}
# #metrics {"StartTime": 1644293516.9361708, "EndTime": 1644293516.936203, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 23}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5306000879949062, "count": 1, "min": 0.5306000879949062, "max": 0.5306000879949062}}}
# #metrics {"StartTime": 1644293516.9362397, "EndTime": 1644293516.9362538, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 24}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.0809531622651833, "count": 1, "min": 1.0809531622651833, "max": 1.0809531622651833}}}
# #metrics {"StartTime": 1644293516.9363046, "EndTime": 1644293516.9363203, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 25}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.0806157694294225, "count": 1, "min": 1.0806157694294225, "max": 1.0806157694294225}}}
# #metrics {"StartTime": 1644293516.9363759, "EndTime": 1644293516.9363923, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 26}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.0811927944164181, "count": 1, "min": 1.0811927944164181, "max": 1.0811927944164181}}}
# #metrics {"StartTime": 1644293516.936443, "EndTime": 1644293516.9364593, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 27}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.0806420212942152, "count": 1, "min": 1.0806420212942152, "max": 1.0806420212942152}}}
# #metrics {"StartTime": 1644293516.9365182, "EndTime": 1644293516.9365351, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 28}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.1822309901558574, "count": 1, "min": 1.1822309901558574, "max": 1.1822309901558574}}}
# #metrics {"StartTime": 1644293516.9365878, "EndTime": 1644293516.9366052, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 29}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.2228483647485475, "count": 1, "min": 1.2228483647485475, "max": 1.2228483647485475}}}
# #metrics {"StartTime": 1644293516.9366565, "EndTime": 1644293516.9366727, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 30}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.1816888533549093, "count": 1, "min": 1.1816888533549093, "max": 1.1816888533549093}}}
# #metrics {"StartTime": 1644293516.9367304, "EndTime": 1644293516.9367483, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 31}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.2195927194566583, "count": 1, "min": 1.2195927194566583, "max": 1.2195927194566583}}}
# [02/08/2022 04:11:56 INFO 139697446053696] #quality_metric: host=algo-1, epoch=1, train binary_classification_weighted_cross_entropy_objective <loss>=0.3762333395109704
# [02/08/2022 04:11:56 INFO 139697446053696] #early_stopping_criteria_metric: host=algo-1, epoch=1, criteria=binary_classification_weighted_cross_entropy_objective, value=0.3452077499849712
# [02/08/2022 04:11:56 INFO 139697446053696] Epoch 1: Loss improved. Updating best model
# [02/08/2022 04:11:56 INFO 139697446053696] Saving model for epoch: 1
# [02/08/2022 04:11:56 INFO 139697446053696] Saved checkpoint to "/tmp/tmpbx1mlf02/mx-mod-0000.params"
# [02/08/2022 04:11:56 INFO 139697446053696] #progress_metric: host=algo-1, completed 13.333333333333334 % of epochs
# #metrics {"StartTime": 1644293509.137734, "EndTime": 1644293516.9466121, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 410728.0, "count": 1, "min": 410728, "max": 410728}, "Total Batches Seen": {"sum": 412.0, "count": 1, "min": 412, "max": 412}, "Max Records Seen Between Resets": {"sum": 199364.0, "count": 1, "min": 199364, "max": 199364}, "Max Batches Seen Between Resets": {"sum": 200.0, "count": 1, "min": 200, "max": 200}, "Reset Count": {"sum": 4.0, "count": 1, "min": 4, "max": 4}, "Number of Records Since Last Reset": {"sum": 199364.0, "count": 1, "min": 199364, "max": 199364}, "Number of Batches Since Last Reset": {"sum": 200.0, "count": 1, "min": 200, "max": 200}}}
# [02/08/2022 04:11:56 INFO 139697446053696] #throughput_metric: host=algo-1, train throughput=25529.93742690462 records/second
# [2022-02-08 04:12:04.509] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 7, "duration": 7561, "num_examples": 200, "num_bytes": 33493152}
# #metrics {"StartTime": 1644293524.5095057, "EndTime": 1644293524.5095918, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 0}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.3391149269755761, "count": 1, "min": 0.3391149269755761, "max": 0.3391149269755761}}}
# #metrics {"StartTime": 1644293524.509661, "EndTime": 1644293524.509676, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 1}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.3195404147047493, "count": 1, "min": 0.3195404147047493, "max": 0.3195404147047493}}}
# #metrics {"StartTime": 1644293524.509722, "EndTime": 1644293524.509738, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 2}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.32698557615040535, "count": 1, "min": 0.32698557615040535, "max": 0.32698557615040535}}}
# #metrics {"StartTime": 1644293524.5097835, "EndTime": 1644293524.5097976, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 3}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.3274032881846979, "count": 1, "min": 0.3274032881846979, "max": 0.3274032881846979}}}
# #metrics {"StartTime": 1644293524.5098453, "EndTime": 1644293524.5098608, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 4}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.4777964639903313, "count": 1, "min": 0.4777964639903313, "max": 0.4777964639903313}}}
# #metrics {"StartTime": 1644293524.509911, "EndTime": 1644293524.5099273, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 5}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.590638911990065, "count": 1, "min": 0.590638911990065, "max": 0.590638911990065}}}
# #metrics {"StartTime": 1644293524.5099769, "EndTime": 1644293524.5099926, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 6}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.48253254189802774, "count": 1, "min": 0.48253254189802774, "max": 0.48253254189802774}}}
# #metrics {"StartTime": 1644293524.5100422, "EndTime": 1644293524.5100574, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 7}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.6031271160259918, "count": 1, "min": 0.6031271160259918, "max": 0.6031271160259918}}}
# #metrics {"StartTime": 1644293524.5101066, "EndTime": 1644293524.5101216, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 8}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.3290663219432735, "count": 1, "min": 0.3290663219432735, "max": 0.3290663219432735}}}
# #metrics {"StartTime": 1644293524.5101702, "EndTime": 1644293524.5101857, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 9}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.33843334504707373, "count": 1, "min": 0.33843334504707373, "max": 0.33843334504707373}}}
# #metrics {"StartTime": 1644293524.5102448, "EndTime": 1644293524.5102606, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 10}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.33953402284401746, "count": 1, "min": 0.33953402284401746, "max": 0.33953402284401746}}}
# #metrics {"StartTime": 1644293524.5103037, "EndTime": 1644293524.5103188, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 11}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.3347382457100566, "count": 1, "min": 0.3347382457100566, "max": 0.3347382457100566}}}
# #metrics {"StartTime": 1644293524.5103672, "EndTime": 1644293524.510383, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 12}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.43369665937567475, "count": 1, "min": 0.43369665937567475, "max": 0.43369665937567475}}}
# #metrics {"StartTime": 1644293524.5104318, "EndTime": 1644293524.5104475, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 13}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5582932119513276, "count": 1, "min": 0.5582932119513276, "max": 0.5582932119513276}}}
# #metrics {"StartTime": 1644293524.510496, "EndTime": 1644293524.5105124, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 14}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.40992417111229057, "count": 1, "min": 0.40992417111229057, "max": 0.40992417111229057}}}
# #metrics {"StartTime": 1644293524.510561, "EndTime": 1644293524.5105767, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 15}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5464452117843245, "count": 1, "min": 0.5464452117843245, "max": 0.5464452117843245}}}
# #metrics {"StartTime": 1644293524.5106258, "EndTime": 1644293524.5106418, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 16}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.44801290402819766, "count": 1, "min": 0.44801290402819766, "max": 0.44801290402819766}}}
# #metrics {"StartTime": 1644293524.5106921, "EndTime": 1644293524.5107079, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 17}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.4507313074466571, "count": 1, "min": 0.4507313074466571, "max": 0.4507313074466571}}}
# #metrics {"StartTime": 1644293524.5107563, "EndTime": 1644293524.5107722, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 18}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.4471608550872036, "count": 1, "min": 0.4471608550872036, "max": 0.4471608550872036}}}
# #metrics {"StartTime": 1644293524.5108304, "EndTime": 1644293524.5108466, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 19}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.4506483911868915, "count": 1, "min": 0.4506483911868915, "max": 0.4506483911868915}}}
# #metrics {"StartTime": 1644293524.5109246, "EndTime": 1644293524.5109425, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 20}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5034817837087353, "count": 1, "min": 0.5034817837087353, "max": 0.5034817837087353}}}
# #metrics {"StartTime": 1644293524.5109935, "EndTime": 1644293524.5110383, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 21}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5302559648638394, "count": 1, "min": 0.5302559648638394, "max": 0.5302559648638394}}}
# #metrics {"StartTime": 1644293524.5110936, "EndTime": 1644293524.5111084, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 22}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5034230974091957, "count": 1, "min": 0.5034230974091957, "max": 0.5034230974091957}}}
# #metrics {"StartTime": 1644293524.5111575, "EndTime": 1644293524.5111728, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 23}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.531876334511455, "count": 1, "min": 0.531876334511455, "max": 0.531876334511455}}}
# #metrics {"StartTime": 1644293524.5112205, "EndTime": 1644293524.5112367, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 24}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.080485231179089, "count": 1, "min": 1.080485231179089, "max": 1.080485231179089}}}
# #metrics {"StartTime": 1644293524.511295, "EndTime": 1644293524.511311, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 25}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.0806065483668341, "count": 1, "min": 1.0806065483668341, "max": 1.0806065483668341}}}
# #metrics {"StartTime": 1644293524.511368, "EndTime": 1644293524.5113847, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 26}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.080347275623724, "count": 1, "min": 1.080347275623724, "max": 1.080347275623724}}}
# #metrics {"StartTime": 1644293524.5114388, "EndTime": 1644293524.511454, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 27}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.0807068119528305, "count": 1, "min": 1.0807068119528305, "max": 1.0807068119528305}}}
# #metrics {"StartTime": 1644293524.5115092, "EndTime": 1644293524.511526, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 28}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.1454150128388525, "count": 1, "min": 1.1454150128388525, "max": 1.1454150128388525}}}
# #metrics {"StartTime": 1644293524.5115788, "EndTime": 1644293524.5115952, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 29}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.2139291877171503, "count": 1, "min": 1.2139291877171503, "max": 1.2139291877171503}}}
# #metrics {"StartTime": 1644293524.5116456, "EndTime": 1644293524.51166, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 30}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.1451639179632291, "count": 1, "min": 1.1451639179632291, "max": 1.1451639179632291}}}
# #metrics {"StartTime": 1644293524.511697, "EndTime": 1644293524.5117102, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 31}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.2131926508764526, "count": 1, "min": 1.2131926508764526, "max": 1.2131926508764526}}}
# [02/08/2022 04:12:04 INFO 139697446053696] #quality_metric: host=algo-1, epoch=2, train binary_classification_weighted_cross_entropy_objective <loss>=0.3391149269755761
# [02/08/2022 04:12:04 INFO 139697446053696] #early_stopping_criteria_metric: host=algo-1, epoch=2, criteria=binary_classification_weighted_cross_entropy_objective, value=0.3195404147047493
# [02/08/2022 04:12:04 INFO 139697446053696] Epoch 2: Loss improved. Updating best model
# [02/08/2022 04:12:04 INFO 139697446053696] Saving model for epoch: 2
# [02/08/2022 04:12:04 INFO 139697446053696] Saved checkpoint to "/tmp/tmpxu_7gjsf/mx-mod-0000.params"
# [02/08/2022 04:12:04 INFO 139697446053696] #progress_metric: host=algo-1, completed 20.0 % of epochs
# #metrics {"StartTime": 1644293516.9479656, "EndTime": 1644293524.5214715, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 610092.0, "count": 1, "min": 610092, "max": 610092}, "Total Batches Seen": {"sum": 612.0, "count": 1, "min": 612, "max": 612}, "Max Records Seen Between Resets": {"sum": 199364.0, "count": 1, "min": 199364, "max": 199364}, "Max Batches Seen Between Resets": {"sum": 200.0, "count": 1, "min": 200, "max": 200}, "Reset Count": {"sum": 5.0, "count": 1, "min": 5, "max": 5}, "Number of Records Since Last Reset": {"sum": 199364.0, "count": 1, "min": 199364, "max": 199364}, "Number of Batches Since Last Reset": {"sum": 200.0, "count": 1, "min": 200, "max": 200}}}
# [02/08/2022 04:12:04 INFO 139697446053696] #throughput_metric: host=algo-1, train throughput=26323.427087907454 records/second
# [2022-02-08 04:12:12.246] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 9, "duration": 7724, "num_examples": 200, "num_bytes": 33493152}
# #metrics {"StartTime": 1644293532.2468286, "EndTime": 1644293532.24691, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 0}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.32226599174767884, "count": 1, "min": 0.32226599174767884, "max": 0.32226599174767884}}}
# #metrics {"StartTime": 1644293532.2470033, "EndTime": 1644293532.2470212, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 1}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.3074733453491824, "count": 1, "min": 0.3074733453491824, "max": 0.3074733453491824}}}
# ...
# #metrics {"StartTime": 1644293611.5434182, "EndTime": 1644293611.543425, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 5}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5330752930856829, "count": 1, "min": 0.5330752930856829, "max": 0.5330752930856829}}}
# #metrics {"StartTime": 1644293611.5434473, "EndTime": 1644293611.543454, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 6}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.28378996158005604, "count": 1, "min": 0.28378996158005604, "max": 0.28378996158005604}}}
# #metrics {"StartTime": 1644293611.5434763, "EndTime": 1644293611.5434828, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 7}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.47326236121019527, "count": 1, "min": 0.47326236121019527, "max": 0.47326236121019527}}}
# #metrics {"StartTime": 1644293611.5435052, "EndTime": 1644293611.5435119, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 8}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.29130650279749576, "count": 1, "min": 0.29130650279749576, "max": 0.29130650279749576}}}
# #metrics {"StartTime": 1644293611.5435367, "EndTime": 1644293611.5435455, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 9}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.29114658903955815, "count": 1, "min": 0.29114658903955815, "max": 0.29114658903955815}}}
# #metrics {"StartTime": 1644293611.543591, "EndTime": 1644293611.5436053, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 10}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.29353761303005504, "count": 1, "min": 0.29353761303005504, "max": 0.29353761303005504}}}
# #metrics {"StartTime": 1644293611.5436366, "EndTime": 1644293611.5436447, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 11}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.2908794963204082, "count": 1, "min": 0.2908794963204082, "max": 0.2908794963204082}}}
# #metrics {"StartTime": 1644293611.543668, "EndTime": 1644293611.5436747, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 12}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.2914942595515419, "count": 1, "min": 0.2914942595515419, "max": 0.2914942595515419}}}
# #metrics {"StartTime": 1644293611.5436966, "EndTime": 1644293611.5437033, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 13}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.4870187229367357, "count": 1, "min": 0.4870187229367357, "max": 0.4870187229367357}}}
# #metrics {"StartTime": 1644293611.543725, "EndTime": 1644293611.5437315, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 14}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.2914134636116986, "count": 1, "min": 0.2914134636116986, "max": 0.2914134636116986}}}
# #metrics {"StartTime": 1644293611.5437531, "EndTime": 1644293611.5437596, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 15}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.49398941992754913, "count": 1, "min": 0.49398941992754913, "max": 0.49398941992754913}}}
# #metrics {"StartTime": 1644293611.5437813, "EndTime": 1644293611.5437877, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 16}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.4376009713177705, "count": 1, "min": 0.4376009713177705, "max": 0.4376009713177705}}}
# #metrics {"StartTime": 1644293611.5438097, "EndTime": 1644293611.5438159, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 17}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.4484181482516342, "count": 1, "min": 0.4484181482516342, "max": 0.4484181482516342}}}
# #metrics {"StartTime": 1644293611.543837, "EndTime": 1644293611.5438437, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 18}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.43762711445410646, "count": 1, "min": 0.43762711445410646, "max": 0.43762711445410646}}}
# #metrics {"StartTime": 1644293611.5438654, "EndTime": 1644293611.5438724, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 19}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.44841468803367424, "count": 1, "min": 0.44841468803367424, "max": 0.44841468803367424}}}
# #metrics {"StartTime": 1644293611.543945, "EndTime": 1644293611.5439599, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 20}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.45202172866897966, "count": 1, "min": 0.45202172866897966, "max": 0.45202172866897966}}}
# #metrics {"StartTime": 1644293611.543991, "EndTime": 1644293611.5439985, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 21}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5203195825893077, "count": 1, "min": 0.5203195825893077, "max": 0.5203195825893077}}}
# #metrics {"StartTime": 1644293611.5440252, "EndTime": 1644293611.5440323, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 22}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.4520227471739803, "count": 1, "min": 0.4520227471739803, "max": 0.4520227471739803}}}
# #metrics {"StartTime": 1644293611.544055, "EndTime": 1644293611.5440617, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 23}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 0.5202868180394772, "count": 1, "min": 0.5202868180394772, "max": 0.5202868180394772}}}
# #metrics {"StartTime": 1644293611.5440836, "EndTime": 1644293611.54409, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 24}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.0734474260339786, "count": 1, "min": 1.0734474260339786, "max": 1.0734474260339786}}}
# #metrics {"StartTime": 1644293611.5441117, "EndTime": 1644293611.5441182, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 25}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.0808105422743601, "count": 1, "min": 1.0808105422743601, "max": 1.0808105422743601}}}
# #metrics {"StartTime": 1644293611.54414, "EndTime": 1644293611.5441465, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 26}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.073446477075318, "count": 1, "min": 1.073446477075318, "max": 1.073446477075318}}}
# #metrics {"StartTime": 1644293611.5441682, "EndTime": 1644293611.544175, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 27}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.0808158106204853, "count": 1, "min": 1.0808158106204853, "max": 1.0808158106204853}}}
# #metrics {"StartTime": 1644293611.5441966, "EndTime": 1644293611.544203, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 28}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.081110000226965, "count": 1, "min": 1.081110000226965, "max": 1.081110000226965}}}
# #metrics {"StartTime": 1644293611.5442247, "EndTime": 1644293611.5442314, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 29}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.178819695554187, "count": 1, "min": 1.178819695554187, "max": 1.178819695554187}}}
# #metrics {"StartTime": 1644293611.5442529, "EndTime": 1644293611.5442593, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 30}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.0811094335814817, "count": 1, "min": 1.0811094335814817, "max": 1.0811094335814817}}}
# #metrics {"StartTime": 1644293611.544281, "EndTime": 1644293611.5442874, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "model": 31}, "Metrics": {"train_binary_classification_weighted_cross_entropy_objective": {"sum": 1.1788132949905779, "count": 1, "min": 1.1788132949905779, "max": 1.1788132949905779}}}
# [02/08/2022 04:13:31 INFO 139697446053696] #quality_metric: host=algo-1, epoch=14, train binary_classification_weighted_cross_entropy_objective <loss>=0.29068308453583835
# [02/08/2022 04:13:31 INFO 139697446053696] #early_stopping_criteria_metric: host=algo-1, epoch=14, criteria=binary_classification_weighted_cross_entropy_objective, value=0.28373790798474796
# [02/08/2022 04:13:31 INFO 139697446053696] Epoch 14: Loss improved. Updating best model
# [02/08/2022 04:13:31 INFO 139697446053696] Saving model for epoch: 14
# [02/08/2022 04:13:31 INFO 139697446053696] Saved checkpoint to "/tmp/tmp6p1g859q/mx-mod-0000.params"
# [02/08/2022 04:13:31 INFO 139697446053696] #progress_metric: host=algo-1, completed 100.0 % of epochs
# #metrics {"StartTime": 1644293604.8748484, "EndTime": 1644293611.5535636, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 14, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 3002460.0, "count": 1, "min": 3002460, "max": 3002460}, "Total Batches Seen": {"sum": 3012.0, "count": 1, "min": 3012, "max": 3012}, "Max Records Seen Between Resets": {"sum": 199364.0, "count": 1, "min": 199364, "max": 199364}, "Max Batches Seen Between Resets": {"sum": 200.0, "count": 1, "min": 200, "max": 200}, "Reset Count": {"sum": 17.0, "count": 1, "min": 17, "max": 17}, "Number of Records Since Last Reset": {"sum": 199364.0, "count": 1, "min": 199364, "max": 199364}, "Number of Batches Since Last Reset": {"sum": 200.0, "count": 1, "min": 200, "max": 200}}}
# [02/08/2022 04:13:31 INFO 139697446053696] #throughput_metric: host=algo-1, train throughput=29849.973667983213 records/second
# [02/08/2022 04:13:31 WARNING 139697446053696] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [02/08/2022 04:13:31 WARNING 139697446053696] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [2022-02-08 04:13:31.559] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 33, "duration": 3, "num_examples": 1, "num_bytes": 168000}
# [2022-02-08 04:13:32.143] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 36, "duration": 581, "num_examples": 200, "num_bytes": 33493152}
# [2022-02-08 04:13:33.045] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 38, "duration": 826, "num_examples": 200, "num_bytes": 33493152}
# [02/08/2022 04:13:33 INFO 139697446053696] #train_score (algo-1) : ('binary_classification_weighted_cross_entropy_objective', 0.2687483957430368)
# [02/08/2022 04:13:33 INFO 139697446053696] #train_score (algo-1) : ('binary_classification_accuracy', 0.999398085913204)
# [02/08/2022 04:13:33 INFO 139697446053696] #train_score (algo-1) : ('binary_f_1.000', 0.8255813953488372)
# [02/08/2022 04:13:33 INFO 139697446053696] #train_score (algo-1) : ('precision', 0.8580060422960725)
# [02/08/2022 04:13:33 INFO 139697446053696] #train_score (algo-1) : ('recall', 0.7955182072829131)
# [02/08/2022 04:13:33 INFO 139697446053696] #train_score (algo-1) : ('roc_auc_score', 0.9883347149127631)
# [02/08/2022 04:13:33 INFO 139697446053696] #train_score (algo-1) : ('binary_balanced_accuracy', 0.5)
# [02/08/2022 04:13:33 INFO 139697446053696] #train_score (algo-1) : ('binary_log_loss', 0.7326821872687728)
# [02/08/2022 04:13:33 INFO 139697446053696] #quality_metric: host=algo-1, train binary_classification_weighted_cross_entropy_objective <loss>=0.2687483957430368
# [02/08/2022 04:13:33 INFO 139697446053696] #quality_metric: host=algo-1, train binary_classification_accuracy <score>=0.999398085913204
# [02/08/2022 04:13:33 INFO 139697446053696] #quality_metric: host=algo-1, train binary_f_1.000 <score>=0.8255813953488372
# [02/08/2022 04:13:33 INFO 139697446053696] #quality_metric: host=algo-1, train precision <score>=0.8580060422960725
# [02/08/2022 04:13:33 INFO 139697446053696] #quality_metric: host=algo-1, train recall <score>=0.7955182072829131
# [02/08/2022 04:13:33 INFO 139697446053696] #quality_metric: host=algo-1, train roc_auc_score <score>=0.9883347149127631
# [02/08/2022 04:13:33 INFO 139697446053696] #quality_metric: host=algo-1, train binary_balanced_accuracy <score>=0.5
# [02/08/2022 04:13:33 INFO 139697446053696] #quality_metric: host=algo-1, train binary_log_loss <score>=0.7326821872687728
# [02/08/2022 04:13:33 INFO 139697446053696] Best model found for hyperparameters: {"optimizer": "adam", "learning_rate": 0.1, "wd": 0.0001, "l1": 0.0, "lr_scheduler_step": 10, "lr_scheduler_factor": 0.99, "lr_scheduler_minimum_lr": 1e-05}
# [02/08/2022 04:13:33 INFO 139697446053696] Saved checkpoint to "/tmp/tmp_be04pqn/mx-mod-0000.params"
# [02/08/2022 04:13:33 INFO 139697446053696] Test data is not provided.
# #metrics {"StartTime": 1644293501.6912026, "EndTime": 1644293613.337099, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training"}, "Metrics": {"initialize.time": {"sum": 326.32970809936523, "count": 1, "min": 326.32970809936523, "max": 326.32970809936523}, "epochs": {"sum": 15.0, "count": 1, "min": 15, "max": 15}, "check_early_stopping.time": {"sum": 15.334367752075195, "count": 15, "min": 0.8897781372070312, "max": 1.2230873107910156}, "update.time": {"sum": 109473.28186035156, "count": 15, "min": 6675.909519195557, "max": 7805.915594100952}, "finalize.time": {"sum": 1773.3173370361328, "count": 1, "min": 1773.3173370361328, "max": 1773.3173370361328}, "setuptime": {"sum": 24.641036987304688, "count": 1, "min": 24.641036987304688, "max": 24.641036987304688}, "totaltime": {"sum": 111892.3146724701, "count": 1, "min": 111892.3146724701, "max": 111892.3146724701}}}
#
# 2022-02-08 04:13:47 Uploading - Uploading generated training model
# 2022-02-08 04:13:47 Completed - Training job completed
# ProfilerReport-1644293266: NoIssuesFound
# Training seconds: 185
# Billable seconds: 185
# CPU times: user 861 ms, sys: 56.6 ms, total: 917 ms
# Wall time: 6min 15s

# %%
# %%time 
# deploy and evaluate a predictor
my_predictor = my_learner.deploy(initial_instance_count=1, instance_type='ml.t2.medium')
# Out:
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# -------!CPU times: user 150 ms, sys: 217 µs, total: 150 ms
# Wall time: 3min 31s

# %%
print('Metrics for balanced, LinearLearner.\n')

# get metrics for balanced predictor
metrics = evaluate(my_predictor, 
                   test_features.values.astype('float32'), 
                   test_labels, 
                   verbose=True)
# Out:
# Metrics for balanced, LinearLearner.
#
# prediction (col)    0.0  1.0
# actual (row)
# 0                 85286   22
# 1                    34  101
#
# Recall:     0.748
# Precision:  0.821
# Accuracy:   0.999

# %%
## IMPORTANT
# delete the predictor endpoint after evaluation 
delete_endpoint(my_predictor)
# Out:
# The endpoint attribute has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The endpoint attribute has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# Deleted linear-learner-2022-02-08-04-14-02-030

# %% [markdown]
# ## Final Cleanup!
#
# * Double check that you have deleted all your endpoints.
# * I'd also suggest manually deleting your S3 bucket, models, and endpoint configurations directly from your AWS console.
#
# You can find thorough cleanup instructions, [in the documentation](https://docs.aws.amazon.com/sagemaker/latest/dg/ex1-cleanup.html).

# %% [markdown]
# ---
# # Conclusion
#
# In this notebook, you saw how to train and deploy a LinearLearner in SageMaker. This model is well-suited for a binary classification task that involves specific design decisions and managing class imbalance in the training set.
#
# Following the steps of a machine learning workflow, you loaded in some credit card transaction data, explored that data and prepared it for model training. Then trained, deployed, and evaluated several models, according to different design considerations!
